# %%
data = [
    ["What are the saved hours for each improvement in the database?", "SELECT Improve_name, Time AS Saved_Hours FROM Jidouka;"],
    ["Can you tell me about the departments involved in the database?", "SELECT Department_name FROM Department;"],
    ["Who are the creators of the innovations listed?", "SELECT Author_name AS Creator FROM Author;"],
    ["Which tools are associated with jidouka improvements?", "SELECT DISTINCT Tool_name FROM Tool INNER JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id;"],
    ["Show me all jidouka improvements and their associated products.", "SELECT Improve_name, Product_name FROM Jidouka;"],
    ["What is the purpose of quantum computing?", "Quantum computing leverages quantum-mechanical phenomena to perform operations on data, often solving problems faster than classical computers for specific tasks."],
    ["How many applications does each jidouka improvement have?", "SELECT Improve_name, Applications FROM Jidouka;"],
    ["List the launch times of all innovations.", "SELECT Improve_name, Release_date AS Launch_Time FROM Jidouka;"],
    ["Who created the task named 'Optimization'? (Assume 'Optimization' exists)", "SELECT Author_name AS Creator FROM Author INNER JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE Improve_name = 'Optimization';"],
    ["What is the latest product innovation in the database?", "SELECT Improve_name, Product_name FROM Jidouka ORDER BY Release_date DESC LIMIT 1;"],
    ["What is the tallest building in the world?", "The tallest building in the world is the Burj Khalifa in Dubai, standing at 828 meters."],
    ["How many hours were saved by improvements in the 'Design Center' department?", "SELECT SUM(Time) AS Total_Saved_Hours FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Design Center';"],
    ["Which tools are used in more than one jidouka improvement?", "SELECT Tool_name FROM Tool INNER JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id GROUP BY Tool_name HAVING COUNT(DISTINCT Jidouka_id) > 1;"],
    ["What is the population of Japan?", "I am not sure about the exact population of Japan."],
    ["What are the types of tasks associated with jidouka?", "SELECT DISTINCT Job_name AS Task_Type FROM Job INNER JOIN Jidouka ON Job.Id = Jidouka.Job_id;"],
    ["Give me a list of all additional documents linked to improvements.", "SELECT Improve_name, Other_info AS Additional_Documents FROM Jidouka;"],
    ["Who are the employees working on improvements that saved more than 50 hours?", "SELECT Author_name AS Employee FROM Author INNER JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE Time > 50;"],
    ["List all improvements that apply to at least 10 tasks.", "SELECT Improve_name FROM Jidouka WHERE Applications >= 10;"],
    ["What are the outputs of innovations launched in the last year?", "SELECT Improve_name, Product_name AS Output FROM Jidouka WHERE Release_date >= DATE_SUB(CURDATE(), INTERVAL 1 YEAR);"],
    ["How many different tools are in the database?", "SELECT COUNT(DISTINCT Tool_name) AS Total_Tools FROM Tool;"],
    ["List all tasks and the departments they are associated with.", "SELECT Job_name AS Task, Department_name AS Department FROM Job INNER JOIN Jidouka ON Job.Id = Jidouka.Job_id INNER JOIN Department ON Department.Id = Jidouka.Department_id;"],
    ["What is the total number of applications across all improvements?", "SELECT SUM(Applications) AS Total_Applications FROM Jidouka;"],
    ["Which employees are associated with improvements involving the tool '3D Printer'?", "SELECT Author_name AS Employee FROM Author INNER JOIN Jidouka ON Author.Id = Jidouka.Author_id INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON Tool.Id = JidoukaTool.Tool_id WHERE Tool_name = '3D Printer';"],
    ["Give me the details of improvements introduced after January 1, 2023.", "SELECT * FROM Jidouka WHERE Release_date > '2023-01-01';"],
    ["What are the most frequently used tools in jidouka improvements?", "SELECT Tool_name, COUNT(*) AS Usage_Count FROM Tool INNER JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id GROUP BY Tool_name ORDER BY Usage_Count DESC;"],
    ["How do solar panels work?", "Solar panels convert sunlight into electricity using photovoltaic cells."],
    ["List the innovations that saved exactly 100 hours.", "SELECT Improve_name FROM Jidouka WHERE Time = 100;"],
    ["What departments have more than 3 innovations associated with them?", "SELECT Department_name FROM Department INNER JOIN Jidouka ON Department.Id = Jidouka.Department_id GROUP BY Department_name HAVING COUNT(*) > 3;"],
    ["Which innovations have no description provided?", "SELECT Improve_name FROM Jidouka WHERE Description IS NULL;"],
    ["Show the total number of improvements created by each employee.", "SELECT Author_name, COUNT(*) AS Total_Improvements FROM Author INNER JOIN Jidouka ON Author.Id = Jidouka.Author_id GROUP BY Author_name;"],
    ["What is the speed of light?", "The speed of light in a vacuum is approximately 299,792 kilometers per second."],
    ["Which innovations involve both 'Tool A' and 'Tool B'?", "SELECT Improve_name FROM Jidouka INNER JOIN JidoukaTool AS jt1 ON Jidouka.Id = jt1.Jidouka_id INNER JOIN Tool AS t1 ON jt1.Tool_id = t1.Id INNER JOIN JidoukaTool AS jt2 ON Jidouka.Id = jt2.Jidouka_id INNER JOIN Tool AS t2 ON jt2.Tool_id = t2.Id WHERE t1.Tool_name = 'Tool A' AND t2.Tool_name = 'Tool B';"],
    ["What are the earliest innovations in the database?", "SELECT Improve_name, Release_date FROM Jidouka ORDER BY Release_date ASC LIMIT 5;"],
    ["What are the outputs of all improvements in the 'Manufacturing' department?", "SELECT Improve_name, Product_name AS Output FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Manufacturing';"],
    ["Which jobs have no associated innovations?", "SELECT Job_name FROM Job LEFT JOIN Jidouka ON Job.Id = Jidouka.Job_id WHERE Jidouka.Id IS NULL;"],
    ["List the documents linked to innovations that saved more than 20 hours.", "SELECT Improve_name, Other_info AS Document FROM Jidouka WHERE Time > 20;"],
    ["How many employees are in the database?", "SELECT COUNT(*) AS Total_Employees FROM Author;"],
    ["What is the formula for calculating the area of a circle?", "The formula is π × r², where r is the radius of the circle."],
    ["Which tools are associated with improvements in the 'Research and Development' team?", "SELECT DISTINCT Tool_name FROM Tool INNER JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id INNER JOIN Jidouka ON JidoukaTool.Jidouka_id = Jidouka.Id INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Research and Development';"],
    ["How many hours in total were saved by innovations launched after 2020?", "SELECT SUM(Time) AS Total_Saved_Hours FROM Jidouka WHERE Release_date > '2020-01-01';"],
    ["What are the types of tasks most commonly associated with jidouka?", "SELECT Job_name, COUNT(*) AS Frequency FROM Job INNER JOIN Jidouka ON Job.Id = Jidouka.Job_id GROUP BY Job_name ORDER BY Frequency DESC;"],
    ["Which innovation applies to the most tasks?", "SELECT Improve_name, Applications FROM Jidouka ORDER BY Applications DESC LIMIT 1;"],
    ["What is the purpose of photosynthesis?", "Photosynthesis is the process by which plants convert sunlight into chemical energy stored in glucose."],
    ["What improvements have the longest description?", "SELECT Improve_name, LENGTH(Description) AS Description_Length FROM Jidouka ORDER BY Description_Length DESC LIMIT 1;"],
    ["List all innovations associated with the product 'Eco-friendly Packaging'.", "SELECT Improve_name FROM Jidouka WHERE Product_name = 'Eco-friendly Packaging';"],
    ["What are the additional documents available for improvements in the 'Team A' department?", "SELECT Improve_name, Other_info AS Additional_Documents FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Team A';"],
    ["Who is the author of the innovation named 'Automation Upgrade'?", "SELECT Author_name AS Author FROM Author INNER JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE Improve_name = 'Automation Upgrade';"],
    ["What are the most recent improvements introduced by 'John Doe'?", "SELECT Improve_name, Release_date FROM Jidouka INNER JOIN Author ON Jidouka.Author_id = Author.Id WHERE Author_name = 'John Doe' ORDER BY Release_date DESC;"],
    ["What are the most common tools in the database?", "SELECT Tool_name, COUNT(*) AS Frequency FROM Tool INNER JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id GROUP BY Tool_name ORDER BY Frequency DESC;"],
    ["What is the distance from the Earth to the Moon?", "The average distance from the Earth to the Moon is approximately 384,400 kilometers."],
    ["What innovations are linked to more than 5 tasks?", "SELECT Improve_name FROM Jidouka WHERE Applications > 5;"],
    ["How many improvements have been created in the last month?", "SELECT COUNT(*) AS Recent_Improvements FROM Jidouka WHERE Release_date >= DATE_SUB(CURDATE(), INTERVAL 1 MONTH);"],
    ["Which authors have not contributed to any improvements?", "SELECT Author_name FROM Author LEFT JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE Jidouka.Id IS NULL;"],
    ["Show the details of all jidouka improvements associated with the 'Tool Kit' tool.", "SELECT Jidouka.* FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON JidoukaTool.Tool_id = Tool.Id WHERE Tool_name = 'Tool Kit';"],
    ["List all tools used in innovations introduced before 2022.", "SELECT DISTINCT Tool_name FROM Tool INNER JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id INNER JOIN Jidouka ON JidoukaTool.Jidouka_id = Jidouka.Id WHERE Release_date < '2022-01-01';"],
    ["Which departments have no jidouka improvements linked to them?", "SELECT Department_name FROM Department LEFT JOIN Jidouka ON Department.Id = Jidouka.Department_id WHERE Jidouka.Id IS NULL;"],
    ["What is the capital of France?", "The capital of France is Paris."],
    ["How many hours in total were saved by innovations linked to 'Tool X'?", "SELECT SUM(Time) AS Total_Saved_Hours FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON JidoukaTool.Tool_id = Tool.Id WHERE Tool_name = 'Tool X';"],
    ["What are the unique products associated with jidouka improvements?", "SELECT DISTINCT Product_name AS Unique_Products FROM Jidouka;"],
    ["Which innovations have no associated tools?", "SELECT Improve_name FROM Jidouka LEFT JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id WHERE JidoukaTool.Tool_id IS NULL;"],
    ["List the employees who contributed to innovations saving more than 30 hours.", "SELECT DISTINCT Author_name AS Employee FROM Author INNER JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE Time > 30;"],
    ["What are the most recent innovations in the 'Engineering' team?", "SELECT Improve_name, Release_date FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Engineering' ORDER BY Release_date DESC;"],
    ["Who created the most jidouka improvements?", "SELECT Author_name, COUNT(*) AS Total_Improvements FROM Author INNER JOIN Jidouka ON Author.Id = Jidouka.Author_id GROUP BY Author_name ORDER BY Total_Improvements DESC LIMIT 1;"],
    ["What are the most common departments associated with jidouka improvements?", "SELECT Department_name, COUNT(*) AS Total_Improvements FROM Department INNER JOIN Jidouka ON Department.Id = Jidouka.Department_id GROUP BY Department_name ORDER BY Total_Improvements DESC;"],
    ["How does blockchain technology work?", "Blockchain is a decentralized digital ledger that records transactions across multiple computers in a secure and immutable manner."],
    ["Which improvements apply to tasks in 'Logistics'?", "SELECT Improve_name FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Logistics';"],
    ["What are the names of all the jobs?", "SELECT Job_name FROM Job;"],
    ["List all the departments and their IDs.", "SELECT Id, Department_name FROM Department;"],
    ["Who created the improvements and what are their names?", "SELECT Author_name, Improve_name FROM Author JOIN Jidouka ON Author.Id = Jidouka.Author_id;"],
    ["Which tools are associated with each improvement?", "SELECT Jidouka.Improve_name, Tool.Tool_name FROM JidoukaTool JOIN Jidouka ON JidoukaTool.Jidouka_id = Jidouka.Id JOIN Tool ON JidoukaTool.Tool_id = Tool.Id;"],
    ["How many applications have been associated with each jidouka?", "SELECT Improve_name, Applications FROM Jidouka;"],
    ["List all the jidouka released in 2023.", "SELECT Improve_name FROM Jidouka WHERE YEAR(Release_date) = 2023;"],
    ["What is the total number of jobs?", "SELECT COUNT(*) FROM Job;"],
    ["Show all the details for improvements related to a specific department called 'Design'.", "SELECT * FROM Jidouka JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Design';"],
    ["List the saved hours and product names for all jidoukas.", "SELECT Time, Product_name FROM Jidouka;"],
    ["Give me the name of the employee who authored 'Automation Process Improvement'.", "SELECT Author_name FROM Author JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE Improve_name = 'Automation Process Improvement';"],
    ["Can you tell me who invented the light bulb?", "The light bulb was invented by Thomas Edison, although others also contributed to its development."],
    ["What is the tallest mountain in the world?", "Mount Everest is the tallest mountain in the world."],
    ["List all authors and their jidouka innovations.", "SELECT Author_name, Improve_name FROM Author JOIN Jidouka ON Author.Id = Jidouka.Author_id;"],
    ["Who are the employees working in departments related to innovation?", "SELECT DISTINCT Author_name FROM Author JOIN Jidouka ON Author.Id = Jidouka.Author_id JOIN Department ON Jidouka.Department_id = Department.Id;"],
    ["What tools are most commonly used in jidoukas that save more than 100 hours?", "SELECT Tool.Tool_name FROM JidoukaTool JOIN Jidouka ON JidoukaTool.Jidouka_id = Jidouka.Id JOIN Tool ON JidoukaTool.Tool_id = Tool.Id WHERE Jidouka.Time > 100;"],
    ["What department is involved in innovations released before 2022?", "SELECT DISTINCT Department_name FROM Department JOIN Jidouka ON Department.Id = Jidouka.Department_id WHERE Release_date < '2022-01-01';"],
    ["Show me the document link or other info of improvements done by 'John Smith'.", "SELECT Other_info FROM Jidouka JOIN Author ON Jidouka.Author_id = Author.Id WHERE Author_name = 'John Smith';"],
    ["How many jidoukas have been released after 2020?", "SELECT COUNT(*) FROM Jidouka WHERE Release_date > '2020-01-01';"],
    ["What are the most popular programming languages?", "I am not sure."],
    ["Who is known as the father of modern physics?", "Albert Einstein is often considered the father of modern physics."],
    ["List all improvements along with their respective job names.", "SELECT Improve_name, Job_name FROM Jidouka JOIN Job ON Jidouka.Job_id = Job.Id;"],
    ["What are the names of all tools used in the 'Quality Assurance' department?", "SELECT Tool.Tool_name FROM JidoukaTool JOIN Jidouka ON JidoukaTool.Jidouka_id = Jidouka.Id JOIN Tool ON JidoukaTool.Tool_id = Tool.Id JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Quality Assurance';"],
    ["What is the average number of applications per improvement?", "SELECT AVG(Applications) FROM Jidouka;"],
    ["Who are some famous authors in history?", "I am not sure."],
    ["List all improvements that have documentation.", "SELECT Improve_name, Other_info FROM Jidouka WHERE Other_info IS NOT NULL;"],
    ["What is the release date for each jidouka?", "SELECT Improve_name, Release_date FROM Jidouka;"],
    ["Show all job names where the saved time is more than 200 hours.", "SELECT Job_name FROM Jidouka JOIN Job ON Jidouka.Job_id = Job.Id WHERE Time > 200;"],
    ["Who created the first car?", "Karl Benz is credited with inventing the first modern automobile."],
    ["List improvements along with their number of applications.", "SELECT Improve_name, Applications FROM Jidouka;"],
    ["What are the names of all jidoukas with a specific tool, say 'AI Assistant'?", "SELECT Improve_name FROM Jidouka JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id JOIN Tool ON JidoukaTool.Tool_id = Tool.Id WHERE Tool_name = 'AI Assistant';"],
    ["Can you explain quantum mechanics?", "Quantum mechanics is a fundamental theory in physics describing the properties of nature on an atomic scale, but it's complex and detailed."],
    ["Show the description and product name for jidoukas in the 'R&D' team.", "SELECT Description, Product_name FROM Jidouka JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'R&D';"],
    ["List authors and the saved time of the jidoukas they created.", "SELECT Author_name, Time FROM Author JOIN Jidouka ON Author.Id = Jidouka.Author_id;"],
    ["What improvements were made by employees with more than one tool used?", "SELECT Improve_name FROM Jidouka JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id GROUP BY Jidouka.Id HAVING COUNT(Tool_id) > 1;"],
    ["Which improvements have more than 500 applications?", "SELECT Improve_name FROM Jidouka WHERE Applications > 500;"],
    ["What is the capital of France?", "The capital of France is Paris."],
    ["How many improvements were made by the author 'Jane Doe'?", "SELECT COUNT(*) FROM Jidouka JOIN Author ON Jidouka.Author_id = Author.Id WHERE Author_name = 'Jane Doe';"],
    ["List all departments involved in more than 5 improvements.", "SELECT Department_name FROM Department JOIN Jidouka ON Department.Id = Jidouka.Department_id GROUP BY Department_name HAVING COUNT(Jidouka.Id) > 5;"],
    ["Who are the authors of jidoukas related to 'AI Development'?", "SELECT Author_name FROM Author JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE Improve_name LIKE '%AI Development%';"],
    ["What year was the World Wide Web invented?", "The World Wide Web was invented in 1989 by Tim Berners-Lee."],
    ["List all product names of jidoukas released in 2021.", "SELECT Product_name FROM Jidouka WHERE YEAR(Release_date) = 2021;"],
    ["Show the tools used in improvements that save more than 50 hours.", "SELECT DISTINCT Tool_name FROM Tool JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id JOIN Jidouka ON JidoukaTool.Jidouka_id = Jidouka.Id WHERE Jidouka.Time > 50;"],
    ["What is the current population of the world?", "I am not sure about the current population."],
    ["List the job types and their associated innovations.", "SELECT Job_name, Improve_name FROM Job JOIN Jidouka ON Job.Id = Jidouka.Job_id;"],
    ["Who are the top 5 most prolific authors based on the number of jidoukas?", "SELECT Author_name, COUNT(Jidouka.Id) AS JidoukaCount FROM Author JOIN Jidouka ON Author.Id = Jidouka.Author_id GROUP BY Author_name ORDER BY JidoukaCount DESC LIMIT 5;"],
    ["List the improvements related to a tool called 'Data Analyzer'.", "SELECT Improve_name FROM Jidouka JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id JOIN Tool ON JidoukaTool.Tool_id = Tool.Id WHERE Tool_name = 'Data Analyzer';"],
    ["Who are the notable composers of classical music?", "Some notable classical composers include Ludwig van Beethoven, Wolfgang Amadeus Mozart, and Johann Sebastian Bach."],
    ["Which improvements have a release date before 2020?", "SELECT Improve_name FROM Jidouka WHERE Release_date < '2020-01-01';"],
    ["What is the average saved time for all improvements?", "SELECT AVG(Time) FROM Jidouka;"],
    ["Can you name the author of 'Improvement X'?", "SELECT Author_name FROM Author JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE Improve_name = 'Improvement X';"],
    ["Which departments have more than 3 authors associated with their jidoukas?", "SELECT Department_name FROM Department JOIN Jidouka ON Department.Id = Jidouka.Department_id JOIN Author ON Jidouka.Author_id = Author.Id GROUP BY Department_name HAVING COUNT(DISTINCT Author.Id) > 3;"],
    ["List the product outputs along with their release dates.", "SELECT Product_name, Release_date FROM Jidouka;"],
    ["How many authors contributed to innovations involving 'Machine Learning'?", "SELECT COUNT(DISTINCT Author.Id) FROM Author JOIN Jidouka ON Author.Id = Jidouka.Author_id JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id JOIN Tool ON JidoukaTool.Tool_id = Tool.Id WHERE Tool_name = 'Machine Learning';"],
    ["What is the largest desert in the world?", "The largest desert in the world is the Sahara Desert."],
    ["What innovations were released in December 2022?", "SELECT Improve_name FROM Jidouka WHERE MONTH(Release_date) = 12 AND YEAR(Release_date) = 2022;"],
    ["Show all details for improvements made by 'Michael Johnson'.", "SELECT * FROM Jidouka JOIN Author ON Jidouka.Author_id = Author.Id WHERE Author_name = 'Michael Johnson';"],
    ["Which jidoukas have product names containing 'Tech'?", "SELECT Improve_name FROM Jidouka WHERE Product_name LIKE '%Tech%';"],
    ["List the authors and tools associated with improvements released before 2021.", "SELECT Author_name, Tool_name FROM Author JOIN Jidouka ON Author.Id = Jidouka.Author_id JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id JOIN Tool ON JidoukaTool.Tool_id = Tool.Id WHERE Release_date < '2021-01-01';"],
    ["What is the meaning of life?", "Philosophically, the meaning of life is a complex topic, often considered to be subjective."],
    ["How many jidoukas are associated with each tool?", "SELECT Tool_name, COUNT(JidoukaTool.Jidouka_id) AS JidoukaCount FROM Tool JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id GROUP BY Tool_name;"],
    ["List the departments and the number of jidoukas they are involved in.", "SELECT Department_name, COUNT(Jidouka.Id) AS JidoukaCount FROM Department JOIN Jidouka ON Department.Id = Jidouka.Department_id GROUP BY Department_name;"],
    ["What innovations were created by the author 'Alex Lee' in the 'Engineering' department?", "SELECT Improve_name FROM Jidouka JOIN Author ON Jidouka.Author_id = Author.Id JOIN Department ON Jidouka.Department_id = Department.Id WHERE Author_name = 'Alex Lee' AND Department_name = 'Engineering';"],
    ["Show improvements and their application counts sorted by highest to lowest.", "SELECT Improve_name, Applications FROM Jidouka ORDER BY Applications DESC;"],
    ["List all the improvements where saved time is exactly 100 hours.", "SELECT Improve_name FROM Jidouka WHERE Time = 100;"],
    ["What tool is used the most across all improvements?", "SELECT Tool_name FROM Tool JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id GROUP BY Tool_name ORDER BY COUNT(JidoukaTool.Jidouka_id) DESC LIMIT 1;"],
    ["Can you tell me about quantum computers?", "Quantum computers use the principles of quantum mechanics to process information much more efficiently for certain tasks than classical computers."],
    ["What is the link to documents for innovations that saved more than 150 hours?", "SELECT Other_info FROM Jidouka WHERE Time > 150;"],
    ["List the job names where innovations were released after 2022.", "SELECT Job_name FROM Jidouka JOIN Job ON Jidouka.Job_id = Job.Id WHERE Release_date > '2022-01-01';"],
    ["Who are the authors of the innovations with fewer than 5 applications?", "SELECT Author_name FROM Author JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE Applications < 5;"],
    ["List the names of tools not used in any jidouka.", "SELECT Tool_name FROM Tool WHERE Id NOT IN (SELECT Tool_id FROM JidoukaTool);"],
    ["Show the release date and saved time for jidoukas authored by 'Emma Brown'.", "SELECT Release_date, Time FROM Jidouka JOIN Author ON Jidouka.Author_id = Author.Id WHERE Author_name = 'Emma Brown';"],
    ["What are the most innovative technologies in 2023?", "I am not sure."],
    ["How many jidoukas were authored by 'Robert White' in 2020?", "SELECT COUNT(*) FROM Jidouka JOIN Author ON Jidouka.Author_id = Author.Id WHERE Author_name = 'Robert White' AND YEAR(Release_date) = 2020;"],
    ["Which departments have tools used in more than 3 improvements?", "SELECT Department_name FROM Department JOIN Jidouka ON Department.Id = Jidouka.Department_id JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id GROUP BY Department_name HAVING COUNT(DISTINCT JidoukaTool.Tool_id) > 3;"],
    ["What is the product of the longest improvement?", "SELECT Product_name FROM Jidouka ORDER BY Time DESC LIMIT 1;"],
    ["List the authors and departments they are associated with.", "SELECT Author_name, Department_name FROM Author JOIN Jidouka ON Author.Id = Jidouka.Author_id JOIN Department ON Jidouka.Department_id = Department.Id;"],
    ["Show improvements launched on weekends.", "SELECT Improve_name FROM Jidouka WHERE DAYOFWEEK(Release_date) IN (1, 7);"],
    ["Who were the major contributors to innovations in the 'Tech' field?", "SELECT Author_name FROM Author JOIN Jidouka ON Author.Id = Jidouka.Author_id JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name LIKE '%Tech%';"],
    ["What is the output of the improvement with the most applications?", "SELECT Product_name FROM Jidouka ORDER BY Applications DESC LIMIT 1;"],
    ["Can you tell me about the basics of AI?", "Artificial Intelligence (AI) involves creating algorithms and systems that mimic human intelligence to perform tasks like learning and problem-solving."],
    ["Show all improvements associated with authors who have released more than 3 innovations.", "SELECT Improve_name FROM Jidouka JOIN Author ON Jidouka.Author_id = Author.Id GROUP BY Author.Id HAVING COUNT(Jidouka.Id) > 3;"],
    ["List the names of jidoukas and the departments that released them after 2021.", "SELECT Improve_name, Department_name FROM Jidouka JOIN Department ON Jidouka.Department_id = Department.Id WHERE Release_date > '2021-01-01';"],
    ["What are the innovations with saved hours greater than 200?", "SELECT Improve_name FROM Jidouka WHERE Time > 200;"],
    ["List all tools linked to more than three improvements.", "SELECT Tool_name FROM Tool INNER JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id GROUP BY Tool_name HAVING COUNT(DISTINCT Jidouka_id) > 3;"],
    ["How many products are associated with improvements in the database?", "SELECT COUNT(DISTINCT Product_name) AS Total_Products FROM Jidouka;"],
    ["Which department has contributed to the most innovations?", "SELECT Department_name, COUNT(*) AS Total_Innovations FROM Department INNER JOIN Jidouka ON Department.Id = Jidouka.Department_id GROUP BY Department_name ORDER BY Total_Innovations DESC LIMIT 1;"],
    ["What is the purpose of AI?", "Artificial Intelligence aims to simulate human intelligence processes in machines to solve complex problems and automate tasks."],
    ["Who are the authors of improvements released in the last six months?", "SELECT DISTINCT Author_name FROM Author INNER JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE Release_date >= DATE_SUB(CURDATE(), INTERVAL 6 MONTH);"],
    ["Which improvements have more than five associated tools?", "SELECT Improve_name FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id GROUP BY Improve_name HAVING COUNT(DISTINCT Tool_id) > 5;"],
    ["List all the descriptions for innovations linked to 'Automation' tasks.", "SELECT Description FROM Jidouka INNER JOIN Job ON Jidouka.Job_id = Job.Id WHERE Job_name = 'Automation';"],
    ["What are the saved hours for improvements in the 'Production' department?", "SELECT Improve_name, Time AS Saved_Hours FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Production';"],
    ["Which innovations have no associated products?", "SELECT Improve_name FROM Jidouka WHERE Product_name IS NULL;"],
    ["What is the formula for Newton's second law of motion?", "Newton's second law of motion is F = m × a, where F is force, m is mass, and a is acceleration."],
    ["How many tasks are linked to the innovation named 'Efficiency Upgrade'?", "SELECT Applications FROM Jidouka WHERE Improve_name = 'Efficiency Upgrade';"],
    ["List the employees who created innovations associated with 'Research Tools'.", "SELECT DISTINCT Author_name FROM Author INNER JOIN Jidouka ON Author.Id = Jidouka.Author_id INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON JidoukaTool.Tool_id = Tool.Id WHERE Tool_name = 'Research Tools';"],
    ["Which departments have innovations launched before 2020?", "SELECT DISTINCT Department_name FROM Department INNER JOIN Jidouka ON Department.Id = Jidouka.Department_id WHERE Release_date < '2020-01-01';"],
    ["What are the outputs of the innovations linked to the 'Quality Control' team?", "SELECT Improve_name, Product_name FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Quality Control';"],
    ["Which innovations have a description that contains the word 'automation'?", "SELECT Improve_name FROM Jidouka WHERE Description LIKE '%automation%';"],
    ["How many hours were saved by the innovation 'Green Packaging'?", "SELECT Time FROM Jidouka WHERE Improve_name = 'Green Packaging';"],
    ["Which tools are not linked to any jidouka improvements?", "SELECT Tool_name FROM Tool LEFT JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id WHERE JidoukaTool.Jidouka_id IS NULL;"],
    ["How do magnets work?", "Magnets work by generating a magnetic field due to the alignment of magnetic domains within their material."],
    ["What are the innovations with the most applications?", "SELECT Improve_name, Applications FROM Jidouka ORDER BY Applications DESC LIMIT 1;"],
    ["Which tools are associated with innovations that saved more than 100 hours?", "SELECT DISTINCT Tool_name FROM Tool INNER JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id INNER JOIN Jidouka ON Jidouka.Id = JidoukaTool.Jidouka_id WHERE Time > 100;"],
    ["List all innovations introduced by 'Jane Smith'.", "SELECT Improve_name FROM Jidouka INNER JOIN Author ON Jidouka.Author_id = Author.Id WHERE Author_name = 'Jane Smith';"],
    ["Which departments have the most employees linked to innovations?", "SELECT Department_name, COUNT(DISTINCT Author.Id) AS Total_Employees FROM Department INNER JOIN Jidouka ON Department.Id = Jidouka.Department_id INNER JOIN Author ON Jidouka.Author_id = Author.Id GROUP BY Department_name ORDER BY Total_Employees DESC;"],
    ["What is the boiling point of water?", "The boiling point of water is 100°C (212°F) at standard atmospheric pressure."],
    ["How many jidouka improvements have exactly three tools linked to them?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id GROUP BY Jidouka.Id HAVING COUNT(DISTINCT Tool_id) = 3;"],
    ["What are the additional documents linked to innovations in the 'Operations' team?", "SELECT Improve_name, Other_info AS Additional_Documents FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Operations';"],
    ["What is the total number of improvements linked to the 'Design Tools'?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON JidoukaTool.Tool_id = Tool.Id WHERE Tool_name = 'Design Tools';"],
    ["List all departments linked to innovations that saved less than 50 hours.", "SELECT DISTINCT Department_name FROM Department INNER JOIN Jidouka ON Department.Id = Jidouka.Department_id WHERE Time < 50;"],
    ["What are the newest innovations in the 'Analytics' department?", "SELECT Improve_name, Release_date FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Analytics' ORDER BY Release_date DESC LIMIT 3;"],
    ["How many improvements have been created in the 'Logistics' team?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Logistics';"],
    ["Which tools are linked to the most jidouka improvements?", "SELECT Tool_name, COUNT(*) AS Total_Usage FROM Tool INNER JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id GROUP BY Tool_name ORDER BY Total_Usage DESC LIMIT 1;"],
    ["What is the atomic number of hydrogen?", "The atomic number of hydrogen is 1."],
    ["Which improvements saved less than 10 hours?", "SELECT Improve_name FROM Jidouka WHERE Time < 10;"],
    ["List the authors of the innovations launched in the 'Engineering' team.", "SELECT DISTINCT Author_name FROM Author INNER JOIN Jidouka ON Author.Id = Jidouka.Author_id INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Engineering';"],
    ["What are the saved hours for innovations introduced before 2021?", "SELECT Improve_name, Time FROM Jidouka WHERE Release_date < '2021-01-01';"],
    ["Which innovations are associated with more than one department?", "SELECT Improve_name FROM Jidouka GROUP BY Improve_name HAVING COUNT(DISTINCT Department_id) > 1;"],
    ["How many tools are linked to the innovation named 'Automation Framework'?", "SELECT COUNT(DISTINCT Tool_id) AS Total_Tools FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id WHERE Improve_name = 'Automation Framework';"],
    ["What is the most common job type associated with jidouka improvements?", "SELECT Job_name, COUNT(*) AS Frequency FROM Job INNER JOIN Jidouka ON Job.Id = Jidouka.Job_id GROUP BY Job_name ORDER BY Frequency DESC LIMIT 1;"],
    ["What are the details of the oldest innovation in the database?", "SELECT * FROM Jidouka ORDER BY Release_date ASC LIMIT 1;"],
    ["What is the total number of hours saved by all innovations?", "SELECT SUM(Time) AS Total_Saved_Hours FROM Jidouka;"],
    ["List the tools used in the 'Development' department.", "SELECT DISTINCT Tool_name FROM Tool INNER JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id INNER JOIN Jidouka ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Development';"],
    ["What are the innovations introduced by 'Team B'?", "SELECT Improve_name FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Team B';"],
    ["Which tools are linked to innovations launched in the last three months?", "SELECT DISTINCT Tool_name FROM Tool INNER JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id INNER JOIN Jidouka ON Jidouka.Id = JidoukaTool.Jidouka_id WHERE Release_date >= DATE_SUB(CURDATE(), INTERVAL 3 MONTH);"],
    ["List all improvements associated with 'Testing Tools'.", "SELECT Improve_name FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON JidoukaTool.Tool_id = Tool.Id WHERE Tool_name = 'Testing Tools';"],
        ["List all authors and the departments they have worked with.", "SELECT Author_name, Department_name FROM Author JOIN Jidouka ON Author.Id = Jidouka.Author_id JOIN Department ON Jidouka.Department_id = Department.Id;"],
    ["Show all improvements launched on a specific date, such as '2023-06-15'.", "SELECT Improve_name FROM Jidouka WHERE Release_date = '2023-06-15';"],
    ["What improvements saved more than 300 hours and have documentation?", "SELECT Improve_name, Other_info FROM Jidouka WHERE Time > 300 AND Other_info IS NOT NULL;"],
    ["List the tools associated with 'Productivity Enhancement'.", "SELECT Tool_name FROM JidoukaTool JOIN Jidouka ON JidoukaTool.Jidouka_id = Jidouka.Id JOIN Tool ON JidoukaTool.Tool_id = Tool.Id WHERE Improve_name = 'Productivity Enhancement';"],
    ["How many hours were saved by the improvement with the most applications?", "SELECT Time FROM Jidouka ORDER BY Applications DESC LIMIT 1;"],
    ["Show the product names of jidoukas with release times before June 2021.", "SELECT Product_name FROM Jidouka WHERE Release_date < '2021-06-01';"],
    ["List all jidoukas related to 'Manufacturing' jobs.", "SELECT Improve_name FROM Jidouka JOIN Job ON Jidouka.Job_id = Job.Id WHERE Job_name LIKE '%Manufacturing%';"],
    ["Which authors created innovations in departments starting with 'Tech'?", "SELECT Author_name FROM Author JOIN Jidouka ON Author.Id = Jidouka.Author_id JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name LIKE 'Tech%';"],
    ["What jidoukas have other info provided?", "SELECT Improve_name, Other_info FROM Jidouka WHERE Other_info IS NOT NULL;"],
    ["How many tools are associated with the improvement 'Process Optimization'?", "SELECT COUNT(Tool_id) FROM JidoukaTool JOIN Jidouka ON JidoukaTool.Jidouka_id = Jidouka.Id WHERE Improve_name = 'Process Optimization';"],
    ["List the number of jidoukas per author.", "SELECT Author_name, COUNT(Jidouka.Id) AS JidoukaCount FROM Author JOIN Jidouka ON Author.Id = Jidouka.Author_id GROUP BY Author_name;"],
    ["What are the release dates of jidoukas that have saved time greater than 400 hours?", "SELECT Release_date FROM Jidouka WHERE Time > 400;"],
    ["Show the departments involved in improvements that use a tool called 'Automated System'.", "SELECT DISTINCT Department_name FROM Department JOIN Jidouka ON Department.Id = Jidouka.Department_id JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id JOIN Tool ON JidoukaTool.Tool_id = Tool.Id WHERE Tool_name = 'Automated System';"],
    ["Which jidoukas have been applied to more than 100 jobs?", "SELECT Improve_name FROM Jidouka WHERE Applications > 100;"],
    ["What innovations are linked to both 'Engineering' and 'Development' departments?", "SELECT Improve_name FROM Jidouka JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name IN ('Engineering', 'Development') GROUP BY Improve_name HAVING COUNT(DISTINCT Department_name) = 2;"],
    ["List the jidoukas by 'Anna Lee' with their product names and release dates.", "SELECT Improve_name, Product_name, Release_date FROM Jidouka JOIN Author ON Jidouka.Author_id = Author.Id WHERE Author_name = 'Anna Lee';"],
    ["How many total jidoukas involve 'Software Development' jobs?", "SELECT COUNT(*) FROM Jidouka JOIN Job ON Jidouka.Job_id = Job.Id WHERE Job_name = 'Software Development';"],
    ["Show improvements that have a tutorial link.", "SELECT Improve_name, Other_info FROM Jidouka WHERE Other_info LIKE '%tutorial%';"],
    ["List all jidoukas and their department names released between 2020 and 2022.", "SELECT Improve_name, Department_name FROM Jidouka JOIN Department ON Jidouka.Department_id = Department.Id WHERE Release_date BETWEEN '2020-01-01' AND '2022-12-31';"],
    ["Which jidoukas involve tools used in more than 10 different jidoukas?", "SELECT Tool_name, COUNT(JidoukaTool.Jidouka_id) AS CountJidoukas FROM Tool JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id GROUP BY Tool_name HAVING CountJidoukas > 10;"],
    ["What improvements were made in collaboration between 'Design' and 'Marketing' teams?", "SELECT Improve_name FROM Jidouka JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name IN ('Design', 'Marketing') GROUP BY Improve_name HAVING COUNT(DISTINCT Department_name) = 2;"],
    ["Who is considered the father of the telephone?", "Alexander Graham Bell is credited with inventing the telephone."],
    ["Show all details for improvements that used more than one tool.", "SELECT * FROM Jidouka JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id GROUP BY Jidouka.Id HAVING COUNT(Tool_id) > 1;"],
    ["Which authors have created innovations applied to exactly 10 tasks?", "SELECT Author_name FROM Author JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE Applications = 10;"],
    ["List improvements with release dates in the past year.", "SELECT Improve_name FROM Jidouka WHERE Release_date >= DATE_SUB(CURDATE(), INTERVAL 1 YEAR);"],
    ["What jidoukas are linked to 'John Adams' and save more than 200 hours?", "SELECT Improve_name FROM Jidouka JOIN Author ON Jidouka.Author_id = Author.Id WHERE Author_name = 'John Adams' AND Time > 200;"],
    ["List departments and their number of associated jidoukas.", "SELECT Department_name, COUNT(Jidouka.Id) AS JidoukaCount FROM Department JOIN Jidouka ON Department.Id = Jidouka.Department_id GROUP BY Department_name;"],
    ["Who are the authors of jidoukas that include 'Machine Learning' as a tool?", "SELECT Author_name FROM Author JOIN Jidouka ON Author.Id = Jidouka.Author_id JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id JOIN Tool ON JidoukaTool.Tool_id = Tool.Id WHERE Tool_name = 'Machine Learning';"],
    ["How many jidoukas were launched in December of any year?", "SELECT COUNT(*) FROM Jidouka WHERE MONTH(Release_date) = 12;"],
    ["What jidoukas have more than 3 associated tools?", "SELECT Improve_name FROM Jidouka JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id GROUP BY Jidouka.Id HAVING COUNT(Tool_id) > 3;"],
    ["List all improvements authored by 'Lisa Brown' in the 'Design' department.", "SELECT Improve_name FROM Jidouka JOIN Author ON Jidouka.Author_id = Author.Id JOIN Department ON Jidouka.Department_id = Department.Id WHERE Author_name = 'Lisa Brown' AND Department_name = 'Design';"],
    ["What innovations are related to the 'Construction' job?", "SELECT Improve_name FROM Jidouka JOIN Job ON Jidouka.Job_id = Job.Id WHERE Job_name = 'Construction';"],
    ["How many authors have created jidoukas with over 100 applications?", "SELECT COUNT(DISTINCT Author.Id) FROM Author JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE Applications > 100;"],
    ["What tools are linked to innovations that save less than 50 hours?", "SELECT Tool_name FROM Tool JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id JOIN Jidouka ON JidoukaTool.Jidouka_id = Jidouka.Id WHERE Time < 50;"],
    ["List all improvements with a product output that includes 'AI'.", "SELECT Improve_name FROM Jidouka WHERE Product_name LIKE '%AI%';"],
    ["Who created 'Improvement Y' and when was it released?", "SELECT Author_name, Release_date FROM Author JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE Improve_name = 'Improvement Y';"],
    ["What departments have jidoukas with descriptions that mention 'automation'?", "SELECT DISTINCT Department_name FROM Department JOIN Jidouka ON Department.Id = Jidouka.Department_id WHERE Description LIKE '%automation%';"],
    ["Show all jidoukas released in January across any year.", "SELECT Improve_name FROM Jidouka WHERE MONTH(Release_date) = 1;"],
    ["List tools that are associated with more than one author.", "SELECT Tool_name FROM Tool JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id JOIN Jidouka ON JidoukaTool.Jidouka_id = Jidouka.Id GROUP BY Tool_name HAVING COUNT(DISTINCT Jidouka.Author_id) > 1;"],
    ["How many jidoukas have saved between 100 and 300 hours?", "SELECT COUNT(*) FROM Jidouka WHERE Time BETWEEN 100 AND 300;"],
    ["Which jidoukas have a release date on the last day of any month?", "SELECT Improve_name FROM Jidouka WHERE DAY(Release_date) = DAY(LAST_DAY(Release_date));"],
    ["List all innovations created by authors whose names start with 'J'.", "SELECT Improve_name FROM Jidouka JOIN Author ON Jidouka.Author_id = Author.Id WHERE Author_name LIKE 'J%';"],
    ["Who has authored the most jidoukas?", "SELECT Author_name FROM Author JOIN Jidouka ON Author.Id = Jidouka.Author_id GROUP BY Author_name ORDER BY COUNT(Jidouka.Id) DESC LIMIT 1;"],
    ["Show all jidoukas linked to the 'IT' department.", "SELECT Improve_name FROM Jidouka JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'IT';"],
    ["What tools are not linked to any jidoukas?", "SELECT Tool_name FROM Tool WHERE Id NOT IN (SELECT Tool_id FROM JidoukaTool);"],
    ["Show the jidoukas created after 2021 that are associated with 'Innovation Hub'.", "SELECT Improve_name FROM Jidouka JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Innovation Hub' AND Release_date > '2021-01-01';"],
    ["Which jidouka improvements have no associated department?", "SELECT Improve_name FROM Jidouka WHERE Department_id IS NULL;"],
    ["What is the release time of innovations associated with 'Software Development'?", "SELECT Improve_name, Release_date FROM Jidouka INNER JOIN Job ON Jidouka.Job_id = Job.Id WHERE Job_name = 'Software Development';"],
    ["How many innovations have descriptions mentioning 'automation'?", "SELECT COUNT(*) AS Total_Innovations FROM Jidouka WHERE Description LIKE '%automation%';"],
    ["List the top 5 innovations with the most applications.", "SELECT Improve_name, Applications FROM Jidouka ORDER BY Applications DESC LIMIT 5;"],
    ["Who are the creators of improvements that saved over 500 hours?", "SELECT DISTINCT Author_name FROM Author INNER JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE Time > 500;"],
    ["Which tools are associated with jidouka improvements that have no products?", "SELECT DISTINCT Tool_name FROM Tool INNER JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id INNER JOIN Jidouka ON Jidouka.Id = JidoukaTool.Jidouka_id WHERE Product_name IS NULL;"],
    ["How many innovations were launched in 2023?", "SELECT COUNT(*) AS Total_Innovations FROM Jidouka WHERE YEAR(Release_date) = 2023;"],
    ["What is the main purpose of an operating system?", "An operating system manages computer hardware and software resources and provides common services for computer programs."],
    ["List the innovations associated with more than 10 jobs.", "SELECT Improve_name FROM Jidouka WHERE Applications > 10;"],
    ["What is the total number of saved hours across all improvements in the 'HR' department?", "SELECT SUM(Time) AS Total_Saved_Hours FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'HR';"],
    ["Which improvements have a description containing the word 'optimization'?", "SELECT Improve_name FROM Jidouka WHERE Description LIKE '%optimization%';"],
    ["List all tools that are not associated with any jidouka improvement.", "SELECT Tool_name FROM Tool LEFT JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id WHERE JidoukaTool.Jidouka_id IS NULL;"],
    ["Who is the author of the innovation with the highest number of applications?", "SELECT Author_name FROM Author INNER JOIN Jidouka ON Author.Id = Jidouka.Author_id ORDER BY Applications DESC LIMIT 1;"],
    ["What are the top 3 improvements with the longest saved hours?", "SELECT Improve_name, Time FROM Jidouka ORDER BY Time DESC LIMIT 3;"],
    ["What is the most innovative team in the company?", "SELECT Department_name, COUNT(*) AS Total_Innovations FROM Department INNER JOIN Jidouka ON Department.Id = Jidouka.Department_id GROUP BY Department_name ORDER BY Total_Innovations DESC LIMIT 1;"],
    ["What are the outputs of innovations in the 'Design' department?", "SELECT Product_name FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Design';"],
    ["List all jidouka improvements linked to 'Efficiency Tools'.", "SELECT Improve_name FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON JidoukaTool.Tool_id = Tool.Id WHERE Tool_name = 'Efficiency Tools';"],
    ["Which jidouka improvements were launched after 2022?", "SELECT Improve_name FROM Jidouka WHERE Release_date > '2022-12-31';"],
    ["What are the most commonly used tools across all jidouka improvements?", "SELECT Tool_name, COUNT(*) AS Usage FROM Tool INNER JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id GROUP BY Tool_name ORDER BY Usage DESC;"],
    ["What is the purpose of a firewall?", "A firewall is a security system designed to monitor and control incoming and outgoing network traffic based on predetermined security rules."],
    ["How many jidouka improvements have been created by 'Alice Johnson'?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka INNER JOIN Author ON Jidouka.Author_id = Author.Id WHERE Author_name = 'Alice Johnson';"],
    ["What is the oldest innovation in the 'Supply Chain' team?", "SELECT Improve_name, Release_date FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Supply Chain' ORDER BY Release_date ASC LIMIT 1;"],
    ["Which jidouka improvements have no additional documents?", "SELECT Improve_name FROM Jidouka WHERE Other_info IS NULL;"],
    ["List all tools used by the 'R&D' department.", "SELECT DISTINCT Tool_name FROM Tool INNER JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id INNER JOIN Jidouka ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'R&D';"],
    ["What are the jidouka improvements with applications greater than 15?", "SELECT Improve_name FROM Jidouka WHERE Applications > 15;"],
    ["Who are the creators of the jidouka improvements launched before 2020?", "SELECT DISTINCT Author_name FROM Author INNER JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE Release_date < '2020-01-01';"],
    ["What is the release time of the most recent innovation?", "SELECT Improve_name, Release_date FROM Jidouka ORDER BY Release_date DESC LIMIT 1;"],
    ["What is the total number of tools used by all jidouka improvements?", "SELECT COUNT(DISTINCT Tool_id) AS Total_Tools FROM JidoukaTool;"],
    ["List all jidouka improvements in the 'Testing' department.", "SELECT Improve_name FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Testing';"],
    ["Which jidouka improvements are linked to the most departments?", "SELECT Improve_name FROM Jidouka GROUP BY Improve_name HAVING COUNT(DISTINCT Department_id) = (SELECT MAX(Count_Departments) FROM (SELECT Improve_name, COUNT(DISTINCT Department_id) AS Count_Departments FROM Jidouka GROUP BY Improve_name) AS Temp);"],
    ["How do jet engines work?", "Jet engines work by compressing air, mixing it with fuel, and igniting the mixture to produce thrust through high-speed exhaust gases."],
    ["Which jidouka improvements have saved less than 20 hours?", "SELECT Improve_name FROM Jidouka WHERE Time < 20;"],
    ["What is the total number of jidouka improvements created in the 'Marketing' department?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Marketing';"],
    ["What are the most recent innovations in the 'Analytics' team?", "SELECT Improve_name, Release_date FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Analytics' ORDER BY Release_date DESC LIMIT 3;"],
    ["How many improvements are associated with 'Logistics' tasks?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka INNER JOIN Job ON Jidouka.Job_id = Job.Id WHERE Job_name = 'Logistics';"],
    ["What is the atomic weight of helium?", "The atomic weight of helium is approximately 4.0026 u."],
    ["List all jidouka improvements with the keyword 'green' in their description.", "SELECT Improve_name FROM Jidouka WHERE Description LIKE '%green%';"],
    ["What is the average number of applications per jidouka improvement?", "SELECT AVG(Applications) AS Average_Applications FROM Jidouka;"],
    ["Which tools are linked to jidouka improvements launched within the last year?", "SELECT DISTINCT Tool_name FROM Tool INNER JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id INNER JOIN Jidouka ON Jidouka.Id = JidoukaTool.Jidouka_id WHERE Release_date >= DATE_SUB(CURDATE(), INTERVAL 1 YEAR);"],
    ["What are the top 3 tools used in jidouka improvements?", "SELECT Tool_name, COUNT(*) AS Usage FROM Tool INNER JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id GROUP BY Tool_name ORDER BY Usage DESC LIMIT 3;"],
    ["How many jidouka improvements were created by authors in the 'Finance' team?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka INNER JOIN Author ON Jidouka.Author_id = Author.Id INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Finance';"],
    ["Which jidouka improvements are linked to the 'Automation' job type?", "SELECT Improve_name FROM Jidouka INNER JOIN Job ON Jidouka.Job_id = Job.Id WHERE Job_name = 'Automation';"],
    ["What is the purpose of an IP address?", "An IP address identifies devices on a network and allows communication between them by providing location and identification information."],
    ["What is the most recent jidouka improvement launched in the 'Quality Control' team?", "SELECT Improve_name, Release_date FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Quality Control' ORDER BY Release_date DESC LIMIT 1;"],
    ["Which jidouka improvements have additional documents or tutorials?", "SELECT Improve_name FROM Jidouka WHERE Other_info IS NOT NULL;"],
    ["List all improvements associated with the 'Web Development' team.", "SELECT Improve_name FROM Jidouka INNER JOIN Job ON Jidouka.Job_id = Job.Id WHERE Job_name = 'Web Development';"],
    ["What is the primary function of a CPU?", "The primary function of a CPU is to process instructions, perform calculations, and manage data flow in a computer."],
    ["What are the saved hours for jidoukas related to 'Automated Processing'?", "SELECT Time FROM Jidouka WHERE Improve_name = 'Automated Processing';"],
    ["List authors who have worked with more than 5 departments.", "SELECT Author_name FROM Author JOIN Jidouka ON Author.Id = Jidouka.Author_id JOIN Department ON Jidouka.Department_id = Department.Id GROUP BY Author_name HAVING COUNT(DISTINCT Department_name) > 5;"],
    ["Which improvements were released by 'David Smith' with fewer than 50 applications?", "SELECT Improve_name FROM Jidouka JOIN Author ON Jidouka.Author_id = Author.Id WHERE Author_name = 'David Smith' AND Applications < 50;"],
    ["Show all tools linked to jidoukas launched in 2023.", "SELECT Tool_name FROM Tool JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id JOIN Jidouka ON JidoukaTool.Jidouka_id = Jidouka.Id WHERE YEAR(Release_date) = 2023;"],
    ["Which jidoukas have descriptions mentioning 'efficiency'?", "SELECT Improve_name FROM Jidouka WHERE Description LIKE '%efficiency%';"],
    ["What improvements did 'Sarah Johnson' create that are used in more than 200 jobs?", "SELECT Improve_name FROM Jidouka JOIN Author ON Jidouka.Author_id = Author.Id WHERE Author_name = 'Sarah Johnson' AND Applications > 200;"],
    ["List all improvements by 'Marketing' department that save less than 100 hours.", "SELECT Improve_name FROM Jidouka JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Marketing' AND Time < 100;"],
    ["How many jidoukas were released on a Friday?", "SELECT COUNT(*) FROM Jidouka WHERE DAYOFWEEK(Release_date) = 6;"],
    ["List tools used by 'Emma Roberts' in her innovations.", "SELECT Tool_name FROM Tool JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id JOIN Jidouka ON Jidouka.Id = JidoukaTool.Jidouka_id JOIN Author ON Jidouka.Author_id = Author.Id WHERE Author_name = 'Emma Roberts';"],
    ["Which jidoukas are associated with products named 'GreenTech Solution'?", "SELECT Improve_name FROM Jidouka WHERE Product_name = 'GreenTech Solution';"],
    ["List all departments with jidoukas that have more than 10 applications.", "SELECT Department_name FROM Department JOIN Jidouka ON Department.Id = Jidouka.Department_id WHERE Applications > 10;"],
    ["What is the number of jidoukas related to 'Logistics' jobs?", "SELECT COUNT(*) FROM Jidouka JOIN Job ON Jidouka.Job_id = Job.Id WHERE Job_name = 'Logistics';"],
    ["Show improvements that were created by more than one author.", "SELECT Improve_name FROM Jidouka JOIN Author ON Jidouka.Author_id = Author.Id GROUP BY Improve_name HAVING COUNT(DISTINCT Author.Id) > 1;"],
    ["Which authors have created jidoukas released after July 2022?", "SELECT Author_name FROM Author JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE Release_date > '2022-07-01';"],
    ["List jidoukas associated with 'Research and Development' departments.", "SELECT Improve_name FROM Jidouka JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Research and Development';"],
    ["What are the tools linked to jidoukas that have saved more than 500 hours?", "SELECT Tool_name FROM Tool JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id JOIN Jidouka ON JidoukaTool.Jidouka_id = Jidouka.Id WHERE Time > 500;"],
    ["List all jidoukas with release dates that fall on public holidays.", "I am not sure which dates in your region are public holidays."],
    ["Who created improvements linked to 'AI'?", "SELECT Author_name FROM Author JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE Product_name LIKE '%AI%';"],
    ["How many jidoukas have descriptions that include 'prototype'?", "SELECT COUNT(*) FROM Jidouka WHERE Description LIKE '%prototype%';"],
    ["Which tools are involved in the most jidoukas?", "SELECT Tool_name FROM Tool JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id GROUP BY Tool_name ORDER BY COUNT(JidoukaTool.Jidouka_id) DESC LIMIT 1;"],
    ["Show the improvements and associated tools launched in 2024.", "SELECT Improve_name, Tool_name FROM Jidouka JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id JOIN Tool ON JidoukaTool.Tool_id = Tool.Id WHERE YEAR(Release_date) = 2024;"],
    ["List all authors whose jidoukas have been used in exactly 15 applications.", "SELECT Author_name FROM Author JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE Applications = 15;"],
    ["What is the product name of the jidouka created by 'Kevin Adams'?", "SELECT Product_name FROM Jidouka JOIN Author ON Jidouka.Author_id = Author.Id WHERE Author_name = 'Kevin Adams';"],
    ["Which jidoukas were created by teams with 'Development' in their name?", "SELECT Improve_name FROM Jidouka JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name LIKE '%Development%';"],
    ["How many authors have innovations with saved time between 200 and 300 hours?", "SELECT COUNT(DISTINCT Author.Id) FROM Author JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE Time BETWEEN 200 AND 300;"],
    ["List jidoukas with a description that includes 'testing phase'.", "SELECT Improve_name FROM Jidouka WHERE Description LIKE '%testing phase%';"],
    ["What is the release year of the jidouka 'Project X'?", "SELECT YEAR(Release_date) FROM Jidouka WHERE Improve_name = 'Project X';"],
    ["Show all jidoukas by authors with last names starting with 'C'.", "SELECT Improve_name FROM Jidouka JOIN Author ON Jidouka.Author_id = Author.Id WHERE Author_name LIKE '% C%';"],
    ["What jidoukas have a product name longer than 20 characters?", "SELECT Improve_name FROM Jidouka WHERE LENGTH(Product_name) > 20;"],
    ["Which improvements are linked to tools related to 'automation'?", "SELECT Improve_name FROM Jidouka JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id JOIN Tool ON JidoukaTool.Tool_id = Tool.Id WHERE Tool_name LIKE '%automation%';"],
    ["List the departments that have jidoukas saving more than 250 hours.", "SELECT DISTINCT Department_name FROM Department JOIN Jidouka ON Department.Id = Jidouka.Department_id WHERE Time > 250;"],
    ["Who authored innovations released on weekends?", "SELECT Author_name FROM Author JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE DAYOFWEEK(Release_date) IN (1, 7);"],
    ["Show the total number of hours saved by jidoukas in the 'Finance' department.", "SELECT SUM(Time) FROM Jidouka JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Finance';"],
    ["What is the earliest release date of any jidouka?", "SELECT MIN(Release_date) FROM Jidouka;"],
    ["List all tools that have not been used in any jidoukas created before 2020.", "SELECT Tool_name FROM Tool WHERE Id NOT IN (SELECT Tool_id FROM JidoukaTool JOIN Jidouka ON JidoukaTool.Jidouka_id = Jidouka.Id WHERE Release_date < '2020-01-01');"],
    ["What jidoukas are associated with tools that have 'AI' in their name?", "SELECT Improve_name FROM Jidouka JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id JOIN Tool ON JidoukaTool.Tool_id = Tool.Id WHERE Tool_name LIKE '%AI%';"],
    ["Which authors have innovations with 'Prototype' in the description?", "SELECT Author_name FROM Author JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE Description LIKE '%Prototype%';"],
    ["List jidoukas where the product name starts with 'Eco'.", "SELECT Improve_name FROM Jidouka WHERE Product_name LIKE 'Eco%';"],
    ["What jidoukas are associated with authors working in more than one department?", "SELECT Improve_name FROM Jidouka JOIN Author ON Jidouka.Author_id = Author.Id JOIN Department ON Jidouka.Department_id = Department.Id GROUP BY Author.Id, Improve_name HAVING COUNT(DISTINCT Department_name) > 1;"],
    ["Show all jidoukas launched on February 29th.", "SELECT Improve_name FROM Jidouka WHERE DAY(Release_date) = 29 AND MONTH(Release_date) = 2;"],
    ["Which tools were last used in jidoukas in 2022?", "SELECT Tool_name FROM Tool JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id JOIN Jidouka ON JidoukaTool.Jidouka_id = Jidouka.Id WHERE YEAR(Release_date) = 2022 ORDER BY Release_date DESC LIMIT 1;"],
    ["What departments have no jidoukas released yet?", "SELECT Department_name FROM Department WHERE Id NOT IN (SELECT Department_id FROM Jidouka);"],
    ["List all jidoukas with saved time greater than 50 but linked to only one tool.", "SELECT Improve_name FROM Jidouka JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id GROUP BY Jidouka.Id HAVING Time > 50 AND COUNT(DISTINCT JidoukaTool.Tool_id) = 1;"],
    ["What is the most common release year for jidoukas?", "SELECT YEAR(Release_date) AS ReleaseYear, COUNT(*) AS Count FROM Jidouka GROUP BY ReleaseYear ORDER BY Count DESC LIMIT 1;"],
    ["Show jidoukas created by authors whose names include 'Lee'.", "SELECT Improve_name FROM Jidouka JOIN Author ON Jidouka.Author_id = Author.Id WHERE Author_name LIKE '%Lee%';"],
    ["List the jidoukas with applications in the range of 10-20.", "SELECT Improve_name FROM Jidouka WHERE Applications BETWEEN 10 AND 20;"],
    ["What is the average number of applications for jidoukas in the 'Engineering' department?", "SELECT AVG(Applications) FROM Jidouka JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Engineering';"],
    ["List all improvements with 'Green' in their product name.", "SELECT Improve_name FROM Jidouka WHERE Product_name LIKE '%Green%';"],
    ["Who are the authors of jidoukas released in December?", "SELECT Author_name FROM Author JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE MONTH(Release_date) = 12;"],
    ["Show jidoukas related to jobs that involve 'Design'.", "SELECT Improve_name FROM Jidouka JOIN Job ON Jidouka.Job_id = Job.Id WHERE Job_name LIKE '%Design%';"],
    ["Which tools are used in jidoukas released before 2018?", "SELECT DISTINCT Tool_name FROM Tool JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id JOIN Jidouka ON JidoukaTool.Jidouka_id = Jidouka.Id WHERE Release_date < '2018-01-01';"],
    ["List the jidoukas that do not have any associated department.", "SELECT Improve_name FROM Jidouka WHERE Department_id IS NULL;"],
    ["Which jidoukas have been used in exactly 5 jobs?", "SELECT Improve_name FROM Jidouka WHERE Applications = 5;"],
    ["How many jidoukas were released by 'John White'?", "SELECT COUNT(*) FROM Jidouka JOIN Author ON Jidouka.Author_id = Author.Id WHERE Author_name = 'John White';"],
    ["Show jidoukas with descriptions that do not contain the word 'automated'.", "SELECT Improve_name FROM Jidouka WHERE Description NOT LIKE '%automated%';"],
    ["What is the maximum number of applications a single jidouka has been used for?", "SELECT MAX(Applications) FROM Jidouka;"],
    ["List jidoukas whose release date falls on a Monday.", "SELECT Improve_name FROM Jidouka WHERE DAYOFWEEK(Release_date) = 2;"],
    ["Show all departments linked to jidoukas launched in Q2 of any year.", "SELECT DISTINCT Department_name FROM Department JOIN Jidouka ON Department.Id = Jidouka.Department_id WHERE MONTH(Release_date) IN (4, 5, 6);"],
    ["What jidoukas were authored by 'Amy Wong' that have saved over 100 hours?", "SELECT Improve_name FROM Jidouka JOIN Author ON Jidouka.Author_id = Author.Id WHERE Author_name = 'Amy Wong' AND Time > 100;"],
    ["List improvements associated with 'Product Innovation' jobs.", "SELECT Improve_name FROM Jidouka JOIN Job ON Jidouka.Job_id = Job.Id WHERE Job_name = 'Product Innovation';"],
    ["Which jidoukas were released in 2020 and have a description with 'prototype'?", "SELECT Improve_name FROM Jidouka WHERE YEAR(Release_date) = 2020 AND Description LIKE '%prototype%';"],
    ["What tools are linked to jidoukas with release dates in March?", "SELECT DISTINCT Tool_name FROM Tool JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id JOIN Jidouka ON JidoukaTool.Jidouka_id = Jidouka.Id WHERE MONTH(Release_date) = 3;"],
    ["Who authored the jidoukas that are used in more than 30 jobs?", "SELECT DISTINCT Author_name FROM Author JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE Applications > 30;"],
    ["Show all jidoukas that do not have associated tools.", "SELECT Improve_name FROM Jidouka WHERE Id NOT IN (SELECT Jidouka_id FROM JidoukaTool);"],
    ["What jidoukas were released by departments starting with 'T'?", "SELECT Improve_name FROM Jidouka JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name LIKE 'T%';"],
    ["List tools used by jidoukas with 'Innovation' in their description.", "SELECT DISTINCT Tool_name FROM Tool JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id JOIN Jidouka ON JidoukaTool.Jidouka_id = Jidouka.Id WHERE Jidouka.Description LIKE '%Innovation%';"],
    ["How many jidoukas are there with release dates on weekends?", "SELECT COUNT(*) FROM Jidouka WHERE DAYOFWEEK(Release_date) IN (1, 7);"],
    ["List all departments whose jidoukas saved between 150 and 300 hours.", "SELECT DISTINCT Department_name FROM Department JOIN Jidouka ON Department.Id = Jidouka.Department_id WHERE Time BETWEEN 150 AND 300;"],
    ["What jidoukas were authored by 'Chris Evans' and launched in 2021?", "SELECT Improve_name FROM Jidouka JOIN Author ON Jidouka.Author_id = Author.Id WHERE Author_name = 'Chris Evans' AND YEAR(Release_date) = 2021;"],
    ["Which jidoukas have 'guide' in their Other_info?", "SELECT Improve_name FROM Jidouka WHERE Other_info LIKE '%guide%';"],
    ["List all jidoukas that have more than 500 applications.", "SELECT Improve_name FROM Jidouka WHERE Applications > 500;"],
    ["What is the shortest description length of any jidouka?", "SELECT MIN(LENGTH(Description)) FROM Jidouka;"],
    ["Show jidoukas with product names ending in 'Tech'.", "SELECT Improve_name FROM Jidouka WHERE Product_name LIKE '%Tech';"],
    ["List authors who created jidoukas without any Other_info.", "SELECT Author_name FROM Author JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE Other_info IS NULL;"],
    ["What jidoukas were launched in odd-numbered years?", "SELECT Improve_name FROM Jidouka WHERE YEAR(Release_date) % 2 <> 0;"],
    ["Which jidoukas have more applications than the average number of applications?", "SELECT Improve_name FROM Jidouka WHERE Applications > (SELECT AVG(Applications) FROM Jidouka);"],
    ["Show all improvements created by authors with 'son' in their name.", "SELECT Improve_name FROM Jidouka JOIN Author ON Jidouka.Author_id = Author.Id WHERE Author_name LIKE '%son%';"],
    ["List jidoukas released in January that have 'prototype' in their Other_info.", "SELECT Improve_name FROM Jidouka WHERE MONTH(Release_date) = 1 AND Other_info LIKE '%prototype%';"],
    ["What tools are linked to improvements with product names that start with 'Smart'?", "SELECT Tool_name FROM Tool JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id JOIN Jidouka ON JidoukaTool.Jidouka_id = Jidouka.Id WHERE Product_name LIKE 'Smart%';"],
    ["List all jidoukas where saved time is greater than the total number of applications.", "SELECT Improve_name FROM Jidouka WHERE Time > Applications;"],
    ["Which jidoukas were authored by 'Linda Brown' with descriptions containing 'beta'?", "SELECT Improve_name FROM Jidouka JOIN Author ON Jidouka.Author_id = Author.Id WHERE Author_name = 'Linda Brown' AND Description LIKE '%beta%';"],
    ["How many jidoukas have a product name longer than 30 characters?", "SELECT COUNT(*) FROM Jidouka WHERE LENGTH(Product_name) > 30;"],
    ["Show all jidoukas related to 'Development' jobs launched in 2022.", "SELECT Improve_name FROM Jidouka JOIN Job ON Jidouka.Job_id = Job.Id WHERE Job_name LIKE '%Development%' AND YEAR(Release_date) = 2022;"],
    ["List authors who have jidoukas launched on public holidays.", "I am not sure about the specific public holidays in your region."],
    ["What is the total number of applications for jidoukas in the 'Health' department?", "SELECT SUM(Applications) FROM Jidouka JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Health';"],
    ["List jidoukas with release times between 2019 and 2021 that save fewer than 20 hours.", "SELECT Improve_name FROM Jidouka WHERE Release_date BETWEEN '2019-01-01' AND '2021-12-31' AND Time < 20;"],
    ["Show all departments linked to improvements that include 'Eco' in the product name.", "SELECT DISTINCT Department_name FROM Department JOIN Jidouka ON Department.Id = Jidouka.Department_id WHERE Product_name LIKE '%Eco%';"],
    ["Which jidoukas were launched on February 14th?", "SELECT Improve_name FROM Jidouka WHERE MONTH(Release_date) = 2 AND DAY(Release_date) = 14;"],
    ["What jidoukas are associated with tools containing 'Analysis' in their name?", "SELECT Improve_name FROM Jidouka JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id JOIN Tool ON JidoukaTool.Tool_id = Tool.Id WHERE Tool_name LIKE '%Analysis%';"],
    ["How many jidoukas have a release date in Q4 (October to December)?", "SELECT COUNT(*) FROM Jidouka WHERE MONTH(Release_date) BETWEEN 10 AND 12;"],
    ["List improvements whose descriptions start with 'Automated'.", "SELECT Improve_name FROM Jidouka WHERE Description LIKE 'Automated%';"],
    ["Show jidoukas released by the 'Research' department with more than 50 applications.", "SELECT Improve_name FROM Jidouka JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Research' AND Applications > 50;"],
    ["Which jidoukas have descriptions shorter than 50 characters?", "SELECT Improve_name FROM Jidouka WHERE LENGTH(Description) < 50;"],
    ["What is the average number of applications for jidoukas in the 'Engineering' department?", "SELECT AVG(Applications) FROM Jidouka JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Engineering';"],
    ["List all improvements with 'Green' in their product name.", "SELECT Improve_name FROM Jidouka WHERE Product_name LIKE '%Green%';"],
    ["Who are the authors of jidoukas released in December?", "SELECT Author_name FROM Author JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE MONTH(Release_date) = 12;"],
    ["Show jidoukas related to jobs that involve 'Design'.", "SELECT Improve_name FROM Jidouka JOIN Job ON Jidouka.Job_id = Job.Id WHERE Job_name LIKE '%Design%';"],
    ["Which tools are used in jidoukas released before 2018?", "SELECT DISTINCT Tool_name FROM Tool JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id JOIN Jidouka ON JidoukaTool.Jidouka_id = Jidouka.Id WHERE Release_date < '2018-01-01';"],
    ["List the jidoukas that do not have any associated department.", "SELECT Improve_name FROM Jidouka WHERE Department_id IS NULL;"],
    ["Which jidoukas have been used in exactly 5 jobs?", "SELECT Improve_name FROM Jidouka WHERE Applications = 5;"],
    ["How many jidoukas were released by 'John White'?", "SELECT COUNT(*) FROM Jidouka JOIN Author ON Jidouka.Author_id = Author.Id WHERE Author_name = 'John White';"],
    ["Show jidoukas with descriptions that do not contain the word 'automated'.", "SELECT Improve_name FROM Jidouka WHERE Description NOT LIKE '%automated%';"],
    ["What is the maximum number of applications a single jidouka has been used for?", "SELECT MAX(Applications) FROM Jidouka;"],
    ["List jidoukas whose release date falls on a Monday.", "SELECT Improve_name FROM Jidouka WHERE DAYOFWEEK(Release_date) = 2;"],
    ["Show all departments linked to jidoukas launched in Q2 of any year.", "SELECT DISTINCT Department_name FROM Department JOIN Jidouka ON Department.Id = Jidouka.Department_id WHERE MONTH(Release_date) IN (4, 5, 6);"],
    ["What jidoukas were authored by 'Amy Wong' that have saved over 100 hours?", "SELECT Improve_name FROM Jidouka JOIN Author ON Jidouka.Author_id = Author.Id WHERE Author_name = 'Amy Wong' AND Time > 100;"],
    ["List improvements associated with 'Product Innovation' jobs.", "SELECT Improve_name FROM Jidouka JOIN Job ON Jidouka.Job_id = Job.Id WHERE Job_name = 'Product Innovation';"],
    ["Which jidoukas were released in 2020 and have a description with 'prototype'?", "SELECT Improve_name FROM Jidouka WHERE YEAR(Release_date) = 2020 AND Description LIKE '%prototype%';"],
    ["What tools are linked to jidoukas with release dates in March?", "SELECT DISTINCT Tool_name FROM Tool JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id JOIN Jidouka ON JidoukaTool.Jidouka_id = Jidouka.Id WHERE MONTH(Release_date) = 3;"],
    ["Who authored the jidoukas that are used in more than 30 jobs?", "SELECT DISTINCT Author_name FROM Author JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE Applications > 30;"],
    ["Show all jidoukas that do not have associated tools.", "SELECT Improve_name FROM Jidouka WHERE Id NOT IN (SELECT Jidouka_id FROM JidoukaTool);"],
    ["What jidoukas were released by departments starting with 'T'?", "SELECT Improve_name FROM Jidouka JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name LIKE 'T%';"],
    ["List tools used by jidoukas with 'Innovation' in their description.", "SELECT DISTINCT Tool_name FROM Tool JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id JOIN Jidouka ON JidoukaTool.Jidouka_id = Jidouka.Id WHERE Jidouka.Description LIKE '%Innovation%';"],
    ["How many jidoukas are there with release dates on weekends?", "SELECT COUNT(*) FROM Jidouka WHERE DAYOFWEEK(Release_date) IN (1, 7);"],
    ["List all departments whose jidoukas saved between 150 and 300 hours.", "SELECT DISTINCT Department_name FROM Department JOIN Jidouka ON Department.Id = Jidouka.Department_id WHERE Time BETWEEN 150 AND 300;"],
    ["What jidoukas were authored by 'Chris Evans' and launched in 2021?", "SELECT Improve_name FROM Jidouka JOIN Author ON Jidouka.Author_id = Author.Id WHERE Author_name = 'Chris Evans' AND YEAR(Release_date) = 2021;"],
    ["Which jidoukas have 'guide' in their Other_info?", "SELECT Improve_name FROM Jidouka WHERE Other_info LIKE '%guide%';"],
    ["List all jidoukas that have more than 500 applications.", "SELECT Improve_name FROM Jidouka WHERE Applications > 500;"],
    ["What is the shortest description length of any jidouka?", "SELECT MIN(LENGTH(Description)) FROM Jidouka;"],
    ["Show jidoukas with product names ending in 'Tech'.", "SELECT Improve_name FROM Jidouka WHERE Product_name LIKE '%Tech';"],
    ["List authors who created jidoukas without any Other_info.", "SELECT Author_name FROM Author JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE Other_info IS NULL;"],
    ["What jidoukas were launched in odd-numbered years?", "SELECT Improve_name FROM Jidouka WHERE YEAR(Release_date) % 2 <> 0;"],
    ["Which jidoukas have more applications than the average number of applications?", "SELECT Improve_name FROM Jidouka WHERE Applications > (SELECT AVG(Applications) FROM Jidouka);"],
    ["Show all improvements created by authors with 'son' in their name.", "SELECT Improve_name FROM Jidouka JOIN Author ON Jidouka.Author_id = Author.Id WHERE Author_name LIKE '%son%';"],
    ["List jidoukas released in January that have 'prototype' in their Other_info.", "SELECT Improve_name FROM Jidouka WHERE MONTH(Release_date) = 1 AND Other_info LIKE '%prototype%';"],
    ["What tools are linked to improvements with product names that start with 'Smart'?", "SELECT Tool_name FROM Tool JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id JOIN Jidouka ON JidoukaTool.Jidouka_id = Jidouka.Id WHERE Product_name LIKE 'Smart%';"],
    ["List all jidoukas where saved time is greater than the total number of applications.", "SELECT Improve_name FROM Jidouka WHERE Time > Applications;"],
    ["Which jidoukas were authored by 'Linda Brown' with descriptions containing 'beta'?", "SELECT Improve_name FROM Jidouka JOIN Author ON Jidouka.Author_id = Author.Id WHERE Author_name = 'Linda Brown' AND Description LIKE '%beta%';"],
    ["How many jidoukas have a product name longer than 30 characters?", "SELECT COUNT(*) FROM Jidouka WHERE LENGTH(Product_name) > 30;"],
    ["Show all jidoukas related to 'Development' jobs launched in 2022.", "SELECT Improve_name FROM Jidouka JOIN Job ON Jidouka.Job_id = Job.Id WHERE Job_name LIKE '%Development%' AND YEAR(Release_date) = 2022;"],
    ["List authors who have jidoukas launched on public holidays.", "I am not sure about the specific public holidays in your region."],
    ["What is the total number of applications for jidoukas in the 'Health' department?", "SELECT SUM(Applications) FROM Jidouka JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Health';"],
    ["List jidoukas with release times between 2019 and 2021 that save fewer than 20 hours.", "SELECT Improve_name FROM Jidouka WHERE Release_date BETWEEN '2019-01-01' AND '2021-12-31' AND Time < 20;"],
    ["Show all departments linked to improvements that include 'Eco' in the product name.", "SELECT DISTINCT Department_name FROM Department JOIN Jidouka ON Department.Id = Jidouka.Department_id WHERE Product_name LIKE '%Eco%';"],
    ["Which jidoukas were launched on February 14th?", "SELECT Improve_name FROM Jidouka WHERE MONTH(Release_date) = 2 AND DAY(Release_date) = 14;"],
    ["What jidoukas are associated with tools containing 'Analysis' in their name?", "SELECT Improve_name FROM Jidouka JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id JOIN Tool ON JidoukaTool.Tool_id = Tool.Id WHERE Tool_name LIKE '%Analysis%';"],
    ["How many jidoukas have a release date in Q4 (October to December)?", "SELECT COUNT(*) FROM Jidouka WHERE MONTH(Release_date) BETWEEN 10 AND 12;"],
    ["List improvements whose descriptions start with 'Automated'.", "SELECT Improve_name FROM Jidouka WHERE Description LIKE 'Automated%';"],
    ["Show jidoukas released by the 'Research' department with more than 50 applications.", "SELECT Improve_name FROM Jidouka JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Research' AND Applications > 50;"],
    ["Which jidoukas have descriptions shorter than 50 characters?", "SELECT Improve_name FROM Jidouka WHERE LENGTH(Description) < 50;"],
    ["Which jidouka improvements have applications between 5 and 15?", "SELECT Improve_name FROM Jidouka WHERE Applications BETWEEN 5 AND 15;"],
    ["What are the names of tools used by innovations in 'Software Development'?", "SELECT DISTINCT Tool_name FROM Tool INNER JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id INNER JOIN Jidouka ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Job ON Jidouka.Job_id = Job.Id WHERE Job_name = 'Software Development';"],
    ["List all jidouka improvements without saved hours data.", "SELECT Improve_name FROM Jidouka WHERE Time IS NULL;"],
    ["What are the outputs of innovations with descriptions mentioning 'recycling'?", "SELECT Product_name FROM Jidouka WHERE Description LIKE '%recycling%';"],
    ["Which jidouka improvements have been launched after January 1, 2024?", "SELECT Improve_name FROM Jidouka WHERE Release_date > '2024-01-01';"],
    ["What is the primary role of a database index?", "A database index improves the speed of data retrieval operations by providing quick access to rows in a table."],
    ["Who are the creators of innovations linked to 'Automation Tools'?", "SELECT DISTINCT Author_name FROM Author INNER JOIN Jidouka ON Author.Id = Jidouka.Author_id INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON Tool.Id = JidoukaTool.Tool_id WHERE Tool_name = 'Automation Tools';"],
    ["List jidouka improvements linked to at least two tools.", "SELECT Improve_name FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id GROUP BY Improve_name HAVING COUNT(Tool_id) >= 2;"],
    ["Which departments have innovations with saved hours greater than 100?", "SELECT DISTINCT Department_name FROM Department INNER JOIN Jidouka ON Department.Id = Jidouka.Department_id WHERE Time > 100;"],
    ["What are the launch times of all jidouka improvements created by 'John Doe'?", "SELECT Release_date FROM Jidouka INNER JOIN Author ON Jidouka.Author_id = Author.Id WHERE Author_name = 'John Doe';"],
    ["What is the oldest jidouka improvement in the database?", "SELECT Improve_name, Release_date FROM Jidouka ORDER BY Release_date ASC LIMIT 1;"],
    ["How many jidouka improvements are associated with 'Engineering'?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Engineering';"],
    ["List all jidouka improvements related to the 'Testing' job.", "SELECT Improve_name FROM Jidouka INNER JOIN Job ON Jidouka.Job_id = Job.Id WHERE Job_name = 'Testing';"],
    ["What are the jidouka improvements with descriptions containing 'sustainability'?", "SELECT Improve_name FROM Jidouka WHERE Description LIKE '%sustainability%';"],
    ["Who are the authors of the three most recent jidouka improvements?", "SELECT Author_name FROM Author INNER JOIN Jidouka ON Author.Id = Jidouka.Author_id ORDER BY Release_date DESC LIMIT 3;"],
    ["What is the total number of tools used in jidouka improvements linked to the 'Operations' team?", "SELECT COUNT(DISTINCT Tool_id) AS Total_Tools FROM JidoukaTool INNER JOIN Jidouka ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Operations';"],
    ["What are the most frequently used tools in jidouka improvements?", "SELECT Tool_name, COUNT(*) AS Usage FROM Tool INNER JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id GROUP BY Tool_name ORDER BY Usage DESC;"],
    ["List all jidouka improvements without any associated tools.", "SELECT Improve_name FROM Jidouka LEFT JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id WHERE JidoukaTool.Tool_id IS NULL;"],
    ["What are the purposes of an IP address and a subnet mask?", "An IP address identifies devices on a network, while a subnet mask separates the network portion and the host portion of an IP address."],
    ["Which jidouka improvements have saved more than 1,000 hours?", "SELECT Improve_name FROM Jidouka WHERE Time > 1000;"],
    ["What are the descriptions of improvements linked to 'Safety Tools'?", "SELECT Description FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON Tool.Id = JidoukaTool.Tool_id WHERE Tool_name = 'Safety Tools';"],
    ["Who are the creators of jidouka improvements with no additional information?", "SELECT DISTINCT Author_name FROM Author INNER JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE Other_info IS NULL;"],
    ["List the top 3 departments with the highest number of jidouka improvements.", "SELECT Department_name, COUNT(*) AS Total_Innovations FROM Department INNER JOIN Jidouka ON Department.Id = Jidouka.Department_id GROUP BY Department_name ORDER BY Total_Innovations DESC LIMIT 3;"],
    ["Which jidouka improvements were launched in the first quarter of 2024?", "SELECT Improve_name FROM Jidouka WHERE Release_date BETWEEN '2024-01-01' AND '2024-03-31';"],
    ["What are the saved hours of improvements in the 'Analytics' team?", "SELECT Time FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Analytics';"],
    ["Which jidouka improvements have the keyword 'innovation' in their additional information?", "SELECT Improve_name FROM Jidouka WHERE Other_info LIKE '%innovation%';"],
    ["What is the most common job type linked to jidouka improvements?", "SELECT Job_name, COUNT(*) AS Frequency FROM Job INNER JOIN Jidouka ON Job.Id = Jidouka.Job_id GROUP BY Job_name ORDER BY Frequency DESC LIMIT 1;"],
    ["What is the smallest planet in the solar system?", "Mercury is the smallest planet in the solar system."],
    ["How many jidouka improvements were created in the 'Design' team before 2023?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Design' AND Release_date < '2023-01-01';"],
    ["What are the outputs of jidouka improvements linked to 'Quality Control'?", "SELECT Product_name FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Quality Control';"],
    ["Which jidouka improvements have more than 20 applications?", "SELECT Improve_name FROM Jidouka WHERE Applications > 20;"],
    ["What is the average number of saved hours for jidouka improvements?", "SELECT AVG(Time) AS Average_Saved_Hours FROM Jidouka;"],
    ["Who are the authors of jidouka improvements linked to 'Machine Learning Tools'?", "SELECT DISTINCT Author_name FROM Author INNER JOIN Jidouka ON Author.Id = Jidouka.Author_id INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON Tool.Id = JidoukaTool.Tool_id WHERE Tool_name = 'Machine Learning Tools';"],
    ["What is the main function of a compiler?", "A compiler translates high-level programming code into machine-readable code for execution by a computer."],
    ["List all jidouka improvements launched in December.", "SELECT Improve_name FROM Jidouka WHERE MONTH(Release_date) = 12;"],
    ["What is the release time of innovations linked to 'Energy Efficiency' tools?", "SELECT Release_date FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON Tool.Id = JidoukaTool.Tool_id WHERE Tool_name = 'Energy Efficiency';"],
    ["How many jidouka improvements have applications greater than 50?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka WHERE Applications > 50;"],
    ["What is the purpose of a DNS server?", "A DNS server translates domain names into IP addresses, enabling computers to locate and connect to websites or services."],
    ["List the jidouka improvements created by authors in the 'Finance' team.", "SELECT Improve_name FROM Jidouka INNER JOIN Author ON Jidouka.Author_id = Author.Id INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Finance';"],
    ["Which tools are most frequently associated with jidouka improvements?", "SELECT Tool_name, COUNT(*) AS Frequency FROM Tool INNER JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id GROUP BY Tool_name ORDER BY Frequency DESC LIMIT 5;"],
    ["What is the launch time of the jidouka improvement with the longest saved hours?", "SELECT Release_date FROM Jidouka ORDER BY Time DESC LIMIT 1;"],
    ["List all jidouka improvements launched before 2020.", "SELECT Improve_name FROM Jidouka WHERE Release_date < '2020-01-01';"],
    ["What are the outputs of innovations created by 'Jane Smith'?", "SELECT Product_name FROM Jidouka INNER JOIN Author ON Jidouka.Author_id = Author.Id WHERE Author_name = 'Jane Smith';"],
    ["How many jidouka improvements have more than three associated tools?", "SELECT COUNT(DISTINCT Jidouka_id) AS Total_Improvements FROM JidoukaTool GROUP BY Jidouka_id HAVING COUNT(Tool_id) > 3;"],
    ["Which jidouka improvements have descriptions mentioning 'automation'?", "SELECT Improve_name FROM Jidouka WHERE Description LIKE '%automation%';"],
    ["What is the launch time of the most recent jidouka improvement?", "SELECT Release_date FROM Jidouka ORDER BY Release_date DESC LIMIT 1;"],
    ["Which departments have jidouka improvements with more than 10 applications?", "SELECT DISTINCT Department_name FROM Department INNER JOIN Jidouka ON Department.Id = Jidouka.Department_id WHERE Applications > 10;"],
    ["What is the average number of applications for jidouka improvements?", "SELECT AVG(Applications) AS Average_Applications FROM Jidouka;"],
    ["What are the improvements with additional documents or tutorials?", "SELECT Improve_name FROM Jidouka WHERE Other_info IS NOT NULL;"],
    ["List all jidoukas created by authors whose names start with 'M'.", "SELECT Improve_name FROM Jidouka JOIN Author ON Jidouka.Author_id = Author.Id WHERE Author_name LIKE 'M%';"],
    ["Which jidoukas have been used in less than 5 applications?", "SELECT Improve_name FROM Jidouka WHERE Applications < 5;"],
    ["What tools are linked to jidoukas with descriptions containing 'prototype'?", "SELECT DISTINCT Tool_name FROM Tool JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id JOIN Jidouka ON JidoukaTool.Jidouka_id = Jidouka.Id WHERE Description LIKE '%prototype%';"],
    ["List the jidoukas with no saved time mentioned.", "SELECT Improve_name FROM Jidouka WHERE Time IS NULL OR Time = 0;"],
    ["What departments are associated with jidoukas released in the last 6 months?", "SELECT DISTINCT Department_name FROM Department JOIN Jidouka ON Department.Id = Jidouka.Department_id WHERE Release_date >= DATE_SUB(CURDATE(), INTERVAL 6 MONTH);"],
    ["List all jidoukas whose product names include 'AI'.", "SELECT Improve_name FROM Jidouka WHERE Product_name LIKE '%AI%';"],
    ["Which jidoukas have release dates on the 1st of any month?", "SELECT Improve_name FROM Jidouka WHERE DAY(Release_date) = 1;"],
    ["Show authors of jidoukas used in more than 20 applications.", "SELECT DISTINCT Author_name FROM Author JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE Applications > 20;"],
    ["List jidoukas that were launched without any department linked.", "SELECT Improve_name FROM Jidouka WHERE Department_id IS NULL;"],
    ["What jidoukas have product names that are exactly 10 characters long?", "SELECT Improve_name FROM Jidouka WHERE LENGTH(Product_name) = 10;"],
    ["Show all jidoukas with release dates in the future.", "SELECT Improve_name FROM Jidouka WHERE Release_date > CURDATE();"],
    ["List tools linked to jidoukas with descriptions containing 'safety'.", "SELECT DISTINCT Tool_name FROM Tool JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id JOIN Jidouka ON JidoukaTool.Jidouka_id = Jidouka.Id WHERE Description LIKE '%safety%';"],
    ["Which jidoukas were created by authors with last names ending in 'son'?", "SELECT Improve_name FROM Jidouka JOIN Author ON Jidouka.Author_id = Author.Id WHERE Author_name LIKE '%son';"],
    ["List all jidoukas where the product name starts and ends with the same letter.", "SELECT Improve_name FROM Jidouka WHERE LEFT(Product_name, 1) = RIGHT(Product_name, 1);"],
    ["What is the total saved time for all jidoukas in the 'Operations' department?", "SELECT SUM(Time) FROM Jidouka JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Operations';"],
    ["Show jidoukas that have been released on a leap day.", "SELECT Improve_name FROM Jidouka WHERE MONTH(Release_date) = 2 AND DAY(Release_date) = 29;"],
    ["Which jidoukas were launched in the second half of any year?", "SELECT Improve_name FROM Jidouka WHERE MONTH(Release_date) BETWEEN 7 AND 12;"],
    ["List all jidoukas with 'eco' in their product name.", "SELECT Improve_name FROM Jidouka WHERE Product_name LIKE '%eco%';"],
    ["What jidoukas have more than 100 applications but less than 200?", "SELECT Improve_name FROM Jidouka WHERE Applications > 100 AND Applications < 200;"],
    ["Show departments linked to jidoukas released on Fridays.", "SELECT DISTINCT Department_name FROM Department JOIN Jidouka ON Department.Id = Jidouka.Department_id WHERE DAYOFWEEK(Release_date) = 6;"],
    ["List tools linked to jidoukas that have been used in only one application.", "SELECT DISTINCT Tool_name FROM Tool JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id JOIN Jidouka ON JidoukaTool.Jidouka_id = Jidouka.Id WHERE Applications = 1;"],
    ["What jidoukas were launched after their associated author joined?", "I am not sure how to determine when the authors joined."],
    ["Show all jidoukas where the description is longer than the product name.", "SELECT Improve_name FROM Jidouka WHERE LENGTH(Description) > LENGTH(Product_name);"],
    ["List authors who have more than 3 jidoukas with release dates in December.", "SELECT Author_name FROM Author JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE MONTH(Release_date) = 12 GROUP BY Author_name HAVING COUNT(Jidouka.Id) > 3;"],
    ["What jidoukas have a time saved value that is an even number?", "SELECT Improve_name FROM Jidouka WHERE Time % 2 = 0;"],
    ["List all jidoukas with a 'draft' mention in their other information.", "SELECT Improve_name FROM Jidouka WHERE Other_info LIKE '%draft%';"],
    ["What jidoukas have a saved time less than 10 but are associated with multiple tools?", "SELECT Improve_name FROM Jidouka JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id GROUP BY Jidouka.Id HAVING Time < 10 AND COUNT(DISTINCT Tool_id) > 1;"],
    ["List jidoukas released in the first week of any year.", "SELECT Improve_name FROM Jidouka WHERE WEEK(Release_date, 1) = 1;"],
    ["Show the number of jidoukas released in each quarter.", "SELECT CONCAT('Q', QUARTER(Release_date)) AS Quarter, COUNT(*) FROM Jidouka GROUP BY Quarter;"],
    ["Which jidoukas have an 'advanced' in their description and saved over 50 hours?", "SELECT Improve_name FROM Jidouka WHERE Description LIKE '%advanced%' AND Time > 50;"],
    ["List tools used in jidoukas created by 'Sophia Miller'.", "SELECT DISTINCT Tool_name FROM Tool JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id JOIN Jidouka ON JidoukaTool.Jidouka_id = Jidouka.Id JOIN Author ON Jidouka.Author_id = Author.Id WHERE Author_name = 'Sophia Miller';"],
    ["What jidoukas were launched in an even-numbered month?", "SELECT Improve_name FROM Jidouka WHERE MONTH(Release_date) IN (2, 4, 6, 8, 10, 12);"],
    ["Show all jidoukas with applications that are multiples of 10.", "SELECT Improve_name FROM Jidouka WHERE Applications % 10 = 0;"],
    ["List authors who created jidoukas with 'test' in their product name.", "SELECT Author_name FROM Author JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE Product_name LIKE '%test%';"],
    ["Which jidoukas were released by departments whose names contain 'Solutions'?", "SELECT Improve_name FROM Jidouka JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name LIKE '%Solutions%';"],
    ["What jidoukas have descriptions ending with a question mark?", "SELECT Improve_name FROM Jidouka WHERE Description LIKE '%?';"],
    ["List jidoukas with more than 3 linked tools.", "SELECT Improve_name FROM Jidouka JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id GROUP BY Jidouka.Id HAVING COUNT(DISTINCT Tool_id) > 3;"],
    ["Show all jidoukas linked to authors whose names contain a hyphen.", "SELECT Improve_name FROM Jidouka JOIN Author ON Jidouka.Author_id = Author.Id WHERE Author_name LIKE '%-%';"],
    ["What jidoukas have a release date that falls on a national holiday?", "I am not sure about specific national holidays in your region."],
    ["List tools used in jidoukas with descriptions mentioning 'review'.", "SELECT DISTINCT Tool_name FROM Tool JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id JOIN Jidouka ON JidoukaTool.Jidouka_id = Jidouka.Id WHERE Description LIKE '%review%';"],
    ["What jidoukas have product names that start with a vowel?", "SELECT Improve_name FROM Jidouka WHERE Product_name REGEXP '^[AEIOUaeiou]';"],
    ["Show jidoukas linked to the 'Management' department launched before 2020.", "SELECT Improve_name FROM Jidouka JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Management' AND Release_date < '2020-01-01';"],
    ["List all jidoukas where the saved time is greater than the average time saved.", "SELECT Improve_name FROM Jidouka WHERE Time > (SELECT AVG(Time) FROM Jidouka);"],
    ["Which jidoukas have 'guide' in their product name and were launched by 'Mark Thomas'?", "SELECT Improve_name FROM Jidouka JOIN Author ON Jidouka.Author_id = Author.Id WHERE Product_name LIKE '%guide%' AND Author_name = 'Mark Thomas';"],
    ["Show jidoukas with release dates on public holidays.", "I am not sure which dates correspond to public holidays."],
    ["What jidoukas have other information containing 'update'?", "SELECT Improve_name FROM Jidouka WHERE Other_info LIKE '%update%';"],
    ["List all jidoukas with release times in the evening (after 5 PM).", "SELECT Improve_name FROM Jidouka WHERE TIME(Release_date) > '17:00:00';"],
    ["Show jidoukas whose applications count is prime.", "This would require a custom function to determine prime numbers in SQL."],
    ["What jidoukas have descriptions containing both 'prototype' and 'draft'?", "SELECT Improve_name FROM Jidouka WHERE Description LIKE '%prototype%' AND Description LIKE '%draft%';"],
    ["Which jidouka improvements are associated with 'Mechanical Engineering'?", "SELECT Improve_name FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Mechanical Engineering';"],
    ["List all tools linked to innovations created in 2023.", "SELECT DISTINCT Tool_name FROM Tool INNER JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id INNER JOIN Jidouka ON Jidouka.Id = JidoukaTool.Jidouka_id WHERE YEAR(Release_date) = 2023;"],
    ["What are the jidouka improvements with saved hours less than 10?", "SELECT Improve_name FROM Jidouka WHERE Time < 10;"],
    ["Which authors have created improvements with descriptions containing 'automation'?", "SELECT DISTINCT Author_name FROM Author INNER JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE Description LIKE '%automation%';"],
    ["List all jidouka improvements that do not have any product names associated.", "SELECT Improve_name FROM Jidouka WHERE Product_name IS NULL;"],
    ["What are the outputs of innovations created by employees from the 'Human Resources' department?", "SELECT Product_name FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Human Resources';"],
    ["What are the most popular tools associated with jidouka improvements?", "SELECT Tool_name, COUNT(*) AS Usage FROM Tool INNER JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id GROUP BY Tool_name ORDER BY Usage DESC LIMIT 5;"],
    ["Who are the authors of jidouka improvements launched in June?", "SELECT DISTINCT Author_name FROM Author INNER JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE MONTH(Release_date) = 6;"],
    ["What are the applications of jidouka improvements linked to 'Research and Development'?", "SELECT Applications FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Research and Development';"],
    ["Which jidouka improvements have the word 'safety' in their description?", "SELECT Improve_name FROM Jidouka WHERE Description LIKE '%safety%';"],
    ["What is the primary function of an operating system?", "An operating system manages hardware resources and provides services for computer programs."],
    ["Which departments have innovations with saved hours exceeding 50?", "SELECT DISTINCT Department_name FROM Department INNER JOIN Jidouka ON Department.Id = Jidouka.Department_id WHERE Time > 50;"],
    ["List jidouka improvements created by 'Alice Johnson'.", "SELECT Improve_name FROM Jidouka INNER JOIN Author ON Jidouka.Author_id = Author.Id WHERE Author_name = 'Alice Johnson';"],
    ["What is the total number of jidouka improvements with more than 5 tools associated?", "SELECT COUNT(DISTINCT Jidouka_id) AS Total_Improvements FROM JidoukaTool GROUP BY Jidouka_id HAVING COUNT(Tool_id) > 5;"],
    ["What are the outputs of innovations launched before 2022?", "SELECT Product_name FROM Jidouka WHERE Release_date < '2022-01-01';"],
    ["Which jidouka improvements have additional information mentioning 'guide'?", "SELECT Improve_name FROM Jidouka WHERE Other_info LIKE '%guide%';"],
    ["What are the three most recent jidouka improvements in 'Logistics'?", "SELECT Improve_name FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Logistics' ORDER BY Release_date DESC LIMIT 3;"],
    ["How many jidouka improvements were launched in 2021?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka WHERE YEAR(Release_date) = 2021;"],
    ["What are the tools linked to improvements in 'AI Research'?", "SELECT DISTINCT Tool_name FROM Tool INNER JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id INNER JOIN Jidouka ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'AI Research';"],
    ["What is the role of a RAM in a computer system?", "RAM temporarily stores data that the CPU needs to access quickly during processing."],
    ["Which jidouka improvements have more than 3 applications?", "SELECT Improve_name FROM Jidouka WHERE Applications > 3;"],
    ["List all improvements associated with 'Data Analytics' tools.", "SELECT Improve_name FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON Tool.Id = JidoukaTool.Tool_id WHERE Tool_name = 'Data Analytics';"],
    ["What are the saved hours of jidouka improvements created by 'Bob Lee'?", "SELECT Time FROM Jidouka INNER JOIN Author ON Jidouka.Author_id = Author.Id WHERE Author_name = 'Bob Lee';"],
    ["What is the purpose of a network router?", "A router directs data packets between devices in a network, enabling communication and internet access."],
    ["Which jidouka improvements have release dates in the second half of the year?", "SELECT Improve_name FROM Jidouka WHERE MONTH(Release_date) >= 7;"],
    ["What is the average number of saved hours for innovations linked to 'IT Support'?", "SELECT AVG(Time) AS Average_Saved_Hours FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'IT Support';"],
    ["Who are the authors of jidouka improvements that saved more than 200 hours?", "SELECT DISTINCT Author_name FROM Author INNER JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE Time > 200;"],
    ["What are the descriptions of improvements linked to tools for 'Security Monitoring'?", "SELECT Description FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON Tool.Id = JidoukaTool.Tool_id WHERE Tool_name = 'Security Monitoring';"],
    ["How many jidouka improvements have been launched in the past three years?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka WHERE Release_date >= DATE_SUB(NOW(), INTERVAL 3 YEAR);"],
    ["What are the launch dates of innovations with more than 10 applications?", "SELECT Release_date FROM Jidouka WHERE Applications > 10;"],
    ["Which jidouka improvements are linked to 'Cloud Computing Tools'?", "SELECT Improve_name FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON Tool.Id = JidoukaTool.Tool_id WHERE Tool_name = 'Cloud Computing Tools';"],
    ["What is the difference between HTTP and HTTPS?", "HTTPS is a secure version of HTTP, using encryption to protect data transmitted between a client and server."],
    ["List all jidouka improvements without any associated department.", "SELECT Improve_name FROM Jidouka WHERE Department_id IS NULL;"],
    ["What is the most frequently associated department for jidouka improvements?", "SELECT Department_name, COUNT(*) AS Frequency FROM Department INNER JOIN Jidouka ON Department.Id = Jidouka.Department_id GROUP BY Department_name ORDER BY Frequency DESC LIMIT 1;"],
    ["Which jidouka improvements have saved less than 5 hours?", "SELECT Improve_name FROM Jidouka WHERE Time < 5;"],
    ["What are the tools linked to innovations launched in 2020?", "SELECT DISTINCT Tool_name FROM Tool INNER JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id INNER JOIN Jidouka ON Jidouka.Id = JidoukaTool.Jidouka_id WHERE YEAR(Release_date) = 2020;"],
    ["What are the outputs of jidouka improvements created in the 'Healthcare' department?", "SELECT Product_name FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Healthcare';"],
    ["Who created the jidouka improvement with the most applications?", "SELECT Author_name FROM Author INNER JOIN Jidouka ON Author.Id = Jidouka.Author_id ORDER BY Applications DESC LIMIT 1;"],
    ["What is the primary purpose of a firewall?", "A firewall protects a network by filtering incoming and outgoing traffic based on security rules."],
    ["List all improvements linked to 'Robotics' tools.", "SELECT Improve_name FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON Tool.Id = JidoukaTool.Tool_id WHERE Tool_name = 'Robotics';"],
    ["What are the saved hours for innovations with the word 'energy' in their description?", "SELECT Time FROM Jidouka WHERE Description LIKE '%energy%';"],
    ["What are the jidouka improvements created by the 'Project Management' team?", "SELECT Improve_name FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Project Management';"],
    ["How many jidouka improvements have applications exceeding 30?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka WHERE Applications > 30;"],
    ["What is the name of the job with the ID 1?", "SELECT Job_name FROM Job WHERE Id = 1;"],
    ["Who is the creator of the improvement in the department of engineering?", "SELECT Author_name FROM Author JOIN Jidouka ON Author.Id = Jidouka.Author_id JOIN Department ON Department.Id = Jidouka.Department_id WHERE Department.Department_name = 'engineering';"],
    ["What was the release time of the innovation for the job manager?", "SELECT Release_date FROM Jidouka JOIN Job ON Job.Id = Jidouka.Job_id WHERE Job.Job_name = 'manager';"],
    ["How much time was saved by improvements about excel", "SELECT Time FROM Jidouka WHERE Improve_name = 'excel';"],
    ["What is the best way to learn SQL?", "To learn SQL, you can start by reading online tutorials, watching video lessons, and practicing queries using a database management system like MySQL or PostgreSQL."],
    ["Can you tell me the name of the tool used in the innovation with ID 2?", "SELECT Tool_name FROM Tool JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id WHERE JidoukaTool.Jidouka_id = 2;"],
    ["What department does the author named John work in?", "SELECT Department_name FROM Department JOIN Jidouka ON Department.Id = Jidouka.Department_id JOIN Author ON Author.Id = Jidouka.Author_id WHERE Author.Author_name = 'John';"],
    ["Which products have been created by innovations in the job role developer?", "SELECT Product_name FROM Jidouka JOIN Job ON Job.Id = Jidouka.Job_id WHERE Job.Job_name = 'developer';"],
    ["How many job roles apply automation related innovations?", "SELECT Applications FROM Jidouka WHERE Improve_name = 'automation';"],
    ["What are the benefits of using version control?", "Version control allows teams to collaborate efficiently, track changes to code, and manage different versions of a project. It also provides backups and helps avoid conflicts between team members."],
    ["How many tools are linked to the jidouka improvement with ID 3?", "SELECT COUNT(*) FROM JidoukaTool WHERE Jidouka_id = 3;"],
    ["What time was saved by innovations in the product 'AppX'?", "SELECT Time FROM Jidouka WHERE Product_name = 'AppX';"],
    ["What is the application of a 'designer' role?", "SELECT * FROM Job WHERE Job_name = 'designer';"],
    ["Who developed the innovation for the IT department?", "SELECT Author_name FROM Author JOIN Jidouka ON Author.Id = Jidouka.Author_id JOIN Department ON Department.Id = Jidouka.Department_id WHERE Department.Department_name = 'IT';"],
    ["Can you tell me about the description of improvement number 5?", "SELECT Description FROM Jidouka WHERE Id = 5;"],
    ["What does the department HR focus on?", "HR, or Human Resources, focuses on recruitment, employee relations, compensation, and benefits management."],
    ["Which tool is most frequently used in innovations?", "SELECT Tool_name FROM Tool JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id GROUP BY Tool_name ORDER BY COUNT(*) DESC LIMIT 1;"],
    ["What are the launch times for innovations in 2023?", "SELECT Release_date FROM Jidouka WHERE YEAR(Release_date) = 2023;"],
    ["What is a good strategy to increase productivity?", "Focus on task prioritization, minimize distractions, and use productivity tools such as task managers or time tracking apps."],
    ["What is the total number of applications for innovations in 'marketing'?", "SELECT Applications FROM Jidouka JOIN Job ON Job.Id = Jidouka.Job_id WHERE Job.Job_name = 'marketing';"],
    ["Which improvements are linked with the job role 'developer'?", "SELECT Improve_name FROM Jidouka JOIN Job ON Job.Id = Jidouka.Job_id WHERE Job.Job_name = 'developer';"],
    ["What is the purpose of using version control in projects?", "Version control helps manage changes to documents, code, and other collections of information in a structured way. It allows developers to track revisions and collaborate without interfering with each other."],
    ["What department is associated with innovation ID 7?", "SELECT Department_name FROM Department JOIN Jidouka ON Department.Id = Jidouka.Department_id WHERE Jidouka.Id = 7;"],
    ["How many innovations were released in 2022?", "SELECT COUNT(*) FROM Jidouka WHERE YEAR(Release_date) = 2022;"],
    ["Can you tell me the tools used for improvement in department 'design'?", "SELECT Tool_name FROM Tool JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id JOIN Jidouka ON JidoukaTool.Jidouka_id = Jidouka.Id JOIN Department ON Department.Id = Jidouka.Department_id WHERE Department.Department_name = 'design';"],
    ["What job type is related to tool 'AutoCAD'?", "SELECT Job_name FROM Job JOIN Jidouka ON Job.Id = Jidouka.Job_id JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id JOIN Tool ON JidoukaTool.Tool_id = Tool.Id WHERE Tool.Tool_name = 'AutoCAD';"],
    ["What is the ID of the author who wrote the improvement in 'sales'?", "SELECT Author_id FROM Jidouka JOIN Department ON Department.Id = Jidouka.Department_id WHERE Department.Department_name = 'sales';"],
    ["What is the main task of the department called 'R&D'?", "R&D, or Research and Development, focuses on researching new technologies, products, or services and developing them for commercial or internal use."],
    ["Which improvements were launched by author 'Alice'?", "SELECT Improve_name FROM Jidouka JOIN Author ON Author.Id = Jidouka.Author_id WHERE Author.Author_name = 'Alice';"],
    ["What is the description of innovation ID 4?", "SELECT Description FROM Jidouka WHERE Id = 4;"],
    ["How many hours were saved by innovation for task 'QA'?", "SELECT Time FROM Jidouka JOIN Job ON Job.Id = Jidouka.Job_id WHERE Job.Job_name = 'QA';"],
    ["What tools are used in the job role 'tester'?", "SELECT Tool_name FROM Tool JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id JOIN Jidouka ON JidoukaTool.Jidouka_id = Jidouka.Id JOIN Job ON Job.Id = Jidouka.Job_id WHERE Job.Job_name = 'tester';"],
    ["How does innovation impact job productivity?", "Innovation can streamline processes, reduce redundancy, and introduce automation, leading to increased productivity."],
    ["What is the date of the first innovation release?", "SELECT MIN(Release_date) FROM Jidouka;"],
    ["Which tool supports innovation in the development department?", "SELECT Tool_name FROM Tool JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id JOIN Jidouka ON JidoukaTool.Jidouka_id = Jidouka.Id JOIN Department ON Department.Id = Jidouka.Department_id WHERE Department.Department_name = 'development';"],
    ["Who is the author of the innovation that improved customer service?", "SELECT Author_name FROM Author JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE Jidouka.Improve_name = 'customer service';"],
    ["What is a recommended method for improving team communication?", "Consider implementing collaborative tools like Slack, Trello, or Microsoft Teams, and ensure regular check-ins for feedback and updates."],
    ["Can you list all innovations for the 'HR' department?", "SELECT Improve_name FROM Jidouka JOIN Department ON Department.Id = Jidouka.Department_id WHERE Department.Department_name = 'HR';"],
    ["What is the relationship between a job and an innovation?", "Job roles can be associated with specific innovations that improve their workflow, processes, or outputs. The relationship is captured in the Jidouka table, linking jobs with innovations."],
    ["How many different jobs apply database innovation?", "SELECT COUNT(DISTINCT Job_id) FROM Jidouka WHERE Improve_name = 'database';"],
    ["Can you tell me how much time was saved by the marketing department's improvement?", "SELECT Time FROM Jidouka JOIN Department ON Department.Id = Jidouka.Department_id WHERE Department.Department_name = 'marketing';"],
    ["How many tools are associated with the innovation 'automation'?", "SELECT COUNT(*) FROM JidoukaTool JOIN Jidouka ON JidoukaTool.Jidouka_id = Jidouka.Id WHERE Jidouka.Improve_name = 'automation';"],
    ["What are the key benefits of continuous learning in a job role?", "Continuous learning helps employees adapt to new technologies, stay competitive, and improve their performance in their roles."],
    ["What tools did the 'engineering' department use for innovations?", "SELECT Tool_name FROM Tool JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id JOIN Jidouka ON JidoukaTool.Jidouka_id = Jidouka.Id JOIN Department ON Department.Id = Jidouka.Department_id WHERE Department.Department_name = 'engineering';"],
    ["Which jidouka improvements have the highest number of applications?", "SELECT Improve_name FROM Jidouka ORDER BY Applications DESC LIMIT 1;"],
    ["List all tools used in jidouka improvements related to 'Artificial Intelligence'.", "SELECT Tool_name FROM Tool INNER JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id INNER JOIN Jidouka ON Jidouka.Id = JidoukaTool.Jidouka_id WHERE Jidouka.Description LIKE '%Artificial Intelligence%';"],
    ["What are the descriptions of jidouka improvements with more than 100 saved hours?", "SELECT Description FROM Jidouka WHERE Time > 100;"],
    ["Which jidouka improvements were created by authors from 'Marketing' department?", "SELECT Improve_name FROM Jidouka INNER JOIN Author ON Jidouka.Author_id = Author.Id INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Marketing';"],
    ["What is the average saved time for jidouka improvements in the 'Operations' department?", "SELECT AVG(Time) AS Average_Saved_Time FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Operations';"],
    ["Which jidouka improvements were launched in the first quarter of 2022?", "SELECT Improve_name FROM Jidouka WHERE Release_date BETWEEN '2022-01-01' AND '2022-03-31';"],
    ["Who is the author of the jidouka improvement with the longest description?", "SELECT Author_name FROM Author INNER JOIN Jidouka ON Author.Id = Jidouka.Author_id ORDER BY LENGTH(Description) DESC LIMIT 1;"],
    ["Which jidouka improvements have no description provided?", "SELECT Improve_name FROM Jidouka WHERE Description IS NULL;"],
    ["What is the total number of jidouka improvements created in 2020?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka WHERE YEAR(Release_date) = 2020;"],
    ["What are the applications of jidouka improvements that were launched in 'March'?", "SELECT Applications FROM Jidouka WHERE MONTH(Release_date) = 3;"],
    ["Which jidouka improvements have tools linked to them from 'Design Automation'?", "SELECT Improve_name FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON Tool.Id = JidoukaTool.Tool_id WHERE Tool_name = 'Design Automation';"],
    ["How many jidouka improvements are linked to 'Sustainability' tools?", "SELECT COUNT(DISTINCT Jidouka_id) AS Total_Improvements FROM JidoukaTool INNER JOIN Tool ON JidoukaTool.Tool_id = Tool.Id WHERE Tool_name = 'Sustainability';"],
    ["Which departments have jidouka improvements launched after '2021-06-01'?", "SELECT DISTINCT Department_name FROM Department INNER JOIN Jidouka ON Department.Id = Jidouka.Department_id WHERE Release_date > '2021-06-01';"],
    ["What are the launch times of jidouka improvements associated with 'Process Optimization'?", "SELECT Release_date FROM Jidouka WHERE Description LIKE '%Process Optimization%';"],
    ["List the jidouka improvements with saved time greater than 200 hours.", "SELECT Improve_name FROM Jidouka WHERE Time > 200;"],
    ["What is the product name of the jidouka improvement with the longest time saved?", "SELECT Product_name FROM Jidouka ORDER BY Time DESC LIMIT 1;"],
    ["Which jidouka improvements are associated with 'Smart Manufacturing' tools?", "SELECT Improve_name FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON Tool.Id = JidoukaTool.Tool_id WHERE Tool_name = 'Smart Manufacturing';"],
    ["What are the total saved hours for innovations in the 'Engineering' department?", "SELECT SUM(Time) AS Total_Saved_Hours FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Engineering';"],
    ["Which authors have created jidouka improvements launched after '2019-12-31'?", "SELECT DISTINCT Author_name FROM Author INNER JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE Release_date > '2019-12-31';"],
    ["Which jidouka improvements are linked to the 'Robotics' tool?", "SELECT Improve_name FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON Tool.Id = JidoukaTool.Tool_id WHERE Tool_name = 'Robotics';"],
    ["How many improvements were created by 'Alice Smith'?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka INNER JOIN Author ON Jidouka.Author_id = Author.Id WHERE Author_name = 'Alice Smith';"],
    ["What are the improvements with the least number of applications?", "SELECT Improve_name FROM Jidouka ORDER BY Applications ASC LIMIT 1;"],
    ["Which tools are used in improvements with 'Automation' in their description?", "SELECT Tool_name FROM Tool INNER JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id INNER JOIN Jidouka ON Jidouka.Id = JidoukaTool.Jidouka_id WHERE Jidouka.Description LIKE '%Automation%';"],
    ["Which jidouka improvements have more than 5 applications?", "SELECT Improve_name FROM Jidouka WHERE Applications > 5;"],
    ["Which innovation have more than 5 applications?", "SELECT Improve_name FROM Jidouka WHERE Applications > 5;"],
    ["What is the total number of saved hours across all jidouka improvements?", "SELECT SUM(Time) AS Total_Saved_Hours FROM Jidouka;"],
    ["The innovation have more than 5 applications?", "SELECT Improve_name FROM Jidouka WHERE Applications > 5;"],
    ["The innovation which saved more than 100 hours?", "SELECT Improve_name FROM Jidouka WHERE Time > 100;"],
    ["List all jidouka improvements associated with 'Customer Experience' department.", "SELECT Improve_name FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Customer Experience';"],
    ["Who are the authors of jidouka improvements released in the year 2022?", "SELECT DISTINCT Author_name FROM Author INNER JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE YEAR(Release_date) = 2022;"],
    ["The authors of jidouka improvements released in the year 2022?", "SELECT DISTINCT Author_name FROM Author INNER JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE YEAR(Release_date) = 2022;"],
    ["The authors of jidouka improvements released in the year 2024?", "SELECT DISTINCT Author_name FROM Author INNER JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE YEAR(Release_date) = 2024;"],
    ["List all of the employees that have innovation released in the year of 2024", "SELECT DISTINCT Author_name FROM Author INNER JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE YEAR(Release_date) = 2024;"],
    ["What is the total number of applications for improvements linked to the 'Quality Control' department?", "SELECT SUM(Applications) AS Total_Applications FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Quality Control';"],
    ["Which jidouka improvements were developed by employees from 'IT' department?", "SELECT Improve_name FROM Jidouka INNER JOIN Author ON Jidouka.Author_id = Author.Id INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'IT';"],
    ["What are the improvements created by 'John Doe' related to 'Lean Manufacturing'?", "SELECT Improve_name FROM Jidouka INNER JOIN Author ON Jidouka.Author_id = Author.Id WHERE Author_name = 'John Doe' AND Description LIKE '%Lean Manufacturing%';"],
    ["What are the improvements of John Doe related to Lean Manufacturing?", "SELECT Improve_name FROM Jidouka INNER JOIN Author ON Jidouka.Author_id = Author.Id WHERE Author_name = 'John Doe' AND Description LIKE '%Lean Manufacturing%';"],    
    ["Which improvements were released in the '2023' year and saved more than 150 hours?", "SELECT Improve_name FROM Jidouka WHERE YEAR(Release_date) = 2023 AND Time > 150;"],
    ["What are the tools linked to jidouka improvements with 'AI' in the product name?", "SELECT Tool_name FROM Tool INNER JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id INNER JOIN Jidouka ON Jidouka.Id = JidoukaTool.Jidouka_id WHERE Jidouka.Product_name LIKE '%AI%';"],
    ["List all jidouka improvements where the saved time is less than 50 hours.", "SELECT Improve_name FROM Jidouka WHERE Time < 50;"],
    ["Which jidouka improvements have a launch time between '2021-04-01' and '2021-06-30'?", "SELECT Improve_name FROM Jidouka WHERE Release_date BETWEEN '2021-04-01' AND '2021-06-30';"],
    ["How many jidouka improvements are associated with the 'Tool Optimization'?", "SELECT COUNT(DISTINCT Jidouka_id) AS Total_Improvements FROM JidoukaTool INNER JOIN Tool ON JidoukaTool.Tool_id = Tool.Id WHERE Tool_name = 'Tool Optimization';"],
    ["Which jidouka improvements have no associated product name?", "SELECT Improve_name FROM Jidouka WHERE Product_name IS NULL;"],
    ["Who are the authors of jidouka improvements launched in June 2021?", "SELECT DISTINCT Author_name FROM Author INNER JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE MONTH(Release_date) = 6 AND YEAR(Release_date) = 2021;"],
    ["What are the jidouka improvements that were applied to more than 10 tasks?", "SELECT Improve_name FROM Jidouka WHERE Applications > 10;"],
    ["Which jidouka improvements are associated with the 'Manufacturing Automation' tool?", "SELECT Improve_name FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON Tool.Id = JidoukaTool.Tool_id WHERE Tool_name = 'Manufacturing Automation';"],
    ["Which jidouka improvements have the highest number of saved hours?", "SELECT Improve_name FROM Jidouka ORDER BY Time DESC LIMIT 1;"],
    ["What is the total number of jidouka improvements created in 2021?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka WHERE YEAR(Release_date) = 2021;"],
    ["List all jidouka improvements created by Jane Doe in the HR department.", "SELECT Improve_name FROM Jidouka INNER JOIN Author ON Jidouka.Author_id = Author.Id INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Author_name = 'Jane Doe' AND Department_name = 'HR';"],
    ["Which jidouka improvements are linked to the 'Automation Tool'?", "SELECT Improve_name FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON Tool.Id = JidoukaTool.Tool_id WHERE Tool_name = 'Automation Tool';"],
    ["What are the improvements with the least number of task applications?", "SELECT Improve_name FROM Jidouka ORDER BY Applications ASC LIMIT 1;"],
    ["How many jidouka improvements involve the 'Data Analytics' tool?", "SELECT COUNT(DISTINCT Jidouka_id) AS Total_Improvements FROM JidoukaTool INNER JOIN Tool ON JidoukaTool.Tool_id = Tool.Id WHERE Tool_name = 'Data Analytics';"],
    ["What are the descriptions of jidouka improvements created by 'Robert Black'?", "SELECT Description FROM Jidouka INNER JOIN Author ON Jidouka.Author_id = Author.Id WHERE Author_name = 'Robert Black';"],
    ["Which jidouka improvements are associated with the 'Software Development' team?", "SELECT Improve_name FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Software Development';"],
    ["What is the total number of applications for jidouka improvements launched before '2022-01-01'?", "SELECT SUM(Applications) AS Total_Applications FROM Jidouka WHERE Release_date < '2022-01-01';"],
    ["Which jidouka improvements were created in the 'Manufacturing' department and saved more than 50 hours?", "SELECT Improve_name FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Manufacturing' AND Time > 50;"],
    ["What are the jidouka improvements that were released in the 'March' month of 2020?", "SELECT Improve_name FROM Jidouka WHERE MONTH(Release_date) = 3 AND YEAR(Release_date) = 2020;"],
    ["Which tools are associated with jidouka improvements that saved more than 100 hours?", "SELECT Tool_name FROM Tool INNER JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id INNER JOIN Jidouka ON Jidouka.Id = JidoukaTool.Jidouka_id WHERE Jidouka.Time > 100;"],
    ["What is the launch time of the jidouka improvement with the earliest launch date?", "SELECT Release_date FROM Jidouka ORDER BY Release_date ASC LIMIT 1;"],
    ["How many jidouka improvements were launched in 2021 and saved more than 200 hours?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka WHERE YEAR(Release_date) = 2021 AND Time > 200;"],
    ["List all jidouka improvements created by 'Sarah White' in the 'R&D' department.", "SELECT Improve_name FROM Jidouka INNER JOIN Author ON Jidouka.Author_id = Author.Id INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Author_name = 'Sarah White' AND Department_name = 'R&D';"],
    ["What is the average number of applications for improvements released after '2022-06-01'?", "SELECT AVG(Applications) AS Average_Applications FROM Jidouka WHERE Release_date > '2022-06-01';"],
    ["Which jidouka improvements were applied to more than 15 tasks?", "SELECT Improve_name FROM Jidouka WHERE Applications > 15;"],
    ["What are the improvements with no associated product name in the 'Logistics' department?", "SELECT Improve_name FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Logistics' AND Product_name IS NULL;"],
    ["Which jidouka improvements are linked to the 'Supply Chain Management' tool?", "SELECT Improve_name FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON Tool.Id = JidoukaTool.Tool_id WHERE Tool_name = 'Supply Chain Management';"],
    ["Which jidouka improvements saved more than 100 hours and were launched in 2021?", "SELECT Improve_name FROM Jidouka WHERE Time > 100 AND YEAR(Release_date) = 2021;"],
    ["What is the total number of jidouka improvements applied to less than 5 tasks?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka WHERE Applications < 5;"],
    ["Which jidouka improvements were created by Michael Green and launched in 2022?", "SELECT Improve_name FROM Jidouka INNER JOIN Author ON Jidouka.Author_id = Author.Id WHERE Author_name = 'Michael Green' AND YEAR(Release_date) = 2022;"],
    ["What is the average number of applications for jidouka improvements linked to 'Digital Transformation'?", "SELECT AVG(Applications) AS Average_Applications FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Digital Transformation';"],
    ["Which improvements saved more than 200 hours and were linked to the 'Automation' tool?", "SELECT Improve_name FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON Tool.Id = JidoukaTool.Tool_id WHERE Tool_name = 'Automation' AND Time > 200;"],
    ["How many jidouka improvements have no description provided?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka WHERE Description IS NULL;"],
    ["What are the jidouka improvements related to 'Process Optimization'?", "SELECT Improve_name FROM Jidouka WHERE Description LIKE '%Process Optimization%';"],
    ["Which jidouka improvements have more than 10 applications and were launched in 2023?", "SELECT Improve_name FROM Jidouka WHERE Applications > 10 AND YEAR(Release_date) = 2023;"],
    ["What is the total number of improvements associated with the 'Sales' department?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Sales';"],
    ["What are the jidouka improvements with the longest description?", "SELECT Improve_name FROM Jidouka ORDER BY LENGTH(Description) DESC LIMIT 1;"],
    ["Which jidouka improvements have been linked to both 'Lean Manufacturing' and 'AI'?", "SELECT Improve_name FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON Tool.Id = JidoukaTool.Tool_id WHERE Tool_name IN ('Lean Manufacturing', 'AI');"],
    ["How many jidouka improvements have a release date in 'January' 2022?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka WHERE MONTH(Release_date) = 1 AND YEAR(Release_date) = 2022;"],
    ["What are the jidouka improvements with no associated product name or description?", "SELECT Improve_name FROM Jidouka WHERE Product_name IS NULL AND Description IS NULL;"],
    ["Which jidouka improvements have a launch time between '2020-01-01' and '2020-12-31'?", "SELECT Improve_name FROM Jidouka WHERE Release_date BETWEEN '2020-01-01' AND '2020-12-31';"],
    ["What is the total number of applications for jidouka improvements related to the 'Supply Chain' department?", "SELECT SUM(Applications) AS Total_Applications FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Supply Chain';"],
    ["Which jidouka improvements saved between 50 and 150 hours?", "SELECT Improve_name FROM Jidouka WHERE Time BETWEEN 50 AND 150;"],
    ["What are the jidouka improvements with 'AI' in their product name?", "SELECT Improve_name FROM Jidouka WHERE Product_name LIKE '%AI%';"],
    ["How many jidouka improvements involve tools from the 'Robotics' category?", "SELECT COUNT(DISTINCT Jidouka_id) AS Total_Improvements FROM JidoukaTool INNER JOIN Tool ON JidoukaTool.Tool_id = Tool.Id WHERE Tool_name LIKE '%Robotics%';"],
    ["Which jidouka improvements were created by 'Chris Turner' and have a launch time after '2022-01-01'?", "SELECT Improve_name FROM Jidouka INNER JOIN Author ON Jidouka.Author_id = Author.Id WHERE Author_name = 'Chris Turner' AND Release_date > '2022-01-01';"],
    ["What are the jidouka improvements associated with both 'Customer Service' and 'Data Analytics' tools?", "SELECT Improve_name FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON Tool.Id = JidoukaTool.Tool_id WHERE Tool_name IN ('Customer Service', 'Data Analytics');"],
    ["Which jidouka improvements saved more than 300 hours and are linked to the 'Manufacturing' department?", "SELECT Improve_name FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Manufacturing' AND Time > 300;"],
    ["What is the total number of jidouka improvements created by 'David Lee' in the 'Engineering' department?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka INNER JOIN Author ON Jidouka.Author_id = Author.Id INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Author_name = 'David Lee' AND Department_name = 'Engineering';"],
    ["What are the improvements linked to both 'Lean' and 'Quality Control' tools?", "SELECT Improve_name FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON Tool.Id = JidoukaTool.Tool_id WHERE Tool_name IN ('Lean', 'Quality Control');"],
    ["How many jidouka improvements have no launch date?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka WHERE Release_date IS NULL;"],
    ["What are the jidouka improvements that saved more than 150 hours and are linked to the 'AI' department?", "SELECT Improve_name FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'AI' AND Time > 150;"],
    ["Which jidouka improvements were created by 'Anna Smith' in 2020?", "SELECT Improve_name FROM Jidouka INNER JOIN Author ON Jidouka.Author_id = Author.Id WHERE Author_name = 'Anna Smith' AND YEAR(Release_date) = 2020;"],
    ["What is the total number of jidouka improvements linked to the 'Marketing' department?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Marketing';"],
    ["Which jidouka improvements have a product name starting with 'Tech'?", "SELECT Improve_name FROM Jidouka WHERE Product_name LIKE 'Tech%';"],
    ["How many jidouka improvements were applied to exactly 10 tasks?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka WHERE Applications = 10;"],
    ["What are the jidouka improvements with descriptions containing the word 'Automation'?", "SELECT Improve_name FROM Jidouka WHERE Description LIKE '%Automation%';"],
    ["What is the average number of applications for improvements in the 'Customer Service' department?", "SELECT AVG(Applications) AS Average_Applications FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Customer Service';"],
    ["Which jidouka improvements were launched after '2021-06-30' and saved more than 100 hours?", "SELECT Improve_name FROM Jidouka WHERE Release_date > '2021-06-30' AND Time > 100;"],
    ["What are the jidouka improvements that saved less than 50 hours?", "SELECT Improve_name FROM Jidouka WHERE Time < 50;"],
    ["Which jidouka improvements are associated with both 'Project Management' and 'Business Analysis' tools?", "SELECT Improve_name FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON Tool.Id = JidoukaTool.Tool_id WHERE Tool_name IN ('Project Management', 'Business Analysis');"],
    ["How many jidouka improvements were launched in 2019 and involved 'Robotics' tools?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON Tool.Id = JidoukaTool.Tool_id WHERE YEAR(Release_date) = 2019 AND Tool_name = 'Robotics';"],
    ["What are the jidouka improvements with the longest launch time?", "SELECT Improve_name FROM Jidouka ORDER BY Release_date DESC LIMIT 1;"],
    ["What are the jidouka improvements that were linked to the 'Supply Chain Management' tool and saved more than 50 hours?", "SELECT Improve_name FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON Tool.Id = JidoukaTool.Tool_id WHERE Tool_name = 'Supply Chain Management' AND Time > 50;"],
    ["How many jidouka improvements are associated with the 'Data Analysis' department?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Data Analysis';"],
    ["What is the total time saved by all jidouka improvements launched in 2020?", "SELECT SUM(Time) AS Total_Time_Saved FROM Jidouka WHERE YEAR(Release_date) = 2020;"],
    ["Which jidouka improvements saved over 500 hours and were created in the 'R&D' department?", "SELECT Improve_name FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'R&D' AND Time > 500;"],
    ["How many jidouka improvements were associated with the 'Lean Manufacturing' tool?", "SELECT COUNT(DISTINCT Jidouka_id) AS Total_Improvements FROM JidoukaTool INNER JOIN Tool ON JidoukaTool.Tool_id = Tool.Id WHERE Tool_name = 'Lean Manufacturing';"],
    ["Which jidouka improvements saved between 100 and 200 hours and were launched in 2021?", "SELECT Improve_name FROM Jidouka WHERE Time BETWEEN 100 AND 200 AND YEAR(Release_date) = 2021;"],
    ["What is the total number of jidouka improvements related to the 'AI' tool?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON Tool.Id = JidoukaTool.Tool_id WHERE Tool_name = 'AI';"],
    ["Which jidouka improvements were created by John Doe and applied to less than 3 tasks?", "SELECT Improve_name FROM Jidouka INNER JOIN Author ON Jidouka.Author_id = Author.Id WHERE Author_name = 'John Doe' AND Applications < 3;"],
    ["What is the average number of applications for jidouka improvements linked to the 'Finance' department?", "SELECT AVG(Applications) AS Average_Applications FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Finance';"],
    ["Which jidouka improvements were created before '2020-01-01' and have more than 50 applications?", "SELECT Improve_name FROM Jidouka WHERE Release_date < '2020-01-01' AND Applications > 50;"],
    ["What are the jidouka improvements associated with 'HR' and saved more than 30 hours?", "SELECT Improve_name FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'HR' AND Time > 30;"],
    ["How many jidouka improvements have the word 'optimization' in their description?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka WHERE Description LIKE '%optimization%';"],
    ["Which jidouka improvements saved less than 10 hours and were launched in 2018?", "SELECT Improve_name FROM Jidouka WHERE Time < 10 AND YEAR(Release_date) = 2018;"],
    ["What are the jidouka improvements that were linked to 'Project Management' and saved between 100 and 300 hours?", "SELECT Improve_name FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON Tool.Id = JidoukaTool.Tool_id WHERE Tool_name = 'Project Management' AND Time BETWEEN 100 AND 300;"],
    ["Which jidouka improvements are associated with 'Data Analytics' and have no product name?", "SELECT Improve_name FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON Tool.Id = JidoukaTool.Tool_id WHERE Tool_name = 'Data Analytics' AND Product_name IS NULL;"],
    ["What is the total number of jidouka improvements launched in March of 2022?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka WHERE MONTH(Release_date) = 3 AND YEAR(Release_date) = 2022;"],
    ["Which jidouka improvements have been applied to more than 20 tasks?", "SELECT Improve_name FROM Jidouka WHERE Applications > 20;"],
    ["How many jidouka improvements were linked to the Cloud Computing tool and saved over 100 hours?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON Tool.Id = JidoukaTool.Tool_id WHERE Tool_name = 'Cloud Computing' AND Time > 100;"],
    ["What are the jidouka improvements launched between '2022-05-01' and '2022-12-31'?", "SELECT Improve_name FROM Jidouka WHERE Release_date BETWEEN '2022-05-01' AND '2022-12-31';"],
    ["Which jidouka improvements were associated with both 'Automation' and 'Digital Transformation' tools?", "SELECT Improve_name FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON Tool.Id = JidoukaTool.Tool_id WHERE Tool_name IN ('Automation', 'Digital Transformation');"],
    ["What is the total number of jidouka improvements saved between 500 and 1000 hours?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka WHERE Time BETWEEN 500 AND 1000;"],
    ["Which jidouka improvements saved over 1000 hours and are linked to the 'Finance' department?", "SELECT Improve_name FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Finance' AND Time > 1000;"],
    ["What are the jidouka improvements that saved less than 20 hours and were launched before 2021?", "SELECT Improve_name FROM Jidouka WHERE Time < 20 AND YEAR(Release_date) < 2021;"],
    ["Which jidouka improvements saved between 100 and 200 hours and were launched in the 'Sales' department?", "SELECT Improve_name FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Sales' AND Time BETWEEN 100 AND 200;"],
    ["How many jidouka improvements were created by Emily Johnson and have a product name starting with 'Eco'?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka INNER JOIN Author ON Jidouka.Author_id = Author.Id WHERE Author_name = 'Emily Johnson' AND Product_name LIKE 'Eco%';"],
    ["What jidouka improvements have more than 100 applications and are related to the 'Engineering' department?", "SELECT Improve_name FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Engineering' AND Applications > 100;"],
    ["What are the jidouka improvements that were launched after '2023-01-01' and saved less than 50 hours?", "SELECT Improve_name FROM Jidouka WHERE Release_date > '2023-01-01' AND Time < 50;"],
    ["Which jidouka improvements saved over 100 hours and are linked to the 'Marketing' department?", "SELECT Improve_name FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Marketing' AND Time > 100;"],
    ["How many jidouka improvements are associated with the 'Data Science' tool?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON Tool.Id = JidoukaTool.Tool_id WHERE Tool_name = 'Data Science';"],
    ["What is the total number of jidouka improvements launched in 'Q1' of 2022?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka WHERE Release_date BETWEEN '2022-01-01' AND '2022-03-31';"],
    ["Which jidouka improvements are associated with 'Digitalization' and saved more than 200 hours?", "SELECT Improve_name FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON Tool.Id = JidoukaTool.Tool_id WHERE Tool_name = 'Digitalization' AND Time > 200;"],
    ["What are the jidouka improvements created by Michael Brown that saved less than 50 hours?", "SELECT Improve_name FROM Jidouka INNER JOIN Author ON Jidouka.Author_id = Author.Id WHERE Author_name = 'Michael Brown' AND Time < 50;"],
    ["How many jidouka improvements are linked to the IoT tool and have a description about 'Smart Devices'?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON Tool.Id = JidoukaTool.Tool_id WHERE Tool_name = 'IoT' AND Description LIKE '%Smart Devices%';"],
    ["Which jidouka improvements have saved more than 500 hours and are associated with 'Automation' tools?", "SELECT Improve_name FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON Tool.Id = JidoukaTool.Tool_id WHERE Tool_name = 'Automation' AND Time > 500;"],
    ["How many jidouka improvements were created in 2019 and have a product name starting with 'Smart'?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka WHERE YEAR(Release_date) = 2019 AND Product_name LIKE 'Smart%';"],
    ["What jidouka improvements were launched before '2021-12-31' and have no description?", "SELECT Improve_name FROM Jidouka WHERE Release_date < '2021-12-31' AND Description IS NULL;"],
    ["Which jidouka improvements were launched after '2022-06-01' and saved over 200 hours?", "SELECT Improve_name FROM Jidouka WHERE Release_date > '2022-06-01' AND Time > 200;"],
    ["What is the total time saved by jidouka improvements in the 'HR' department?", "SELECT SUM(Time) AS Total_Time_Saved FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'HR';"],
    ["Which jidouka improvements are linked to both 'AI' and 'Blockchain' tools?", "SELECT Improve_name FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON Tool.Id = JidoukaTool.Tool_id WHERE Tool_name IN ('AI', 'Blockchain');"],
    ["How many jidouka improvements were launched in 2020 and applied to exactly 5 tasks?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka WHERE YEAR(Release_date) = 2020 AND Applications = 5;"],
    ["What jidouka improvements saved over 200 hours and have a description containing 'Efficiency'?", "SELECT Improve_name FROM Jidouka WHERE Time > 200 AND Description LIKE '%Efficiency%';"],
    ["What is the total number of jidouka improvements launched in the 'Software' department?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Software';"],
    ["Which jidouka improvements saved between 50 and 150 hours and were associated with 'Data Security' tools?", "SELECT Improve_name FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON Tool.Id = JidoukaTool.Tool_id WHERE Tool_name = 'Data Security' AND Time BETWEEN 50 AND 150;"],
    ["Which jidouka improvements saved over 300 hours and were launched by 'Sarah Lee'?", "SELECT Improve_name FROM Jidouka INNER JOIN Author ON Jidouka.Author_id = Author.Id WHERE Author_name = 'Sarah Lee' AND Time > 300;"],
    ["How many jidouka improvements were launched after '2022-06-15' and applied to more than 10 tasks?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka WHERE Release_date > '2022-06-15' AND Applications > 10;"],
    ["What are the jidouka improvements linked to the 'ERP' tool and saved over 400 hours?", "SELECT Improve_name FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON Tool.Id = JidoukaTool.Tool_id WHERE Tool_name = 'ERP' AND Time > 400;"],
    ["Which jidouka improvements have the word 'automation' in their description and were launched before 2021?", "SELECT Improve_name FROM Jidouka WHERE Description LIKE '%automation%' AND Release_date < '2021-01-01';"],
    ["How many jidouka improvements saved more than 150 hours and were associated with the 'Manufacturing' department?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Manufacturing' AND Time > 150;"],
    ["What jidouka improvements saved between 100 and 500 hours and were linked to 'Digital Transformation'?", "SELECT Improve_name FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON Tool.Id = JidoukaTool.Tool_id WHERE Tool_name = 'Digital Transformation' AND Time BETWEEN 100 AND 500;"],
    ["Which jidouka improvements were launched in 2021 and have 'Cost Reduction' as their description?", "SELECT Improve_name FROM Jidouka WHERE YEAR(Release_date) = 2021 AND Description LIKE '%Cost Reduction%';"],
    ["How many jidouka improvements were created by 'David Smith' and have more than 10 applications?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka INNER JOIN Author ON Jidouka.Author_id = Author.Id WHERE Author_name = 'David Smith' AND Applications > 10;"],
    ["What jidouka improvements were associated with 'Cloud Computing' and saved less than 50 hours?", "SELECT Improve_name FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON Tool.Id = JidoukaTool.Tool_id WHERE Tool_name = 'Cloud Computing' AND Time < 50;"],
    ["What is the total number of jidouka improvements with a description that includes 'Sustainability'?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka WHERE Description LIKE '%Sustainability%';"],
    ["Which jidouka improvements saved between 200 and 400 hours and were applied in the 'Operations' department?", "SELECT Improve_name FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Operations' AND Time BETWEEN 200 AND 400;"],
    ["How many jidouka improvements were launched before '2020-03-01' and had fewer than 5 applications?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka WHERE Release_date < '2020-03-01' AND Applications < 5;"],
    ["Which jidouka improvements have a 'Productivity' keyword in their description and were created after 2022?", "SELECT Improve_name FROM Jidouka WHERE Description LIKE '%Productivity%' AND Release_date > '2022-01-01';"],
    ["What jidouka improvements saved over 1000 hours and were created by 'Alice Cooper'?", "SELECT Improve_name FROM Jidouka INNER JOIN Author ON Jidouka.Author_id = Author.Id WHERE Author_name = 'Alice Cooper' AND Time > 1000;"],
    ["How many jidouka improvements are associated with 'AI' and have been launched in 'Q3' of 2021?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka WHERE Tool_name = 'AI' AND Release_date BETWEEN '2021-07-01' AND '2021-09-30';"],
    ["Which jidouka improvements saved between 50 and 150 hours and were created in the 'Logistics' department?", "SELECT Improve_name FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Logistics' AND Time BETWEEN 50 AND 150;"],
    ["What jidouka improvements have the word 'Efficiency' in their description and saved more than 500 hours?", "SELECT Improve_name FROM Jidouka WHERE Description LIKE '%Efficiency%' AND Time > 500;"],
    ["How many jidouka improvements have a 'Lean' keyword in their description and saved between 200 and 400 hours?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka WHERE Description LIKE '%Lean%' AND Time BETWEEN 200 AND 400;"],
    ["What are the jidouka improvements that were associated with the 'Robotics' tool and saved over 100 hours?", "SELECT Improve_name FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON Tool.Id = JidoukaTool.Tool_id WHERE Tool_name = 'Robotics' AND Time > 100;"],
    ["Which jidouka improvements were launched in '2020' and have saved more than 50 hours?", "SELECT Improve_name FROM Jidouka WHERE YEAR(Release_date) = 2020 AND Time > 50;"],
    ["How many jidouka improvements have been applied to at least 20 tasks and are linked to the 'AI' tool?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON Tool.Id = JidoukaTool.Tool_id WHERE Tool_name = 'AI' AND Applications >= 20;"],
    ["What jidouka improvements have more than 300 applications and are associated with the 'Automation' tool?", "SELECT Improve_name FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON Tool.Id = JidoukaTool.Tool_id WHERE Tool_name = 'Automation' AND Applications > 300;"],
    ["Which jidouka improvements were created by John Doe and saved more than 1000 hours?", "SELECT Improve_name FROM Jidouka INNER JOIN Author ON Jidouka.Author_id = Author.Id WHERE Author_name = 'John Doe' AND Time > 1000;"],
    ["How many jidouka improvements were applied to over 50 tasks and launched after '2021-01-01'?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka WHERE Applications > 50 AND Release_date > '2021-01-01';"],
    ["What jidouka improvements are associated with 'Cloud Technology' and saved between 100 and 300 hours?", "SELECT Improve_name FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON Tool.Id = JidoukaTool.Tool_id WHERE Tool_name = 'Cloud Technology' AND Time BETWEEN 100 AND 300;"],
    ["Which jidouka improvements have 'Cost Savings' in their description and were applied in the 'Finance' department?", "SELECT Improve_name FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Finance' AND Description LIKE '%Cost Savings%';"],
    ["How many jidouka improvements saved over 500 hours and were linked to the 'Business Intelligence' tool?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON Tool.Id = JidoukaTool.Tool_id WHERE Tool_name = 'Business Intelligence' AND Time > 500;"],
    ["What jidouka improvements saved between 50 and 200 hours and were launched before '2021-12-31'?", "SELECT Improve_name FROM Jidouka WHERE Time BETWEEN 50 AND 200 AND Release_date < '2021-12-31';"],
    ["Which jidouka improvements were launched in '2022' and applied to exactly 3 tasks?", "SELECT Improve_name FROM Jidouka WHERE YEAR(Release_date) = 2022 AND Applications = 3;"],
    ["How many jidouka improvements have the word innovation in their description and were created by 'Chris Taylor'?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka WHERE Description LIKE '%innovation%' AND Author_name = 'Chris Taylor';"],
    ["What jidouka improvements saved more than 100 hours and were associated with the 'Big Data' tool?", "SELECT Improve_name FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON Tool.Id = JidoukaTool.Tool_id WHERE Tool_name = 'Big Data' AND Time > 100;"],
    ["Which jidouka improvements are linked to the 'ERP' tool and were launched in 'Q2' of 2021?", "SELECT Improve_name FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON Tool.Id = JidoukaTool.Tool_id WHERE Tool_name = 'ERP' AND Release_date BETWEEN '2021-04-01' AND '2021-06-30';"],
    ["What jidouka improvements saved between 200 and 500 hours and are associated with the 'Automation' department?", "SELECT Improve_name FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Automation' AND Time BETWEEN 200 AND 500;"],
    ["How many jidouka improvements were applied to fewer than 5 tasks and saved more than 50 hours?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka WHERE Applications < 5 AND Time > 50;"],
    ["What are the jidouka improvements that were created by Linda White and have 'AI' in their description?", "SELECT Improve_name FROM Jidouka INNER JOIN Author ON Jidouka.Author_id = Author.Id WHERE Author_name = 'Linda White' AND Description LIKE '%AI%';"],
    ["How many jidouka improvements have a product name starting with 'Tech' and were launched after '2021-06-01'?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka WHERE Product_name LIKE 'Tech%' AND Release_date > '2021-06-01';"],
    ["Which jidouka improvements have been applied in more than 100 tasks and were created in 2020?", "SELECT Improve_name FROM Jidouka WHERE Applications > 100 AND YEAR(Release_date) = 2020;"],
    ["What jidouka improvements were launched after '2022-01-01' and saved over 300 hours?", "SELECT Improve_name FROM Jidouka WHERE Release_date > '2022-01-01' AND Time > 300;"],
    ["How many jidouka improvements have the keyword 'productivity' in their description and were associated with the 'Data Science' tool?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON Tool.Id = JidoukaTool.Tool_id WHERE Tool_name = 'Data Science' AND Description LIKE '%productivity%';"],
    ["What are the jidouka improvements launched in 2021 that saved between 100 and 200 hours?", "SELECT Improve_name FROM Jidouka WHERE YEAR(Release_date) = 2021 AND Time BETWEEN 100 AND 200;"],
    ["Which jidouka improvements are associated with 'IoT' tools and saved more than 150 hours?", "SELECT Improve_name FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON Tool.Id = JidoukaTool.Tool_id WHERE Tool_name = 'IoT' AND Time > 150;"],
    ["How many jidouka improvements saved over 500 hours and have 'Automation' as their description?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka WHERE Description LIKE '%Automation%' AND Time > 500;"],
    ["What jidouka improvements saved between 150 and 300 hours and were created by 'James Lee'?", "SELECT Improve_name FROM Jidouka INNER JOIN Author ON Jidouka.Author_id = Author.Id WHERE Author_name = 'James Lee' AND Time BETWEEN 150 AND 300;"],
    ["Name of improvements were launched after 2024-01-01 and saved at least 20 hours?", "SELECT Improve_name FROM Jidouka WHERE Release_date > '2024-01-01' AND Time > 20;"],
    ["What jidouka improvements were launched after '2022-01-01' and saved over 300 hours?", "SELECT Improve_name FROM Jidouka WHERE Release_date > '2022-01-01' AND Time > 300;"],
    ["What innovations were released after '2023-01-02' and saved over 1000 hours?", "SELECT Improve_name FROM Jidouka WHERE Release_date > '2023-01-02' AND Time > 1000;"],
    ["Name of improvements were launched after 2024-01-01 and saved at least 20 hours?", "SELECT Improve_name FROM Jidouka WHERE Release_date > '2024-01-01' AND Time > 20;"],
    ["Name of innovations were launched after 2020-01-01 and saved at least 150 hours?", "SELECT Improve_name FROM Jidouka WHERE Release_date > '2020-01-01' AND Time > 150;"],  
    ["Which jidouka improvements were launched before 2020-01-01 and saved over 100 hours?", "SELECT Improve_name FROM Jidouka WHERE Release_date < '2020-01-01' AND Time > 100;"],
    ["How many jidouka improvements have Efficiency in their description and were linked to 'AI' tools?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON Tool.Id = JidoukaTool.Tool_id WHERE Tool_name = 'AI' AND Description LIKE '%Efficiency%';"],
    ["What jidouka improvements were applied in more than 30 tasks and were created in the 'Engineering' department?", "SELECT Improve_name FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Engineering' AND Applications > 30;"],
    ["How many jidouka improvements were created by Eve Johnson and have 'Productivity' as their description?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka INNER JOIN Author ON Jidouka.Author_id = Author.Id WHERE Author_name = 'Eve Johnson' AND Description LIKE '%Productivity%';"],
    ["Which jidouka improvements have the word Lean in their description and saved between 100 and 200 hours?", "SELECT Improve_name FROM Jidouka WHERE Description LIKE '%Lean%' AND Time BETWEEN 100 AND 200;"],
    ["How many jidouka improvements are associated with Data Analytics tools and saved over 200 hours?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON Tool.Id = JidoukaTool.Tool_id WHERE Tool_name = 'Data Analytics' AND Time > 200;"],
    ["What jidouka improvements were launched in '2021' and applied to at least 10 tasks?", "SELECT Improve_name FROM Jidouka WHERE YEAR(Release_date) = 2021 AND Applications >= 10;"],
    ["Which jidouka improvements saved between 500 and 1000 hours and are linked to the 'Automation' tool?", "SELECT Improve_name FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON Tool.Id = JidoukaTool.Tool_id WHERE Tool_name = 'Automation' AND Time BETWEEN 500 AND 1000;"],
    ["How many jidouka improvements saved over 300 hours and were launched in 'Q4' of 2022?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka WHERE Time > 300 AND Release_date BETWEEN '2022-10-01' AND '2022-12-31';"],
    ["Which jidouka improvements were applied to more than 50 tasks and had 'Quality Control' in their description?", "SELECT Improve_name FROM Jidouka WHERE Applications > 50 AND Description LIKE '%Quality Control%';"],
    ["How many jidouka improvements were created by 'Michael Green' and have 'Sustainability' in their description?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka INNER JOIN Author ON Jidouka.Author_id = Author.Id WHERE Author_name = 'Michael Green' AND Description LIKE '%Sustainability%';"],
    ["What jidouka improvements were associated with Robotics tools and saved over 150 hours?", "SELECT Improve_name FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON Tool.Id = JidoukaTool.Tool_id WHERE Tool_name = 'Robotics' AND Time > 150;"],
    ["Which jidouka improvements saved over 200 hours and were applied in the 'Manufacturing' department?", "SELECT Improve_name FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'Manufacturing' AND Time > 200;"],
    ["How many jidouka improvements saved between 100 and 300 hours and were created in the 'R&D' department?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka INNER JOIN Department ON Jidouka.Department_id = Department.Id WHERE Department_name = 'R&D' AND Time BETWEEN 100 AND 300;"],
    ["What jidouka improvements were launched after '2021-07-01' and applied to more than 15 tasks?", "SELECT Improve_name FROM Jidouka WHERE Release_date > '2021-07-01' AND Applications > 15;"],
    ["How many jidouka improvements have 'Automation' in their description and saved between 50 and 100 hours?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka WHERE Description LIKE '%Automation%' AND Time BETWEEN 50 AND 100;"],
    ["Which jidouka improvements saved between 50 and 150 hours and were linked to the 'Lean Manufacturing' tool?", "SELECT Improve_name FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON Tool.Id = JidoukaTool.Tool_id WHERE Tool_name = 'Lean Manufacturing' AND Time BETWEEN 50 AND 150;"],
    ["How many jidouka improvements were created by Rachel Adams and saved more than 400 hours?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka INNER JOIN Author ON Jidouka.Author_id = Author.Id WHERE Author_name = 'Rachel Adams' AND Time > 400;"],
    ["What jidouka improvements were associated with the 'Blockchain' tool and have the word 'security' in their description?", "SELECT Improve_name FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON Tool.Id = JidoukaTool.Tool_id WHERE Tool_name = 'Blockchain' AND Description LIKE '%security%';"],
    ["How many jidouka improvements saved over 600 hours and were linked to 'Cloud Computing' tools?", "SELECT COUNT(*) AS Total_Improvements FROM Jidouka INNER JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id INNER JOIN Tool ON Tool.Id = JidoukaTool.Tool_id WHERE Tool_name = 'Cloud Computing' AND Time > 600;"],
    ["What is the task associated with the job 'Improvement of production process'?", "SELECT Job_name FROM Job WHERE Job_name = 'Improvement of production process';"],
    ["Can you tell me about the history of the Eiffel Tower?", "The Eiffel Tower was completed in 1889 and was initially a temporary structure for the 1889 Exposition Universelle in Paris."],
    ["What tools are used in the innovation process?", "SELECT Tool_name FROM Tool INNER JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id INNER JOIN Jidouka ON JidoukaTool.Jidouka_id = Jidouka.Id WHERE Jidouka.Improve_name = 'innovation';"],
    ["Who is the author of the 'Productivity Boost' improvement?", "SELECT Author_name FROM Author INNER JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE Jidouka.Improve_name = 'Productivity Boost';"],
    ["How much time was saved in the 'Task Automation' improvement?", "SELECT Time FROM Jidouka WHERE Improve_name = 'Task Automation';"],
    ["What is the release date for the 'Inventory Management' product?", "SELECT Release_date FROM Jidouka WHERE Product_name = 'Inventory Management';"],
    ["What is the capital of Australia?", "The capital of Australia is Canberra."],
    ["Which department worked on the 'Production Efficiency' innovation?", "SELECT Department_name FROM Department INNER JOIN Jidouka ON Department.Id = Jidouka.Department_id WHERE Jidouka.Improve_name = 'Production Efficiency';"],
    ["How many jobs applied the 'Automated Inspection' innovation?", "SELECT Applications FROM Jidouka WHERE Improve_name = 'Automated Inspection';"],
    ["What is the description of the 'Energy Conservation' innovation?", "SELECT Description FROM Jidouka WHERE Improve_name = 'Energy Conservation';"],
    ["What is the purpose of the Jidouka table?", "The Jidouka table stores information about improvements, innovations, and the relationship between jobs, departments, authors, and tools."],
    ["How many hours were saved by the Assembly Line Optimization improvement?", "SELECT Time FROM Jidouka WHERE Improve_name = 'Assembly Line Optimization';"],
    ["What tool is used in the Data Analysis improvement?", "SELECT Tool_name FROM Tool INNER JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id INNER JOIN Jidouka ON JidoukaTool.Jidouka_id = Jidouka.Id WHERE Jidouka.Improve_name = 'Data Analysis';"],
    ["What is the release time for Automated Packaging?", "SELECT Release_date FROM Jidouka WHERE Improve_name = 'Automated Packaging';"],
    ["How many products have been improved with the 'Speed Enhancement' tool?", "SELECT Product_name FROM Jidouka WHERE Improve_name = 'Speed Enhancement';"],
    ["Where is the Department of Automation located?", "Sorry, I don't know that."],
    ["Who created the Quality Control innovation?", "SELECT Author_name FROM Author INNER JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE Jidouka.Improve_name = 'Quality Control';"],
    ["What are some innovations related to Waste Reduction?", "SELECT Improve_name FROM Jidouka WHERE Improve_name LIKE '%Waste Reduction%';"],
    ["How can I improve my skills in machine learning?", "To improve your machine learning skills, consider studying online courses, reading textbooks, and practicing with real-world datasets."],
    ["Which department is responsible for Automated Testing?", "SELECT Department_name FROM Department INNER JOIN Jidouka ON Department.Id = Jidouka.Department_id WHERE Jidouka.Improve_name = 'Automated Testing';"],
    ["What is the job associated with 'Material Handling'?", "SELECT Job_name FROM Job WHERE Job_name = 'Material Handling';"],
    ["How can I get to the nearest airport?", "Sorry, I don't know that."],
    ["What product was launched using the Process Optimization improvement?", "SELECT Product_name FROM Jidouka WHERE Improve_name = 'Process Optimization';"],
    ["When was the 'Waste Minimization' improvement released?", "SELECT Release_date FROM Jidouka WHERE Improve_name = 'Waste Minimization';"],
    ["What is the latest tool introduced for 'Energy Saving'?", "SELECT Tool_name FROM Tool INNER JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id INNER JOIN Jidouka ON JidoukaTool.Jidouka_id = Jidouka.Id WHERE Jidouka.Improve_name = 'Energy Saving';"],
    ["What is the capital of Japan?", "The capital of Japan is Tokyo."],
    ["How many applications use the Automated Packaging innovation?", "SELECT Applications FROM Jidouka WHERE Improve_name = 'Automated Packaging';"],
    ["Who is responsible for System Integration improvement?", "SELECT Author_name FROM Author INNER JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE Jidouka.Improve_name = 'System Integration';"],
    ["How can I improve my programming skills?", "Practice coding daily, work on projects, and learn new languages or frameworks."],
    ["What department is working on Lean Manufacturing?", "SELECT Department_name FROM Department INNER JOIN Jidouka ON Department.Id = Jidouka.Department_id WHERE Jidouka.Improve_name = 'Lean Manufacturing';"],
    ["What is the description of the Robotic Process Automation innovation?", "SELECT Description FROM Jidouka WHERE Improve_name = 'Robotic Process Automation';"],
    ["What is the tool used in Automated Data Entry?", "SELECT Tool_name FROM Tool INNER JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id INNER JOIN Jidouka ON JidoukaTool.Jidouka_id = Jidouka.Id WHERE Jidouka.Improve_name = 'Automated Data Entry';"],
    ["What is the number of jobs applying 'Artificial Intelligence' innovation?", "SELECT Applications FROM Jidouka WHERE Improve_name = 'Artificial Intelligence';"],
    ["Can you tell me about the Eiffel Tower?", "The Eiffel Tower was completed in 1889 and was initially a temporary structure for the 1889 Exposition Universelle in Paris."],
    ["What is the launch time for the Data Migration innovation?", "SELECT Release_date FROM Jidouka WHERE Improve_name = 'Data Migration';"],
    ["Who developed the Smart Factory innovation?", "SELECT Author_name FROM Author INNER JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE Jidouka.Improve_name = 'Smart Factory';"],
    ["How many applications were involved in 'Automated Inspection'?", "SELECT Applications FROM Jidouka WHERE Improve_name = 'Automated Inspection';"],
    ["What are the benefits of Predictive Maintenance?", "Sorry, I don't know that."],
    ["How many hours were saved by the Automation of Reporting innovation?", "SELECT Time FROM Jidouka WHERE Improve_name = 'Automation of Reporting';"],
    ["What department worked on Predictive Analytics?", "SELECT Department_name FROM Department INNER JOIN Jidouka ON Department.Id = Jidouka.Department_id WHERE Jidouka.Improve_name = 'Predictive Analytics';"],
    ["What is the product associated with Supply Chain Optimization?", "SELECT Product_name FROM Jidouka WHERE Improve_name = 'Supply Chain Optimization';"],
    ["How many tools are used in the Robotics Implementation innovation?", "SELECT COUNT(Tool_name) FROM Tool INNER JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id INNER JOIN Jidouka ON JidoukaTool.Jidouka_id = Jidouka.Id WHERE Jidouka.Improve_name = 'Robotics Implementation';"],
    ["What is the release time for Quality Assurance Automation?", "SELECT Release_date FROM Jidouka WHERE Improve_name = 'Quality Assurance Automation';"],
    ["What is the primary function of the Job table?", "The Job table stores information about different jobs within the company, including job names and IDs."],
    ["How many hours were saved with Product Development Efficiency?", "SELECT Time FROM Jidouka WHERE Improve_name = 'Product Development Efficiency';"],
    ["Who created the Cost Reduction innovation?", "SELECT Author_name FROM Author INNER JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE Jidouka.Improve_name = 'Cost Reduction';"],
    ["What is the tool used in the Inventory Automation innovation?", "SELECT Tool_name FROM Tool INNER JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id INNER JOIN Jidouka ON JidoukaTool.Jidouka_id = Jidouka.Id WHERE Jidouka.Improve_name = 'Inventory Automation';"],
    ["What is the description of the 'Production Line Optimization' improvement?", "SELECT Description FROM Jidouka WHERE Improve_name = 'Production Line Optimization';"],
    ["Who created the 'Workplace Safety' innovation?", "SELECT Author_name FROM Author INNER JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE Jidouka.Improve_name = 'Workplace Safety';"],
    ["How many tasks use the 'AI-powered Automation' innovation?", "SELECT Applications FROM Jidouka WHERE Improve_name = 'AI-powered Automation';"],
    ["What is the release date for 'Energy-efficient Production'?", "SELECT Release_date FROM Jidouka WHERE Improve_name = 'Energy-efficient Production';"],
    ["What is the job associated with 'Automated Sorting'?", "SELECT Job_name FROM Job WHERE Job_name = 'Automated Sorting';"],
    ["What is the product name related to 'Automated Packaging'?", "SELECT Product_name FROM Jidouka WHERE Improve_name = 'Automated Packaging';"],
    ["Who is responsible for the 'Robotic Automation' innovation?", "SELECT Author_name FROM Author INNER JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE Jidouka.Improve_name = 'Robotic Automation';"],
    ["What tools are used in 'AI-based Monitoring'?", "SELECT Tool_name FROM Tool INNER JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id INNER JOIN Jidouka ON JidoukaTool.Jidouka_id = Jidouka.Id WHERE Jidouka.Improve_name = 'AI-based Monitoring';"],
    ["How many applications were involved in 'Predictive Maintenance'?", "SELECT Applications FROM Jidouka WHERE Improve_name = 'Predictive Maintenance';"],
    ["How many hours were saved by 'Advanced Manufacturing'?", "SELECT Time FROM Jidouka WHERE Improve_name = 'Advanced Manufacturing';"],
    ["What is the department working on 'Supply Chain Optimization'?", "SELECT Department_name FROM Department INNER JOIN Jidouka ON Department.Id = Jidouka.Department_id WHERE Jidouka.Improve_name = 'Supply Chain Optimization';"],
    ["Who is the author of 'Smart Warehouse Management'?", "SELECT Author_name FROM Author INNER JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE Jidouka.Improve_name = 'Smart Warehouse Management';"],
    ["What is the description of the 'Automated Assembly Line'?", "SELECT Description FROM Jidouka WHERE Improve_name = 'Automated Assembly Line';"],
    ["What is the release date for 'Manufacturing Process Automation'?", "SELECT Release_date FROM Jidouka WHERE Improve_name = 'Manufacturing Process Automation';"],
    ["What is the product associated with 'Lean Production'?", "SELECT Product_name FROM Jidouka WHERE Improve_name = 'Lean Production';"],
    ["Can you tell me who invented the wheel?", "The invention of the wheel dates back to around 3500 BC in Mesopotamia, but it is not attributed to a single individual."],
    ["How many jobs have implemented 'Data Analytics'?", "SELECT Applications FROM Jidouka WHERE Improve_name = 'Data Analytics';"],
    ["What is the tool used in 'Process Automation'?", "SELECT Tool_name FROM Tool INNER JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id INNER JOIN Jidouka ON JidoukaTool.Jidouka_id = Jidouka.Id WHERE Jidouka.Improve_name = 'Process Automation';"],
    ["What department is responsible for 'Quality Control Automation'?", "SELECT Department_name FROM Department INNER JOIN Jidouka ON Department.Id = Jidouka.Department_id WHERE Jidouka.Improve_name = 'Quality Control Automation';"],
    ["What is the job name for 'Waste Management Automation'?", "SELECT Job_name FROM Job WHERE Job_name = 'Waste Management Automation';"],
    ["What is the number of hours saved with 'Robotic Process Automation'?", "SELECT Time FROM Jidouka WHERE Improve_name = 'Robotic Process Automation';"],
    ["Who developed the 'Smart Inventory' innovation?", "SELECT Author_name FROM Author INNER JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE Jidouka.Improve_name = 'Smart Inventory';"],
    ["How many applications are related to 'Smart Manufacturing'?", "SELECT Applications FROM Jidouka WHERE Improve_name = 'Smart Manufacturing';"],
    ["What is the release time for 'Automated Material Handling'?", "SELECT Release_date FROM Jidouka WHERE Improve_name = 'Automated Material Handling';"],
    ["Can you tell me the history of the internet?", "The internet was first developed in the late 1960s and 1970s by DARPA (Defense Advanced Research Projects Agency) as ARPANET, and later became widely available in the 1990s."],
    ["How many departments worked on 'Robotics Integration'?", "SELECT Department_name FROM Department INNER JOIN Jidouka ON Department.Id = Jidouka.Department_id WHERE Jidouka.Improve_name = 'Robotics Integration';"],
    ["What is the job associated with 'Automated Inspection'?", "SELECT Job_name FROM Job WHERE Job_name = 'Automated Inspection';"],
    ["Who is the creator of 'Automated Testing'?", "SELECT Author_name FROM Author INNER JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE Jidouka.Improve_name = 'Automated Testing';"],
    ["What is the description of 'Automated Sorting'?", "SELECT Description FROM Jidouka WHERE Improve_name = 'Automated Sorting';"],
    ["What product was created with the 'Lean Manufacturing' process?", "SELECT Product_name FROM Jidouka WHERE Improve_name = 'Lean Manufacturing';"],
    ["What department is responsible for 'Automation of Inventory'?", "SELECT Department_name FROM Department INNER JOIN Jidouka ON Department.Id = Jidouka.Department_id WHERE Jidouka.Improve_name = 'Automation of Inventory';"],
    ["How many jobs apply AI-based Monitoring?", "SELECT Applications FROM Jidouka WHERE Improve_name = 'AI-based Monitoring';"],
    ["What is the launch time for 'Smart Factory Implementation'?", "SELECT Release_date FROM Jidouka WHERE Improve_name = 'Smart Factory Implementation';"],
    ["What tools are used for 'Automated Reporting'?", "SELECT Tool_name FROM Tool INNER JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id INNER JOIN Jidouka ON JidoukaTool.Jidouka_id = Jidouka.Id WHERE Jidouka.Improve_name = 'Automated Reporting';"],
    ["What is the job type for 'Task Automation'?", "SELECT Job_name FROM Job WHERE Job_name = 'Task Automation';"],
    ["Can you tell me what is climate change?", "Climate change refers to long-term changes in the temperature, precipitation, and other atmospheric conditions on Earth due to human activity or natural processes."],
    ["How many tasks applied Supply Chain Automation?", "SELECT Applications FROM Jidouka WHERE Improve_name = 'Supply Chain Automation';"],
    ["What is the department responsible for 'Automated Packaging'?", "SELECT Department_name FROM Department INNER JOIN Jidouka ON Department.Id = Jidouka.Department_id WHERE Jidouka.Improve_name = 'Automated Packaging';"],
    ["What tool is associated with 'Energy Conservation'?", "SELECT Tool_name FROM Tool INNER JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id INNER JOIN Jidouka ON JidoukaTool.Jidouka_id = Jidouka.Id WHERE Jidouka.Improve_name = 'Energy Conservation';"],
    ["What is the job name related to 'Production Line Efficiency'?", "SELECT Job_name FROM Job WHERE Job_name = 'Production Line Efficiency';"],
    ["How many applications were involved in 'Automated Reporting'?", "SELECT Applications FROM Jidouka WHERE Improve_name = 'Automated Reporting';"],
    ["What is the launch time for Smart Logistics?", "SELECT Release_date FROM Jidouka WHERE Improve_name = 'Smart Logistics';"],
    ["What is the number of hours saved by 'Lean Manufacturing'?", "SELECT Time FROM Jidouka WHERE Improve_name = 'Lean Manufacturing';"],
    ["Who is responsible for the 'Energy Management' innovation?", "SELECT Author_name FROM Author INNER JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE Jidouka.Improve_name = 'Energy Management';"],
    ["How many departments applied 'Predictive Maintenance'?", "SELECT Department_name FROM Department INNER JOIN Jidouka ON Department.Id = Jidouka.Department_id WHERE Jidouka.Improve_name = 'Predictive Maintenance';"],
    ["What is the description of 'Product Quality Improvement'?", "SELECT Description FROM Jidouka WHERE Improve_name = 'Product Quality Improvement';"],
    ["What product was launched with 'Automated Sorting'?", "SELECT Product_name FROM Jidouka WHERE Improve_name = 'Automated Sorting';"],
    ["How many applications are linked to Smart Automation?", "SELECT Applications FROM Jidouka WHERE Improve_name = 'Smart Automation';"],
    ["What is the department working on 'Manufacturing Automation'?", "SELECT Department_name FROM Department INNER JOIN Jidouka ON Department.Id = Jidouka.Department_id WHERE Jidouka.Improve_name = 'Manufacturing Automation';"],
    ["What is the launch date for 'Robotics in Manufacturing'?", "SELECT Release_date FROM Jidouka WHERE Improve_name = 'Robotics in Manufacturing';"],
    ["Who is the author of 'Productivity Boost'?", "SELECT Author_name FROM Author INNER JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE Jidouka.Improve_name = 'Productivity Boost';"],
    ["What is the description of 'AI in Logistics'?", "SELECT Description FROM Jidouka WHERE Improve_name = 'AI in Logistics';"],
    ["What is the description of the 'Digital Transformation' innovation?", "SELECT Description FROM Jidouka WHERE Improve_name = 'Digital Transformation';"],
    ["Who is the author of 'Predictive Analytics'?", "SELECT Author_name FROM Author INNER JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE Jidouka.Improve_name = 'Predictive Analytics';"],
    ["How many applications were used in 'Automated Scheduling'?", "SELECT Applications FROM Jidouka WHERE Improve_name = 'Automated Scheduling';"],
    ["What is the release time for 'Smart Manufacturing Systems'?", "SELECT Release_date FROM Jidouka WHERE Improve_name = 'Smart Manufacturing Systems';"],
    ["What is the product name for 'AI-powered Production'?", "SELECT Product_name FROM Jidouka WHERE Improve_name = 'AI-powered Production';"],
    ["What department is working on 'Automated Material Handling'?", "SELECT Department_name FROM Department INNER JOIN Jidouka ON Department.Id = Jidouka.Department_id WHERE Jidouka.Improve_name = 'Automated Material Handling';"],
    ["Who is responsible for 'Automated Task Management'?", "SELECT Author_name FROM Author INNER JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE Jidouka.Improve_name = 'Automated Task Management';"],
    ["What tools are used in 'Smart Factory Optimization'?", "SELECT Tool_name FROM Tool INNER JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id INNER JOIN Jidouka ON JidoukaTool.Jidouka_id = Jidouka.Id WHERE Jidouka.Improve_name = 'Smart Factory Optimization';"],
    ["How many hours were saved by 'Optimized Workflow'?", "SELECT Time FROM Jidouka WHERE Improve_name = 'Optimized Workflow';"],
    ["What is the department responsible for 'AI Manufacturing'?", "SELECT Department_name FROM Department INNER JOIN Jidouka ON Department.Id = Jidouka.Department_id WHERE Jidouka.Improve_name = 'AI Manufacturing';"],
    ["What is the job associated with 'Cloud Integration'?", "SELECT Job_name FROM Job WHERE Job_name = 'Cloud Integration';"],
    ["What is the product name for 'Automation in Packaging'?", "SELECT Product_name FROM Jidouka WHERE Improve_name = 'Automation in Packaging';"],
    ["Who is the creator of 'Industrial Internet of Things'?", "SELECT Author_name FROM Author INNER JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE Jidouka.Improve_name = 'Industrial Internet of Things';"],
    ["What is the description of 'Advanced Robotics'?", "SELECT Description FROM Jidouka WHERE Improve_name = 'Advanced Robotics';"],
    ["What is the launch date for 'Augmented Reality in Manufacturing'?", "SELECT Release_date FROM Jidouka WHERE Improve_name = 'Augmented Reality in Manufacturing';"],
    ["Can you tell me who invented the lightbulb?", "Thomas Edison is commonly credited with inventing the practical lightbulb in 1879."],
    ["How many jobs applied 'Smart Logistics'?", "SELECT Applications FROM Jidouka WHERE Improve_name = 'Smart Logistics';"],
    ["What is the tool used for 'Smart Production'?", "SELECT Tool_name FROM Tool INNER JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id INNER JOIN Jidouka ON JidoukaTool.Jidouka_id = Jidouka.Id WHERE Jidouka.Improve_name = 'Smart Production';"],
    ["What department is responsible for 'AI-based Scheduling'?", "SELECT Department_name FROM Department INNER JOIN Jidouka ON Department.Id = Jidouka.Department_id WHERE Jidouka.Improve_name = 'AI-based Scheduling';"],
    ["What job is related to 'Predictive Maintenance'?", "SELECT Job_name FROM Job WHERE Job_name = 'Predictive Maintenance';"],
    ["What is the saved time for 'Automated Process Control'?", "SELECT Time FROM Jidouka WHERE Improve_name = 'Automated Process Control';"],
    ["Who developed the 'Data-Driven Manufacturing' innovation?", "SELECT Author_name FROM Author INNER JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE Jidouka.Improve_name = 'Data-Driven Manufacturing';"],
    ["How many applications are associated with 'Supply Chain Optimization'?", "SELECT Applications FROM Jidouka WHERE Improve_name = 'Supply Chain Optimization';"],
    ["What is the launch time for 'Robotics in Logistics'?", "SELECT Release_date FROM Jidouka WHERE Improve_name = 'Robotics in Logistics';"],
    ["What is the product associated with 'Smart Production'?", "SELECT Product_name FROM Jidouka WHERE Improve_name = 'Smart Production';"],
    ["What department is responsible for 'Production Line Optimization'?", "SELECT Department_name FROM Department INNER JOIN Jidouka ON Department.Id = Jidouka.Department_id WHERE Jidouka.Improve_name = 'Production Line Optimization';"],
    ["How many tasks used 'AI-driven Analytics'?", "SELECT Applications FROM Jidouka WHERE Improve_name = 'AI-driven Analytics';"],
    ["What tool is used in 'Automated Testing'?", "SELECT Tool_name FROM Tool INNER JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id INNER JOIN Jidouka ON JidoukaTool.Jidouka_id = Jidouka.Id WHERE Jidouka.Improve_name = 'Automated Testing';"],
    ["What is the job name for 'Workplace Automation'?", "SELECT Job_name FROM Job WHERE Job_name = 'Workplace Automation';"],
    ["How many applications used 'Robotics in Production'?", "SELECT Applications FROM Jidouka WHERE Improve_name = 'Robotics in Production';"],
    ["What is the product for 'Automated Sorting'?", "SELECT Product_name FROM Jidouka WHERE Improve_name = 'Automated Sorting';"],
    ["Can you explain the concept of artificial intelligence?", "Artificial intelligence (AI) is the simulation of human intelligence in machines that are programmed to think, learn, and solve problems."],
    ["How many departments worked on 'Digital Manufacturing'?", "SELECT Department_name FROM Department INNER JOIN Jidouka ON Department.Id = Jidouka.Department_id WHERE Jidouka.Improve_name = 'Digital Manufacturing';"],
    ["What is the release date for 'Cloud-based Automation'?", "SELECT Release_date FROM Jidouka WHERE Improve_name = 'Cloud-based Automation';"],
    ["What is the job related to 'AI-enabled Automation'?", "SELECT Job_name FROM Job WHERE Job_name = 'AI-enabled Automation';"],
    ["How many applications were associated with 'Factory Automation'?", "SELECT Applications FROM Jidouka WHERE Improve_name = 'Factory Automation';"],
    ["Who is the author of 'Industrial Automation'?", "SELECT Author_name FROM Author INNER JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE Jidouka.Improve_name = 'Industrial Automation';"],
    ["What is the saved time for 'Machine Learning in Manufacturing'?", "SELECT Time FROM Jidouka WHERE Improve_name = 'Machine Learning in Manufacturing';"],
    ["What department is responsible for 'Factory Digitalization'?", "SELECT Department_name FROM Department INNER JOIN Jidouka ON Department.Id = Jidouka.Department_id WHERE Jidouka.Improve_name = 'Factory Digitalization';"],
    ["How many tasks implemented 'Real-Time Data Processing'?", "SELECT Applications FROM Jidouka WHERE Improve_name = 'Real-Time Data Processing';"],
    ["What is the product name for 'Automated Quality Control'?", "SELECT Product_name FROM Jidouka WHERE Improve_name = 'Automated Quality Control';"],
    ["What tools are used for 'Predictive Analytics'?", "SELECT Tool_name FROM Tool INNER JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id INNER JOIN Jidouka ON JidoukaTool.Jidouka_id = Jidouka.Id WHERE Jidouka.Improve_name = 'Predictive Analytics';"],
    ["What is the launch time for 'Advanced Manufacturing Systems'?", "SELECT Release_date FROM Jidouka WHERE Improve_name = 'Advanced Manufacturing Systems';"],
    ["How many jobs implemented 'Energy-efficient Systems'?", "SELECT Applications FROM Jidouka WHERE Improve_name = 'Energy-efficient Systems';"],
    ["What is the description of 'Smart Automation'?", "SELECT Description FROM Jidouka WHERE Improve_name = 'Smart Automation';"],
    ["Who is the creator of 'Autonomous Robotics'?", "SELECT Author_name FROM Author INNER JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE Jidouka.Improve_name = 'Autonomous Robotics';"],
    ["What is the saved time for 'Energy Management'?", "SELECT Time FROM Jidouka WHERE Improve_name = 'Energy Management';"],
    ["What is the job name for 'Automated Warehouse Management'?", "SELECT Job_name FROM Job WHERE Job_name = 'Automated Warehouse Management';"],
    ["What is the tool used in 'Industrial Automation'?", "SELECT Tool_name FROM Tool INNER JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id INNER JOIN Jidouka ON JidoukaTool.Jidouka_id = Jidouka.Id WHERE Jidouka.Improve_name = 'Industrial Automation';"],
    ["What is the product associated with 'Advanced Robotics'?", "SELECT Product_name FROM Jidouka WHERE Improve_name = 'Advanced Robotics';"],
    ["How many applications used Smart Logistics?", "SELECT Applications FROM Jidouka WHERE Improve_name = 'Smart Logistics';"],
    ["What is the job associated with 'Automated Inventory Management'?", "SELECT Job_name FROM Job WHERE Job_name = 'Automated Inventory Management';"],
    ["How many applications used 'Predictive Maintenance in Production'?", "SELECT Applications FROM Jidouka WHERE Improve_name = 'Predictive Maintenance in Production';"],
    ["Who is the author of 'AI in Robotics'?", "SELECT Author_name FROM Author INNER JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE Jidouka.Improve_name = 'AI in Robotics';"],
    ["What is the description of 'Smart Factory'?", "SELECT Description FROM Jidouka WHERE Improve_name = 'Smart Factory';"],
    ["What is the launch time for 'IoT in Manufacturing'?", "SELECT Release_date FROM Jidouka WHERE Improve_name = 'IoT in Manufacturing';"],
    ["What department is responsible for 'Blockchain in Supply Chain'?", "SELECT Department_name FROM Department INNER JOIN Jidouka ON Department.Id = Jidouka.Department_id WHERE Jidouka.Improve_name = 'Blockchain in Supply Chain';"],
    ["What is the product name associated with 'Automated Manufacturing'?", "SELECT Product_name FROM Jidouka WHERE Improve_name = 'Automated Manufacturing';"],
    ["How many hours were saved by 'Supply Chain Automation'?", "SELECT Time FROM Jidouka WHERE Improve_name = 'Supply Chain Automation';"],
    ["What tool is used in 'Data Analytics for Manufacturing'?", "SELECT Tool_name FROM Tool INNER JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id INNER JOIN Jidouka ON JidoukaTool.Jidouka_id = Jidouka.Id WHERE Jidouka.Improve_name = 'Data Analytics for Manufacturing';"],
    ["What department is working on 'Robotic Process Automation'?", "SELECT Department_name FROM Department INNER JOIN Jidouka ON Department.Id = Jidouka.Department_id WHERE Jidouka.Improve_name = 'Robotic Process Automation';"],
    ["Who is the author of 'Advanced AI Techniques'?", "SELECT Author_name FROM Author INNER JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE Jidouka.Improve_name = 'Advanced AI Techniques';"],
    ["What job is associated with 'Energy Efficiency in Production'?", "SELECT Job_name FROM Job WHERE Job_name = 'Energy Efficiency in Production';"],
    ["What is the description of 'Cloud Manufacturing'?", "SELECT Description FROM Jidouka WHERE Improve_name = 'Cloud Manufacturing';"],
    ["What is the product name for 'Next-Gen Manufacturing Solutions'?", "SELECT Product_name FROM Jidouka WHERE Improve_name = 'Next-Gen Manufacturing Solutions';"],
    ["What tools are used for 'Smart Warehouse Management'?", "SELECT Tool_name FROM Tool INNER JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id INNER JOIN Jidouka ON JidoukaTool.Jidouka_id = Jidouka.Id WHERE Jidouka.Improve_name = 'Smart Warehouse Management';"],
    ["How many tasks applied 'Predictive Analytics in Manufacturing'?", "SELECT Applications FROM Jidouka WHERE Improve_name = 'Predictive Analytics in Manufacturing';"],
    ["What is the launch time for 'AI Manufacturing Systems'?", "SELECT Release_date FROM Jidouka WHERE Improve_name = 'AI Manufacturing Systems';"],
    ["What department is working on 'Automation in Supply Chain'?", "SELECT Department_name FROM Department INNER JOIN Jidouka ON Department.Id = Jidouka.Department_id WHERE Jidouka.Improve_name = 'Automation in Supply Chain';"],
    ["What is the product name for 'Robotic Arms in Manufacturing'?", "SELECT Product_name FROM Jidouka WHERE Improve_name = 'Robotic Arms in Manufacturing';"],
    ["Who is the author of 'Data Science in Manufacturing'?", "SELECT Author_name FROM Author INNER JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE Jidouka.Improve_name = 'Data Science in Manufacturing';"],
    ["What is the saved time for 'Smart Inventory Management'?", "SELECT Time FROM Jidouka WHERE Improve_name = 'Smart Inventory Management';"],
    ["What is the job associated with 'Cybersecurity in Manufacturing'?", "SELECT Job_name FROM Job WHERE Job_name = 'Cybersecurity in Manufacturing';"],
    ["What is the launch date for 'AI-driven Automation'?", "SELECT Release_date FROM Jidouka WHERE Improve_name = 'AI-driven Automation';"],
    ["What tools are used in 'Advanced Robotics Integration'?", "SELECT Tool_name FROM Tool INNER JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id INNER JOIN Jidouka ON JidoukaTool.Jidouka_id = Jidouka.Id WHERE Jidouka.Improve_name = 'Advanced Robotics Integration';"],
    ["How many applications were used for 'Machine Learning in Manufacturing'?", "SELECT Applications FROM Jidouka WHERE Improve_name = 'Machine Learning in Manufacturing';"],
    ["What is the department working on 'Factory Automation'?", "SELECT Department_name FROM Department INNER JOIN Jidouka ON Department.Id = Jidouka.Department_id WHERE Jidouka.Improve_name = 'Factory Automation';"],
    ["What is the product associated with 'Blockchain in Manufacturing'?", "SELECT Product_name FROM Jidouka WHERE Improve_name = 'Blockchain in Manufacturing';"],
    ["What is the job for 'Intelligent Manufacturing'?", "SELECT Job_name FROM Job WHERE Job_name = 'Intelligent Manufacturing';"],
    ["How many applications were involved in 'Smart Factory Implementation'?", "SELECT Applications FROM Jidouka WHERE Improve_name = 'Smart Factory Implementation';"],
    ["What is the saved time for 'AI for Process Optimization'?", "SELECT Time FROM Jidouka WHERE Improve_name = 'AI for Process Optimization';"],
    ["What is the launch time for 'Automation in Packaging'?", "SELECT Release_date FROM Jidouka WHERE Improve_name = 'Automation in Packaging';"],
    ["What is the tool used for 'Autonomous Quality Control'?", "SELECT Tool_name FROM Tool INNER JOIN JidoukaTool ON Tool.Id = JidoukaTool.Tool_id INNER JOIN Jidouka ON JidoukaTool.Jidouka_id = Jidouka.Id WHERE Jidouka.Improve_name = 'Autonomous Quality Control';"],
    ["What department is working on 'Digital Twin Technology'?", "SELECT Department_name FROM Department INNER JOIN Jidouka ON Department.Id = Jidouka.Department_id WHERE Jidouka.Improve_name = 'Digital Twin Technology';"],
    ["How many jobs implemented 'Smart Production Line'?", "SELECT Applications FROM Jidouka WHERE Improve_name = 'Smart Production Line';"],
    ["Who is the creator of 'IoT-based Production Systems'?", "SELECT Author_name FROM Author INNER JOIN Jidouka ON Author.Id = Jidouka.Author_id WHERE Jidouka.Improve_name = 'IoT-based Production Systems';"],
    ["What is the saved time for 'Robotics in Assembly'?", "SELECT Time FROM Jidouka WHERE Improve_name = 'Robotics in Assembly';"],
    ["What is the description of 'Machine Learning for Process Control'?", "SELECT Description FROM Jidouka WHERE Improve_name = 'Machine Learning for Process Control';"],
]

# %%
data = [
    ["Find jidouka improvements with more than 5 tools?","SELECT Jidouka.Improve_name FROM Jidouka JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id GROUP BY Jidouka.Id HAVING COUNT(JidoukaTool.Tool_id) > 5;"]
    ["Find improvements that used more than 5 tools?","SELECT Jidouka.Improve_name FROM Jidouka JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id GROUP BY Jidouka.Id HAVING COUNT(JidoukaTool.Tool_id) > 5;"]
    ["Find innovations with more than 3 tools?","SELECT Jidouka.Improve_name FROM Jidouka JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id GROUP BY Jidouka.Id HAVING COUNT(JidoukaTool.Tool_id) > 3;"]
    ["Find jidouka improvements that used at least 2 tools?","SELECT Jidouka.Improve_name FROM Jidouka JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id GROUP BY Jidouka.Id HAVING COUNT(JidoukaTool.Tool_id) > 2;"]    
    ["Find innovation that used less than 2 tools?","SELECT Jidouka.Improve_name FROM Jidouka JOIN JidoukaTool ON Jidouka.Id = JidoukaTool.Jidouka_id GROUP BY Jidouka.Id HAVING COUNT(JidoukaTool.Tool_id) < 2;"]
]

# %%
len(data)
# Out:
# 1009

# %%
import re
def modify_query(query):
    modified_query = re.sub(r"= '([^']*)'", r"LIKE LOWER('%\1%')", query)
    return modified_query

# %%
data2 = []
for i in range(len(data)):
    lst = []
    lst.append(data[i][0])
    lst.append(modify_query(data[i][1]))
    data2.append(lst)

# %%
dct = {'question':[], 'answer':[]}
for i in range(len(data2)):
    dct['question'].append(data[i][0])
    dct['answer'].append(data2[i][1])

# %%
import pandas as pd 
df3 = pd.DataFrame(dct)

# %%
df3.to_csv('output1009_records_english_multitableJidouka2.0.csv', index=False)
