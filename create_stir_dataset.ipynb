# %%
context = """ 
You are an SQL query assistant. Based on the table information below, generate an SQL query to retrieve the relevant information for the user. If the user’s question is unrelated to the table, respond naturally in user's language.

The jidouka table contains the following columns:

id: Row identifier (int)
tên_cải_tiến: Name of the improvement (str)
loại_hình_công_việc: Type of work that the improvement is intended to enhance (str) (e.g., database processing, data entry, workflow optimization, etc.)
công_cụ: Tool used to achieve the improvement (str) (e.g., Python, Excel, Visual Studio Code, etc.)
mô_tả: Detailed description of the improvement (str) (e.g., each step of the improvement process)
sản_phẩm: Output product of the improvement (str) (e.g., .csv file, .xlsx file, etc.)
tác_giả: Contributor, company employee, or creator of the improvement (str)
bộ_phận: Department of the author, usually referred to as "dc" (str) (e.g., dc1, dc2, dc3, dcd, souko, etc.)
số_giờ: Number of hours saved by applying the improvement (int)
số_công_việc_áp_dụng: Number of tasks in the company that the improvement has supported (int)
thời_điểm_ra_mắt: Launch date of the tool (str) (e.g., 2024-10-11, 2024-10-09, etc.)
thông_tin_thêm: Link to additional documentation (PowerPoint, video) on using the improvement or the improvement’s tool (str)
"""

# %%
data = [
   ["What improvements were launched on October 11, 2024?", "SELECT * FROM jidouka WHERE thời_điểm_ra_mắt = '2024-10-11';"],
    ["List all improvements using Python as the tool.", "SELECT * FROM jidouka WHERE công_cụ = 'Python';"],
    ["Which improvements have saved more than 100 hours?", "SELECT * FROM jidouka WHERE số_giờ > 100;"],
    ["Show all improvements created by dc2 department.", "SELECT * FROM jidouka WHERE bộ_phận = 'dc2';"],
    ["How many improvements resulted in .csv files?", "SELECT COUNT(*) FROM jidouka WHERE sản_phẩm = '.csv file';"],
    ["Who created the improvement named 'Workflow Optimization'?", "SELECT tác_giả FROM jidouka WHERE tên_cải_tiến = 'Workflow Optimization';"],
    ["What are some tools used for improvements?", "SELECT DISTINCT công_cụ FROM jidouka;"],
    ["How many tasks did the 'Data Entry Enhancement' improvement support?", "SELECT số_công_việc_áp_dụng FROM jidouka WHERE tên_cải_tiến = 'Data Entry Enhancement';"],
    ["List improvements with launch dates in 2023.", "SELECT * FROM jidouka WHERE thời_điểm_ra_mắt LIKE '2023%';"],
    ["How many improvements are there in total?", "SELECT COUNT(*) FROM jidouka;"],
    
    # Unrelated questions (answered)
    ["What is the capital of Japan?", "The capital of Japan is Tokyo."],
    ["How many continents are there?", "There are seven continents on Earth."],
    ["What year did World War II end?", "World War II ended in 1945."],
    ["Who is the author of 'Pride and Prejudice'?", "The author of 'Pride and Prejudice' is Jane Austen."],
    ["How does photosynthesis work?", "Photosynthesis is the process by which plants convert sunlight into energy."],
    ["What’s the largest mammal?", "The blue whale is the largest mammal on Earth."],
    ["What is gravity?", "Gravity is the force that attracts two bodies toward each other."],
    ["How do airplanes fly?", "Airplanes fly due to the lift generated by their wings."],
    ["What is the boiling point of water?", "Water boils at 100°C (212°F) at sea level."],
    ["How many days are there in a leap year?", "A leap year has 366 days."],
    
    # Unrelated questions (unsure)
    ["What is the meaning of life?", "I'm not sure."],
    ["Is there life on other planets?", "I don't know."],
    ["Can you predict the stock market?", "I'm not sure about that."],
    ["What will the weather be like in 50 years?", "I can't say for sure."],
    ["How do we achieve world peace?", "That's a difficult question, and I'm not sure."],
    ["Why are we here?", "I don't know."],
    ["Is time travel possible?", "I'm not certain."],
    ["What happens after we die?", "I can't answer that."],
    ["Is artificial intelligence conscious?", "I'm not sure."],
    ["What is the purpose of art?", "I'm not certain about that."],
    
    # More SQL-related questions
    ["How many hours has the 'Excel Automation' improvement saved?", "SELECT số_giờ FROM jidouka WHERE tên_cải_tiến = 'Excel Automation';"],
    ["Which department has the most improvements?", "SELECT bộ_phận, COUNT(*) FROM jidouka GROUP BY bộ_phận ORDER BY COUNT(*) DESC LIMIT 1;"],
    ["List improvements related to database processing.", "SELECT * FROM jidouka WHERE loại_hình_công_việc = 'database processing';"],
    ["What improvements were launched before 2024?", "SELECT * FROM jidouka WHERE thời_điểm_ra_mắt < '2024-01-01';"],
    ["How many improvements have a PowerPoint link in additional information?", "SELECT COUNT(*) FROM jidouka WHERE thông_tin_thêm LIKE '%.ppt%';"],
    ["Show all improvements from souko department.", "SELECT * FROM jidouka WHERE bộ_phận = 'souko';"],
    ["What is the total number of hours saved across all improvements?", "SELECT SUM(số_giờ) FROM jidouka;"],
    ["Which improvement supports the most tasks?", "SELECT tên_cải_tiến FROM jidouka ORDER BY số_công_việc_áp_dụng DESC LIMIT 1;"],
    ["List improvements with detailed descriptions containing 'optimization'.", "SELECT * FROM jidouka WHERE mô_tả LIKE '%optimization%';"],
    ["Who contributed to the most improvements?", "SELECT tác_giả, COUNT(*) FROM jidouka GROUP BY tác_giả ORDER BY COUNT(*) DESC LIMIT 1;"],
    
    # More unrelated questions (mix of answered and unsure)
    ["Who painted the Mona Lisa?", "The Mona Lisa was painted by Leonardo da Vinci."],
    ["What is the speed of light?", "The speed of light is approximately 299,792 kilometers per second."],
    ["Who was the first human in space?", "Yuri Gagarin was the first human in space."],
    ["What is quantum computing?", "Quantum computing is a type of computing that uses quantum mechanics principles."],
    ["How do black holes form?", "Black holes form when massive stars collapse under their own gravity."],
    ["What is consciousness?", "I'm not sure how to define consciousness precisely."],
    ["Are there other universes?", "I don't know if there are other universes."],
    ["What causes human emotions?", "Human emotions are complex and influenced by both biological and psychological factors."],
    ["What is string theory?", "String theory is a theoretical framework where particles are one-dimensional 'strings' rather than points."],
    ["Is there a multiverse?", "The multiverse is a hypothesis, but its existence is uncertain."],

        ["List all improvements made by dc1 department.", "SELECT * FROM jidouka WHERE bộ_phận = 'dc1';"],
    ["Show improvements that have saved at least 50 hours.", "SELECT * FROM jidouka WHERE số_giờ >= 50;"],
    ["Find all improvements related to workflow optimization.", "SELECT * FROM jidouka WHERE loại_hình_công_việc = 'workflow optimization';"],
    ["List improvements launched after September 2024.", "SELECT * FROM jidouka WHERE thời_điểm_ra_mắt > '2024-09-30';"],
    ["Show all improvements that produced .xlsx files.", "SELECT * FROM jidouka WHERE sản_phẩm = '.xlsx file';"],
    ["Which improvements were created by souko department?", "SELECT * FROM jidouka WHERE bộ_phận = 'souko';"],
    ["How many improvements used Visual Studio Code as a tool?", "SELECT COUNT(*) FROM jidouka WHERE công_cụ = 'Visual Studio Code';"],
    ["Find improvements that contributed to more than 10 tasks.", "SELECT * FROM jidouka WHERE số_công_việc_áp_dụng > 10;"],
    ["List all improvements that were launched in 2024.", "SELECT * FROM jidouka WHERE thời_điểm_ra_mắt LIKE '2024%';"],
    ["Show improvements that have no additional information link.", "SELECT * FROM jidouka WHERE thông_tin_thêm IS NULL OR thông_tin_thêm = '';"],
    
    ["Which departments contributed to improvements?", "SELECT DISTINCT bộ_phận FROM jidouka;"],
    ["Find improvements where the description contains 'automation'.", "SELECT * FROM jidouka WHERE mô_tả LIKE '%automation%';"],
    ["What is the average number of hours saved by all improvements?", "SELECT AVG(số_giờ) FROM jidouka;"],
    ["List improvements with name starting with 'Data'.", "SELECT * FROM jidouka WHERE tên_cải_tiến LIKE 'Data%';"],
    ["How many hours did dc3 department save through their improvements?", "SELECT SUM(số_giờ) FROM jidouka WHERE bộ_phận = 'dc3';"],
    ["Show improvements launched in the month of October.", "SELECT * FROM jidouka WHERE thời_điểm_ra_mắt LIKE '____-10-%';"],
    ["List all improvements related to data entry tasks.", "SELECT * FROM jidouka WHERE loại_hình_công_việc = 'data entry';"],
    ["How many improvements were launched before 2023?", "SELECT COUNT(*) FROM jidouka WHERE thời_điểm_ra_mắt < '2023-01-01';"],
    ["Show improvements that save less than 10 hours.", "SELECT * FROM jidouka WHERE số_giờ < 10;"],
    ["List all contributors who used Excel as a tool.", "SELECT DISTINCT tác_giả FROM jidouka WHERE công_cụ = 'Excel';"],
    
    ["Find improvements from dcd department that saved over 200 hours.", "SELECT * FROM jidouka WHERE bộ_phận = 'dcd' AND số_giờ > 200;"],
    ["How many improvements are linked to additional information files?", "SELECT COUNT(*) FROM jidouka WHERE thông_tin_thêm IS NOT NULL AND thông_tin_thêm != '';"],
    ["List all improvements by contributors named 'Nguyen'.", "SELECT * FROM jidouka WHERE tác_giả LIKE 'Nguyen%';"],
    ["What are the top 5 improvements with the highest number of tasks supported?", "SELECT * FROM jidouka ORDER BY số_công_việc_áp_dụng DESC LIMIT 5;"],
    ["List improvements that were created using Python or Excel.", "SELECT * FROM jidouka WHERE công_cụ = 'Python' OR công_cụ = 'Excel';"],
    ["Find all improvements that saved exactly 50 hours.", "SELECT * FROM jidouka WHERE số_giờ = 50;"],
    ["List improvements with the name containing the word 'Automation'.", "SELECT * FROM jidouka WHERE tên_cải_tiến LIKE '%Automation%';"],
    ["Which contributors from dc1 saved the most hours?", "SELECT tác_giả FROM jidouka WHERE bộ_phận = 'dc1' ORDER BY số_giờ DESC LIMIT 1;"],
    ["Show all improvements related to database processing.", "SELECT * FROM jidouka WHERE loại_hình_công_việc = 'database processing';"],
    ["List improvements created by contributors from dc2 department that supported at least 5 tasks.", "SELECT * FROM jidouka WHERE bộ_phận = 'dc2' AND số_công_việc_áp_dụng >= 5;"],
    
    ["How many improvements were launched in 2022?", "SELECT COUNT(*) FROM jidouka WHERE thời_điểm_ra_mắt LIKE '2022%';"],
    ["Find improvements with description containing 'error reduction'.", "SELECT * FROM jidouka WHERE mô_tả LIKE '%error reduction%';"],
    ["List improvements launched in the first quarter of 2024.", "SELECT * FROM jidouka WHERE thời_điểm_ra_mắt BETWEEN '2024-01-01' AND '2024-03-31';"],
    ["What is the total number of tasks supported by all improvements?", "SELECT SUM(số_công_việc_áp_dụng) FROM jidouka;"],
    ["Show all improvements that were launched after '2023-06-01'.", "SELECT * FROM jidouka WHERE thời_điểm_ra_mắt > '2023-06-01';"],
    ["List all improvements from dcd department related to Python.", "SELECT * FROM jidouka WHERE bộ_phận = 'dcd' AND công_cụ = 'Python';"],
    ["Find improvements that created .xlsx files and saved at least 20 hours.", "SELECT * FROM jidouka WHERE sản_phẩm = '.xlsx file' AND số_giờ >= 20;"],
    ["List all unique types of tool used.", "SELECT DISTINCT công_cụ FROM jidouka;"],
    ["What is the most recent improvement by dc3 department?", "SELECT * FROM jidouka WHERE bộ_phận = 'dc3' ORDER BY thời_điểm_ra_mắt DESC LIMIT 1;"],
    ["Find all improvements that contain 'optimization' in tên_cải_tiến.", "SELECT * FROM jidouka WHERE tên_cải_tiến LIKE '%optimization%';"],
    
    ["How many hours has the improvement 'Database Automation' saved?", "SELECT số_giờ FROM jidouka WHERE tên_cải_tiến = 'Database Automation';"],
    ["List improvements that used either Excel or Visual Studio Code.", "SELECT * FROM jidouka WHERE công_cụ = 'Excel' OR công_cụ = 'Visual Studio Code';"],
    ["What is the oldest improvement in the table?", "SELECT * FROM jidouka ORDER BY thời_điểm_ra_mắt ASC LIMIT 1;"],
    ["Find improvements created by multiple contributors.", "SELECT tác_giả, COUNT(*) FROM jidouka GROUP BY tác_giả HAVING COUNT(*) > 1;"],
    ["List all improvements that saved between 20 and 40 hours.", "SELECT * FROM jidouka WHERE số_giờ BETWEEN 20 AND 40;"],
    ["How many improvements produced a .csv file?", "SELECT COUNT(*) FROM jidouka WHERE sản_phẩm = '.csv file';"],
    ["Find improvements that have supported exactly 10 tasks.", "SELECT * FROM jidouka WHERE số_công_việc_áp_dụng = 10;"],
    ["List all improvements with description containing the phrase 'process improvement'.", "SELECT * FROM jidouka WHERE mô_tả LIKE '%process improvement%';"],
    ["Which department has the fewest improvements?", "SELECT bộ_phận, COUNT(*) FROM jidouka GROUP BY bộ_phận ORDER BY COUNT(*) ASC LIMIT 1;"],
    ["Show improvements created by dc1 that launched after June 2024.", "SELECT * FROM jidouka WHERE bộ_phận = 'dc1' AND thời_điểm_ra_mắt > '2024-06-30';"],
    
    ["Find all improvements from the year 2021.", "SELECT * FROM jidouka WHERE thời_điểm_ra_mắt LIKE '2021%';"],
    ["List improvements related to 'data analysis' using any tool.", "SELECT * FROM jidouka WHERE loại_hình_công_việc = 'data analysis';"],
    ["Show improvements by dc3 that are documented in a video.", "SELECT * FROM jidouka WHERE bộ_phận = 'dc3' AND thông_tin_thêm LIKE '%.mp4%';"],
    ["Find all improvements with name containing 'Report'.", "SELECT * FROM jidouka WHERE tên_cải_tiến LIKE '%Report%';"],
    ["How many contributors have worked on improvements?", "SELECT COUNT(DISTINCT tác_giả) FROM jidouka;"],
    ["List all improvements launched on a Friday in 2024.", "SELECT * FROM jidouka WHERE thời_điểm_ra_mắt IN (SELECT thời_điểm_ra_mắt FROM jidouka WHERE DAYOFWEEK(thời_điểm_ra_mắt) = 6);"],
    ["Find improvements from dcd related to workflow optimization.", "SELECT * FROM jidouka WHERE bộ_phận = 'dcd' AND loại_hình_công_việc = 'workflow optimization';"],
    ["How many hours did dc1 save in total?", "SELECT SUM(số_giờ) FROM jidouka WHERE bộ_phận = 'dc1';"],
    ["List improvements that supported tasks in multiple departments.", "SELECT * FROM jidouka WHERE số_công_việc_áp_dụng > 1;"],
    ["Which contributor has saved the most hours overall?", "SELECT tác_giả, SUM(số_giờ) FROM jidouka GROUP BY tác_giả ORDER BY SUM(số_giờ) DESC LIMIT 1;"],
    
    ["Show all improvements launched in the fourth quarter of 2023.", "SELECT * FROM jidouka WHERE thời_điểm_ra_mắt BETWEEN '2023-10-01' AND '2023-12-31';"],
    ["List improvements with description containing 'efficiency'.", "SELECT * FROM jidouka WHERE mô_tả LIKE '%efficiency%';"],
    ["How many improvements were launched in the second half of 2024?", "SELECT COUNT(*) FROM jidouka WHERE thời_điểm_ra_mắt >= '2024-07-01';"],
    ["Show improvements created with Python that launched in 2023.", "SELECT * FROM jidouka WHERE công_cụ = 'Python' AND thời_điểm_ra_mắt LIKE '2023%';"],
    ["Find improvements where product includes '.pdf' files.", "SELECT * FROM jidouka WHERE sản_phẩm = '.pdf';"],
    ["List all improvements by dc2 that used automation as a tool.", "SELECT * FROM jidouka WHERE bộ_phận = 'dc2' AND công_cụ = 'automation';"],
    ["Show the improvement with the earliest launch date by dc3.", "SELECT * FROM jidouka WHERE bộ_phận = 'dc3' ORDER BY thời_điểm_ra_mắt ASC LIMIT 1;"],
    ["Find all improvements with 'management' in name.", "SELECT * FROM jidouka WHERE tên_cải_tiến LIKE '%management%';"],
    ["How many improvements have saved between 50 and 100 hours?", "SELECT COUNT(*) FROM jidouka WHERE số_giờ BETWEEN 50 AND 100;"],
    ["List the name of all improvements created by dc1 and launched in 2024.", "SELECT tên_cải_tiến FROM jidouka WHERE bộ_phận = 'dc1' AND thời_điểm_ra_mắt LIKE '2024%';"],

    ["List all innovations created by contributors from the design center dc1.", "SELECT * FROM jidouka WHERE bộ_phận = 'dc1';"],
    ["Show improvements launched in 2024 that used Python as a toolkit.", "SELECT * FROM jidouka WHERE thời_điểm_ra_mắt LIKE '2024%' AND công_cụ = 'Python';"],
    ["Find all tasks in the workflow optimization category.", "SELECT * FROM jidouka WHERE loại_hình_công_việc = 'workflow optimization';"],
    ["Which contributors from dcd saved over 50 hours?", "SELECT tác_giả FROM jidouka WHERE bộ_phận = 'dcd' AND số_giờ > 50;"],
    ["How many saved hours did dc1 achieve overall?", "SELECT SUM(số_giờ) FROM jidouka WHERE bộ_phận = 'dc1';"],
    ["Show innovations with a description that includes 'automation'.", "SELECT * FROM jidouka WHERE mô_tả LIKE '%automation%';"],
    ["Which department launched the most number of innovations?", "SELECT bộ_phận, COUNT(*) AS total FROM jidouka GROUP BY bộ_phận ORDER BY total DESC LIMIT 1;"],
    ["List improvements launched in the first quarter of 2023.", "SELECT * FROM jidouka WHERE thời_điểm_ra_mắt BETWEEN '2023-01-01' AND '2023-03-31';"],
    ["Find the total number of hours saved across all innovations by contributors in dc3.", "SELECT SUM(số_giờ) FROM jidouka WHERE bộ_phận = 'dc3';"],
    ["Which task types are most common in innovations?", "SELECT loại_hình_công_việc, COUNT(*) AS frequency FROM jidouka GROUP BY loại_hình_công_việc ORDER BY frequency DESC;"],
    
    ["List all innovations with more than 20 jobs supported.", "SELECT * FROM jidouka WHERE số_công_việc_áp_dụng > 20;"],
    ["Show all improvements created with Excel as the gadget.", "SELECT * FROM jidouka WHERE công_cụ = 'Excel';"],
    ["Find contributors from the department dc2 with saved hours above 100.", "SELECT tác_giả FROM jidouka WHERE bộ_phận = 'dc2' AND số_giờ > 100;"],
    ["Which task type has the most saved hours recorded?", "SELECT loại_hình_công_việc, SUM(số_giờ) AS total_saved FROM jidouka GROUP BY loại_hình_công_việc ORDER BY total_saved DESC LIMIT 1;"],
    ["Find all products that generated .csv files as output.", "SELECT * FROM jidouka WHERE sản_phẩm = '.csv file';"],
    ["How many innovations were launched before 2023 by contributors in the dc1 department?", "SELECT COUNT(*) FROM jidouka WHERE thời_điểm_ra_mắt < '2023-01-01' AND bộ_phận = 'dc1';"],
    ["List all jobs supported by improvements in the design center dcd.", "SELECT số_công_việc_áp_dụng FROM jidouka WHERE bộ_phận = 'dcd';"],
    ["Show saved hours for each contributor who used Python as a tool.", "SELECT tác_giả, số_giờ FROM jidouka WHERE công_cụ = 'Python';"],
    ["List innovations that saved at least 25 hours and are related to quality control.", "SELECT * FROM jidouka WHERE số_giờ >= 25 AND loại_hình_công_việc = 'quality control';"],
    ["What is the average number of work supported by dc2 innovations?", "SELECT AVG(số_công_việc_áp_dụng) FROM jidouka WHERE bộ_phận = 'dc2';"],
    
    ["Find improvements from 2024 that saved over 10 hours.", "SELECT * FROM jidouka WHERE thời_điểm_ra_mắt LIKE '2024%' AND số_giờ > 10;"],
    ["How many contributors are there in total across all departments?", "SELECT COUNT(DISTINCT tác_giả) FROM jidouka;"],
    ["List all innovations with launch dates in January.", "SELECT * FROM jidouka WHERE thời_điểm_ra_mắt LIKE '____-01-%';"],
    ["What were the most frequently used gadgets in 2023?", "SELECT công_cụ, COUNT(*) FROM jidouka WHERE thời_điểm_ra_mắt LIKE '2023%' GROUP BY công_cụ ORDER BY COUNT(*) DESC;"],
    ["Show all contributors who used Visual Studio Code as their device.", "SELECT tác_giả FROM jidouka WHERE công_cụ = 'Visual Studio Code';"],
    ["List all improvements with a detail line containing 'data entry'.", "SELECT * FROM jidouka WHERE mô_tả LIKE '%data entry%';"],
    ["Find all departments and total hours saved by each.", "SELECT bộ_phận, SUM(số_giờ) FROM jidouka GROUP BY bộ_phận;"],
    ["Show all contributors from dcd who have supported more than 5 tasks.", "SELECT tác_giả FROM jidouka WHERE bộ_phận = 'dcd' AND số_công_việc_áp_dụng > 5;"],
    ["List all launch dates for improvements that saved more than 100 hours.", "SELECT thời_điểm_ra_mắt FROM jidouka WHERE số_giờ > 100;"],
    ["Find improvements with descriptions mentioning 'workflow'.", "SELECT * FROM jidouka WHERE mô_tả LIKE '%workflow%';"],
    
    ["How many unique tools have been used across all improvements?", "SELECT COUNT(DISTINCT công_cụ) FROM jidouka;"],
    ["Show contributors who created more than 3 innovations.", "SELECT tác_giả, COUNT(*) FROM jidouka GROUP BY tác_giả HAVING COUNT(*) > 3;"],
    ["List all tasks from dc3 that were launched after 2023.", "SELECT * FROM jidouka WHERE bộ_phận = 'dc3' AND thời_điểm_ra_mắt > '2023-12-31';"],
    ["How many tasks are associated with contributors from dc2?", "SELECT SUM(số_công_việc_áp_dụng) FROM jidouka WHERE bộ_phận = 'dc2';"],
    ["Find all improvements with products in .xlsx format.", "SELECT * FROM jidouka WHERE sản_phẩm = '.xlsx file';"],
    ["List all improvements with saved hours greater than the average.", "SELECT * FROM jidouka WHERE số_giờ > (SELECT AVG(số_giờ) FROM jidouka);"],
    ["Show all contributors who launched improvements in February 2024.", "SELECT tác_giả FROM jidouka WHERE thời_điểm_ra_mắt LIKE '2024-02-%';"],
    ["List tools used in all innovations launched after January 1, 2024.", "SELECT DISTINCT công_cụ FROM jidouka WHERE thời_điểm_ra_mắt > '2024-01-01';"],
    ["Find all contributors from the souko department who saved over 30 hours.", "SELECT tác_giả FROM jidouka WHERE bộ_phận = 'souko' AND số_giờ > 30;"],
    ["List the types of task associated with dc1 improvements.", "SELECT DISTINCT loại_hình_công_việc FROM jidouka WHERE bộ_phận = 'dc1';"],
    
    ["Show all products created with Excel as a gadget.", "SELECT sản_phẩm FROM jidouka WHERE công_cụ = 'Excel';"],
    ["How many jobs have dc3 improvements contributed to?", "SELECT SUM(số_công_việc_áp_dụng) FROM jidouka WHERE bộ_phận = 'dc3';"],
    ["List innovations by contributors from dcd with descriptions containing 'cost saving'.", "SELECT * FROM jidouka WHERE bộ_phận = 'dcd' AND mô_tả LIKE '%cost saving%';"],
    ["Which improvement from dc1 saved the most hours?", "SELECT * FROM jidouka WHERE bộ_phận = 'dc1' ORDER BY số_giờ DESC LIMIT 1;"],
    ["Show all departments that have innovations launched before 2022.", "SELECT DISTINCT bộ_phận FROM jidouka WHERE thời_điểm_ra_mắt < '2022-01-01';"],
    ["Find the total saved hours for innovations launched in the last quarter of 2023.", "SELECT SUM(số_giờ) FROM jidouka WHERE thời_điểm_ra_mắt BETWEEN '2023-10-01' AND '2023-12-31';"],
    ["List all descriptions for innovations that saved over 40 hours.", "SELECT mô_tả FROM jidouka WHERE số_giờ > 40;"],
    ["Show all contributors who worked on innovations related to 'database processing'.", "SELECT tác_giả FROM jidouka WHERE loại_hình_công_việc = 'database processing';"],
    ["Find all products with saved hours under 10 from dc1.", "SELECT sản_phẩm FROM jidouka WHERE số_giờ < 10 AND bộ_phận = 'dc1';"],
    ["List all improvements by dc2 contributors launched in 2022.", "SELECT * FROM jidouka WHERE bộ_phận = 'dc2' AND thời_điểm_ra_mắt LIKE '2022%';"],
        ["Find all contributors who worked on innovations using the tool Python.", "SELECT tác_giả FROM jidouka WHERE công_cụ = 'Python';"],
    ["List all improvements in the quality assurance task type that saved more than 20 hours.", "SELECT * FROM jidouka WHERE loại_hình_công_việc = 'quality assurance' AND số_giờ > 20;"],
    ["Show all products created by the dc2 department.", "SELECT sản_phẩm FROM jidouka WHERE bộ_phận = 'dc2';"],
    ["Which contributors from the dc1 department saved more than 10 hours?", "SELECT tác_giả FROM jidouka WHERE bộ_phận = 'dc1' AND số_giờ > 10;"],
    ["List all innovations that were launched in 2023.", "SELECT * FROM jidouka WHERE thời_điểm_ra_mắt LIKE '2023%';"],
    ["Show saved hours for improvements using Excel as a toolkit.", "SELECT số_giờ FROM jidouka WHERE công_cụ = 'Excel';"],
    ["Find contributors in dc3 who have supported more than 15 jobs.", "SELECT tác_giả FROM jidouka WHERE bộ_phận = 'dc3' AND số_công_việc_áp_dụng > 15;"],
    ["List improvements with descriptions mentioning 'cost efficiency'.", "SELECT * FROM jidouka WHERE mô_tả LIKE '%cost efficiency%';"],
    ["How many contributors from dcd launched innovations in 2024?", "SELECT COUNT(DISTINCT tác_giả) FROM jidouka WHERE bộ_phận = 'dcd' AND thời_điểm_ra_mắt LIKE '2024%';"],
    ["What are the most common task types for innovations?", "SELECT loại_hình_công_việc, COUNT(*) AS count FROM jidouka GROUP BY loại_hình_công_việc ORDER BY count DESC;"],
    
    ["Show all gadgets used in innovations that saved more than 30 hours.", "SELECT DISTINCT công_cụ FROM jidouka WHERE số_giờ > 30;"],
    ["Find improvements with saved hours exceeding the average for dc2.", "SELECT * FROM jidouka WHERE số_giờ > (SELECT AVG(số_giờ) FROM jidouka WHERE bộ_phận = 'dc2');"],
    ["List all improvements launched before 2023 with over 50 saved hours.", "SELECT * FROM jidouka WHERE thời_điểm_ra_mắt < '2023-01-01' AND số_giờ > 50;"],
    ["Show the contributor and department for each innovation related to data entry.", "SELECT tác_giả, bộ_phận FROM jidouka WHERE loại_hình_công_việc = 'data entry';"],
    ["Find all products created by contributors from design center dc1.", "SELECT sản_phẩm FROM jidouka WHERE bộ_phận = 'dc1';"],
    ["How many innovations related to workflow optimization were launched in 2022?", "SELECT COUNT(*) FROM jidouka WHERE loại_hình_công_việc = 'workflow optimization' AND thời_điểm_ra_mắt LIKE '2022%';"],
    ["List all contributors with innovations that saved between 20 and 50 hours.", "SELECT tác_giả FROM jidouka WHERE số_giờ BETWEEN 20 AND 50;"],
    ["Show improvements by dc2 that have supported more than 10 tasks.", "SELECT * FROM jidouka WHERE bộ_phận = 'dc2' AND số_công_việc_áp_dụng > 10;"],
    ["List all jobs supported by contributors in the souko department.", "SELECT số_công_việc_áp_dụng FROM jidouka WHERE bộ_phận = 'souko';"],
    ["Which task type had the highest number of saved hours in dc3?", "SELECT loại_hình_công_việc, SUM(số_giờ) AS total_hours FROM jidouka WHERE bộ_phận = 'dc3' GROUP BY loại_hình_công_việc ORDER BY total_hours DESC LIMIT 1;"],
    
    ["List all gadgets used in innovations from 2023.", "SELECT DISTINCT công_cụ FROM jidouka WHERE thời_điểm_ra_mắt LIKE '2023%';"],
    ["Show innovations created by contributors from dc1 in January 2024.", "SELECT * FROM jidouka WHERE bộ_phận = 'dc1' AND thời_điểm_ra_mắt LIKE '2024-01%';"],
    ["Find all descriptions mentioning 'optimization'.", "SELECT mô_tả FROM jidouka WHERE mô_tả LIKE '%optimization%';"],
    ["How many improvements involved Python as the toolkit?", "SELECT COUNT(*) FROM jidouka WHERE công_cụ = 'Python';"],
    ["List all launch dates for innovations that saved over 60 hours.", "SELECT thời_điểm_ra_mắt FROM jidouka WHERE số_giờ > 60;"],
    ["Show contributors from dc3 with innovations launched after June 2024.", "SELECT tác_giả FROM jidouka WHERE bộ_phận = 'dc3' AND thời_điểm_ra_mắt > '2024-06-30';"],
    ["List the number of work supported by contributors from dcd.", "SELECT số_công_việc_áp_dụng FROM jidouka WHERE bộ_phận = 'dcd';"],
    ["Find all innovations created with Tableau as a device.", "SELECT * FROM jidouka WHERE công_cụ = 'Tableau';"],
    ["How many unique contributors are there in dc2?", "SELECT COUNT(DISTINCT tác_giả) FROM jidouka WHERE bộ_phận = 'dc2';"],
    ["List all task types for improvements launched in 2024.", "SELECT DISTINCT loại_hình_công_việc FROM jidouka WHERE thời_điểm_ra_mắt LIKE '2024%';"],
    
    ["Find the total number of tasks supported by dc1 contributors.", "SELECT SUM(số_công_việc_áp_dụng) FROM jidouka WHERE bộ_phận = 'dc1';"],
    ["How many contributors from dcd saved more than 40 hours?", "SELECT COUNT(DISTINCT tác_giả) FROM jidouka WHERE bộ_phận = 'dcd' AND số_giờ > 40;"],
    ["List all descriptions containing 'data processing'.", "SELECT mô_tả FROM jidouka WHERE mô_tả LIKE '%data processing%';"],
    ["Show the saved hours for each innovation by contributors in dc1.", "SELECT số_giờ FROM jidouka WHERE bộ_phận = 'dc1';"],
    ["How many gadgets were used across all innovations?", "SELECT COUNT(DISTINCT công_cụ) FROM jidouka;"],
    ["Find all improvements launched in the second half of 2023.", "SELECT * FROM jidouka WHERE thời_điểm_ra_mắt BETWEEN '2023-07-01' AND '2023-12-31';"],
    ["List all contributors who created innovations that saved more than 100 hours.", "SELECT DISTINCT tác_giả FROM jidouka WHERE số_giờ > 100;"],
    ["Show products from dc2 with saved hours over 15.", "SELECT sản_phẩm FROM jidouka WHERE bộ_phận = 'dc2' AND số_giờ > 15;"],
    ["List all launch dates for improvements by dc3.", "SELECT thời_điểm_ra_mắt FROM jidouka WHERE bộ_phận = 'dc3';"],
    ["How many improvements were made in the 'report generation' task type?", "SELECT COUNT(*) FROM jidouka WHERE loại_hình_công_việc = 'report generation';"],
    
    ["Show improvements created by contributors in dc3 using Excel.", "SELECT * FROM jidouka WHERE bộ_phận = 'dc3' AND công_cụ = 'Excel';"],
    ["Find all contributors who used a toolkit other than Python.", "SELECT DISTINCT tác_giả FROM jidouka WHERE công_cụ <> 'Python';"],
    ["How many contributors from dc2 have supported fewer than 10 jobs?", "SELECT COUNT(DISTINCT tác_giả) FROM jidouka WHERE bộ_phận = 'dc2' AND số_công_việc_áp_dụng < 10;"],
    ["List all task types for improvements launched in December 2023.", "SELECT DISTINCT loại_hình_công_việc FROM jidouka WHERE thời_điểm_ra_mắt LIKE '2023-12%';"],
    ["Show all contributors who created improvements using Python.", "SELECT DISTINCT tác_giả FROM jidouka WHERE công_cụ = 'Python';"],
    ["List all products generated by innovations in dc1 with saved hours above 20.", "SELECT sản_phẩm FROM jidouka WHERE bộ_phận = 'dc1' AND số_giờ > 20;"],
    ["Find all launch dates for innovations that supported more than 5 jobs.", "SELECT thời_điểm_ra_mắt FROM jidouka WHERE số_công_việc_áp_dụng > 5;"],
    ["How many contributors in dc1 saved between 10 and 30 hours?", "SELECT COUNT(DISTINCT tác_giả) FROM jidouka WHERE bộ_phận = 'dc1' AND số_giờ BETWEEN 10 AND 30;"],
    ["List all innovations with descriptions containing 'automation'.", "SELECT * FROM jidouka WHERE mô_tả LIKE '%automation%';"],
    ["Show all saved hours for improvements launched before 2023.", "SELECT số_giờ FROM jidouka WHERE thời_điểm_ra_mắt < '2023-01-01';"],
    
    ["How many improvements were launched by dc2 in the first quarter of 2023?", "SELECT COUNT(*) FROM jidouka WHERE bộ_phận = 'dc2' AND thời_điểm_ra_mắt BETWEEN '2023-01-01' AND '2023-03-31';"],
    ["List all contributors from dc3 who launched innovations in 2022.", "SELECT DISTINCT tác_giả FROM jidouka WHERE bộ_phận = 'dc3' AND thời_điểm_ra_mắt LIKE '2022%';"],
    ["Find all tools used by contributors in the souko department.", "SELECT DISTINCT công_cụ FROM jidouka WHERE bộ_phận = 'souko';"],
    ["Show all improvements with a launch time in the month of March.", "SELECT * FROM jidouka WHERE thời_điểm_ra_mắt LIKE '____-03%';"],
    ["List contributors from dc1 with innovations saving over 25 hours.", "SELECT DISTINCT tác_giả FROM jidouka WHERE bộ_phận = 'dc1' AND số_giờ > 25;"],
    ["How many gadgets were used across innovations from dc2?", "SELECT COUNT(DISTINCT công_cụ) FROM jidouka WHERE bộ_phận = 'dc2';"],
    ["Find all products created with over 50 saved hours.", "SELECT sản_phẩm FROM jidouka WHERE số_giờ > 50;"],
    ["Show all improvements by contributors in dcd launched after 2023.", "SELECT * FROM jidouka WHERE bộ_phận = 'dcd' AND thời_điểm_ra_mắt > '2023-12-31';"],
    ["List all task types for contributors from dc3.", "SELECT DISTINCT loại_hình_công_việc FROM jidouka WHERE bộ_phận = 'dc3';"],
    ["Find all contributors who created improvements with 'process optimization' in the description.", "SELECT DISTINCT tác_giả FROM jidouka WHERE mô_tả LIKE '%process optimization%';"],

        ["List all improvements related to workflow automation that saved more than 30 hours.", "SELECT * FROM jidouka WHERE loại_hình_công_việc = 'workflow automation' AND số_giờ > 30;"],
    ["Find contributors who have worked on innovations using Excel and Python.", "SELECT DISTINCT tác_giả FROM jidouka WHERE công_cụ IN ('Excel', 'Python');"],
    ["Show all products created by contributors in the souko department.", "SELECT sản_phẩm FROM jidouka WHERE bộ_phận = 'souko';"],
    ["List all innovations launched in 2024 that are related to data processing.", "SELECT * FROM jidouka WHERE thời_điểm_ra_mắt LIKE '2024%' AND loại_hình_công_việc = 'data processing';"],
    ["How many contributors in dc2 launched innovations using Python?", "SELECT COUNT(DISTINCT tác_giả) FROM jidouka WHERE bộ_phận = 'dc2' AND công_cụ = 'Python';"],
    ["Find all products created by improvements launched before 2023.", "SELECT sản_phẩm FROM jidouka WHERE thời_điểm_ra_mắt < '2023-01-01';"],
    ["Show improvements launched in the second quarter of 2023 that supported over 10 tasks.", "SELECT * FROM jidouka WHERE thời_điểm_ra_mắt BETWEEN '2023-04-01' AND '2023-06-30' AND số_công_việc_áp_dụng > 10;"],
    ["List innovations in dc3 launched in the month of November.", "SELECT * FROM jidouka WHERE bộ_phận = 'dc3' AND thời_điểm_ra_mắt LIKE '2023-11%';"],
    ["Show all improvements by contributors from dcd that used Excel as the toolkit.", "SELECT * FROM jidouka WHERE bộ_phận = 'dcd' AND công_cụ = 'Excel';"],
    ["How many innovations launched in 2024 were related to report generation?", "SELECT COUNT(*) FROM jidouka WHERE thời_điểm_ra_mắt LIKE '2024%' AND loại_hình_công_việc = 'report generation';"],
    
    ["List all contributors from dc1 who worked on improvements saving more than 15 hours.", "SELECT DISTINCT tác_giả FROM jidouka WHERE bộ_phận = 'dc1' AND số_giờ > 15;"],
    ["Find all innovations launched by contributors from souko department in 2023.", "SELECT * FROM jidouka WHERE bộ_phận = 'souko' AND thời_điểm_ra_mắt LIKE '2023%';"],
    ["List all saved hours for improvements launched in 2022 in dc3.", "SELECT số_giờ FROM jidouka WHERE bộ_phận = 'dc3' AND thời_điểm_ra_mắt LIKE '2022%';"],
    ["Find all tools used for innovations that saved more than 50 hours.", "SELECT DISTINCT công_cụ FROM jidouka WHERE số_giờ > 50;"],
    ["Show innovations from 2024 that have descriptions mentioning 'efficiency'.", "SELECT * FROM jidouka WHERE thời_điểm_ra_mắt LIKE '2024%' AND mô_tả LIKE '%efficiency%';"],
    ["How many innovations in the task type of data entry were launched in 2023?", "SELECT COUNT(*) FROM jidouka WHERE loại_hình_công_việc = 'data entry' AND thời_điểm_ra_mắt LIKE '2023%';"],
    ["List all improvements created by contributors in dcd with saved hours above 25.", "SELECT * FROM jidouka WHERE bộ_phận = 'dcd' AND số_giờ > 25;"],
    ["Show products generated by improvements launched after 2023.", "SELECT sản_phẩm FROM jidouka WHERE thời_điểm_ra_mắt > '2023-12-31';"],
    ["Find contributors from dc1 who supported more than 20 jobs.", "SELECT DISTINCT tác_giả FROM jidouka WHERE bộ_phận = 'dc1' AND số_công_việc_áp_dụng > 20;"],
    
    ["List all innovations in dc2 with saved hours over 100.", "SELECT * FROM jidouka WHERE bộ_phận = 'dc2' AND số_giờ > 100;"],
    ["Show all task types for innovations created in 2024.", "SELECT DISTINCT loại_hình_công_việc FROM jidouka WHERE thời_điểm_ra_mắt LIKE '2024%';"],
    ["How many products were generated by contributors using Visual Studio Code as a tool?", "SELECT COUNT(*) FROM jidouka WHERE công_cụ = 'Visual Studio Code';"],
    ["List all improvements launched in 2022 that used Python as a toolkit.", "SELECT * FROM jidouka WHERE thời_điểm_ra_mắt LIKE '2022%' AND công_cụ = 'Python';"],
    ["Find all innovations with descriptions including 'automation' that saved over 50 hours.", "SELECT * FROM jidouka WHERE mô_tả LIKE '%automation%' AND số_giờ > 50;"],
    ["Show contributors from dc3 who worked on innovations launched in the first quarter of 2024.", "SELECT DISTINCT tác_giả FROM jidouka WHERE bộ_phận = 'dc3' AND thời_điểm_ra_mắt BETWEEN '2024-01-01' AND '2024-03-31';"],
    ["How many improvements launched in 2023 saved fewer than 10 hours?", "SELECT COUNT(*) FROM jidouka WHERE thời_điểm_ra_mắt LIKE '2023%' AND số_giờ < 10;"],
    ["List all innovations that supported more than 30 jobs.", "SELECT * FROM jidouka WHERE số_công_việc_áp_dụng > 30;"],
    
    ["Find all contributors from dc2 who launched improvements with the product '.xlsx'.", "SELECT DISTINCT tác_giả FROM jidouka WHERE bộ_phận = 'dc2' AND sản_phẩm = '.xlsx';"],
    ["Show innovations launched before 2023 by contributors in dc1.", "SELECT * FROM jidouka WHERE bộ_phận = 'dc1' AND thời_điểm_ra_mắt < '2023-01-01';"],
    ["List all task types for innovations launched in the last quarter of 2023.", "SELECT DISTINCT loại_hình_công_việc FROM jidouka WHERE thời_điểm_ra_mắt BETWEEN '2023-10-01' AND '2023-12-31';"],
    ["Find all tools used by contributors in dc1 who saved more than 50 hours.", "SELECT DISTINCT công_cụ FROM jidouka WHERE bộ_phận = 'dc1' AND số_giờ > 50;"],
    ["How many innovations created by contributors in souko department saved between 10 and 20 hours?", "SELECT COUNT(*) FROM jidouka WHERE bộ_phận = 'souko' AND số_giờ BETWEEN 10 AND 20;"],
    ["Show all innovations with 'quality improvement' in their description.", "SELECT * FROM jidouka WHERE mô_tả LIKE '%quality improvement%';"],
    ["Find all innovations related to the 'data analysis' task type.", "SELECT * FROM jidouka WHERE loại_hình_công_việc = 'data analysis';"],
    ["How many products were created using Tableau?", "SELECT COUNT(*) FROM jidouka WHERE công_cụ = 'Tableau';"],
    ["List all improvements by contributors from dc3 that supported fewer than 5 jobs.", "SELECT * FROM jidouka WHERE bộ_phận = 'dc3' AND số_công_việc_áp_dụng < 5;"],
    
    ["Find contributors who worked on innovations using Python or Excel as the toolkit.", "SELECT DISTINCT tác_giả FROM jidouka WHERE công_cụ IN ('Python', 'Excel');"],
    ["Show all improvements launched by contributors from dc2 in March 2024.", "SELECT * FROM jidouka WHERE bộ_phận = 'dc2' AND thời_điểm_ra_mắt LIKE '2024-03%';"],
    ["How many improvements saved more than 40 hours and were launched after 2022?", "SELECT COUNT(*) FROM jidouka WHERE số_giờ > 40 AND thời_điểm_ra_mắt > '2022-12-31';"],
    ["List all task types that had saved hours greater than the average for dc1.", "SELECT DISTINCT loại_hình_công_việc FROM jidouka WHERE số_giờ > (SELECT AVG(số_giờ) FROM jidouka WHERE bộ_phận = 'dc1');"],
    ["Show products created by improvements launched after 2024.", "SELECT sản_phẩm FROM jidouka WHERE thời_điểm_ra_mắt > '2024-01-01';"],
    ["Find all improvements with 'database optimization' in their description.", "SELECT * FROM jidouka WHERE mô_tả LIKE '%database optimization%';"],
    ["List all contributors from dc1 who launched improvements that saved more than 15 hours.", "SELECT DISTINCT tác_giả FROM jidouka WHERE bộ_phận = 'dc1' AND số_giờ > 15;"],
    ["How many innovations from 2023 were related to process automation?", "SELECT COUNT(*) FROM jidouka WHERE thời_điểm_ra_mắt LIKE '2023%' AND loại_hình_công_việc = 'process automation';"],
    ["Show improvements launched by dc2 with descriptions mentioning 'data entry'.", "SELECT * FROM jidouka WHERE bộ_phận = 'dc2' AND mô_tả LIKE '%data entry%';"],
    ["List all task types that have a saved hour count higher than 20.", "SELECT DISTINCT loại_hình_công_việc FROM jidouka WHERE số_giờ > 20;"],

    ["Show all innovations from dc2 that saved more than 30 hours.", "SELECT * FROM jidouka WHERE bộ_phận = 'dc2' AND số_giờ > 30;"],
    ["Find all task types related to process optimization launched in 2023.", "SELECT DISTINCT loại_hình_công_việc FROM jidouka WHERE loại_hình_công_việc LIKE '%process optimization%' AND thời_điểm_ra_mắt LIKE '2023%';"],
    ["List contributors from dc3 who worked on improvements launched in Q1 2024.", "SELECT DISTINCT tác_giả FROM jidouka WHERE bộ_phận = 'dc3' AND thời_điểm_ra_mắt BETWEEN '2024-01-01' AND '2024-03-31';"],
    ["How many products were created with saved hours greater than 50?", "SELECT COUNT(*) FROM jidouka WHERE số_giờ > 50;"],
    ["Show all improvements with 'automation' mentioned in the description launched in 2022.", "SELECT * FROM jidouka WHERE mô_tả LIKE '%automation%' AND thời_điểm_ra_mắt LIKE '2022%';"],
    ["List innovations launched in the month of June 2024.", "SELECT * FROM jidouka WHERE thời_điểm_ra_mắt LIKE '2024-06%';"],
    ["Find all tools used for improvements created by contributors in the souko department.", "SELECT DISTINCT công_cụ FROM jidouka WHERE bộ_phận = 'souko';"],
    ["How many improvements in the 'data entry' task type saved between 10 and 50 hours?", "SELECT COUNT(*) FROM jidouka WHERE loại_hình_công_việc = 'data entry' AND số_giờ BETWEEN 10 AND 50;"],
    ["Show all products created using Python.", "SELECT sản_phẩm FROM jidouka WHERE công_cụ = 'Python';"],
    ["List all innovations from dc1 with saved hours greater than 100.", "SELECT * FROM jidouka WHERE bộ_phận = 'dc1' AND số_giờ > 100;"],
    
    ["How many innovations in 2023 were related to report generation?", "SELECT COUNT(*) FROM jidouka WHERE thời_điểm_ra_mắt LIKE '2023%' AND loại_hình_công_việc = 'report generation';"],
    ["Find all improvements with descriptions including 'quality improvement' launched in 2024.", "SELECT * FROM jidouka WHERE mô_tả LIKE '%quality improvement%' AND thời_điểm_ra_mắt LIKE '2024%';"],
    ["Show contributors who worked on innovations that supported more than 20 jobs.", "SELECT DISTINCT tác_giả FROM jidouka WHERE số_công_việc_áp_dụng > 20;"],
    ["List all task types for innovations created by dc2 in 2023.", "SELECT DISTINCT loại_hình_công_việc FROM jidouka WHERE bộ_phận = 'dc2' AND thời_điểm_ra_mắt LIKE '2023%';"],
    ["How many improvements launched in 2024 supported more than 50 jobs?", "SELECT COUNT(*) FROM jidouka WHERE thời_điểm_ra_mắt LIKE '2024%' AND số_công_việc_áp_dụng > 50;"],
    ["Find all tools used for innovations that launched before 2023.", "SELECT DISTINCT công_cụ FROM jidouka WHERE thời_điểm_ra_mắt < '2023-01-01';"],
    ["List all contributors from dc1 who saved more than 40 hours.", "SELECT DISTINCT tác_giả FROM jidouka WHERE bộ_phận = 'dc1' AND số_giờ > 40;"],
    ["How many products were generated by innovations that launched in the month of May?", "SELECT COUNT(*) FROM jidouka WHERE thời_điểm_ra_mắt LIKE '____-05%' AND sản_phẩm IS NOT NULL;"],
    ["Show all innovations that used Excel and saved over 20 hours.", "SELECT * FROM jidouka WHERE công_cụ = 'Excel' AND số_giờ > 20;"],
    
    ["Find all improvements created by contributors in dcd department that used Python.", "SELECT * FROM jidouka WHERE bộ_phận = 'dcd' AND công_cụ = 'Python';"],
    ["List all task types with a saved hour count greater than 50.", "SELECT DISTINCT loại_hình_công_việc FROM jidouka WHERE số_giờ > 50;"],
    ["Show innovations from 2023 with saved hours over 100.", "SELECT * FROM jidouka WHERE thời_điểm_ra_mắt LIKE '2023%' AND số_giờ > 100;"],
    ["How many improvements from the souko department were launched in the second quarter of 2024?", "SELECT COUNT(*) FROM jidouka WHERE bộ_phận = 'souko' AND thời_điểm_ra_mắt BETWEEN '2024-04-01' AND '2024-06-30';"],
    ["Find all products created using Visual Studio Code.", "SELECT sản_phẩm FROM jidouka WHERE công_cụ = 'Visual Studio Code';"],
    ["List all innovations that supported fewer than 10 tasks.", "SELECT * FROM jidouka WHERE số_công_việc_áp_dụng < 10;"],
    ["Show contributors from dc2 who launched innovations with 'database' in the description.", "SELECT DISTINCT tác_giả FROM jidouka WHERE bộ_phận = 'dc2' AND mô_tả LIKE '%database%';"],
    ["How many innovations from 2024 were related to 'workflow automation'?", "SELECT COUNT(*) FROM jidouka WHERE thời_điểm_ra_mắt LIKE '2024%' AND loại_hình_công_việc = 'workflow automation';"],
    ["List all task types that supported over 20 jobs.", "SELECT DISTINCT loại_hình_công_việc FROM jidouka WHERE số_công_việc_áp_dụng > 20;"],
    
    ["Find contributors from dc1 who worked on improvements launched after 2023.", "SELECT DISTINCT tác_giả FROM jidouka WHERE bộ_phận = 'dc1' AND thời_điểm_ra_mắt > '2023-12-31';"],
    ["Show all products generated by improvements launched in Q1 2024.", "SELECT sản_phẩm FROM jidouka WHERE thời_điểm_ra_mắt BETWEEN '2024-01-01' AND '2024-03-31';"],
    ["List all saved hours for improvements related to data processing in 2022.", "SELECT số_giờ FROM jidouka WHERE loại_hình_công_việc = 'data processing' AND thời_điểm_ra_mắt LIKE '2022%';"],
    ["How many innovations from the souko department used Python?", "SELECT COUNT(*) FROM jidouka WHERE bộ_phận = 'souko' AND công_cụ = 'Python';"],
    ["Show improvements from dc3 launched in the month of April 2023.", "SELECT * FROM jidouka WHERE bộ_phận = 'dc3' AND thời_điểm_ra_mắt LIKE '2023-04%';"],
    ["Find all contributors who worked on innovations launched in 2023 with saved hours greater than 10.", "SELECT DISTINCT tác_giả FROM jidouka WHERE thời_điểm_ra_mắt LIKE '2023%' AND số_giờ > 10;"],
    ["List all innovations that saved more than 30 hours and were launched before 2022.", "SELECT * FROM jidouka WHERE số_giờ > 30 AND thời_điểm_ra_mắt < '2022-01-01';"],
    ["How many task types were there in innovations launched in 2024?", "SELECT COUNT(DISTINCT loại_hình_công_việc) FROM jidouka WHERE thời_điểm_ra_mắt LIKE '2024%';"],
    
    ["Find all improvements with 'optimization' in the description launched in 2023.", "SELECT * FROM jidouka WHERE mô_tả LIKE '%optimization%' AND thời_điểm_ra_mắt LIKE '2023%';"],
    ["Show all improvements by contributors from dc2 that supported more than 15 jobs.", "SELECT * FROM jidouka WHERE bộ_phận = 'dc2' AND số_công_việc_áp_dụng > 15;"],
    ["List all tools used by contributors who saved more than 50 hours in 2024.", "SELECT DISTINCT công_cụ FROM jidouka WHERE số_giờ > 50 AND thời_điểm_ra_mắt LIKE '2024%';"],
    ["Find all contributors who worked on improvements using Excel as the toolkit.", "SELECT DISTINCT tác_giả FROM jidouka WHERE công_cụ = 'Excel';"],
    ["How many innovations launched in 2023 had a description including 'database'?","SELECT COUNT(*) FROM jidouka WHERE mô_tả LIKE '%database%' AND thời_điểm_ra_mắt LIKE '2023%';"],
    ["List all saved hours for innovations created by contributors in dcd.", "SELECT số_giờ FROM jidouka WHERE bộ_phận = 'dcd';"],
    ["Show all improvements from dc1 launched in Q3 2023 that saved over 20 hours.", "SELECT * FROM jidouka WHERE bộ_phận = 'dc1' AND thời_điểm_ra_mắt BETWEEN '2023-07-01' AND '2023-09-30' AND số_giờ > 20;"],
    ["Find all products generated by tools used in task types related to data entry.", "SELECT DISTINCT sản_phẩm FROM jidouka WHERE loại_hình_công_việc = 'data entry' AND công_cụ IS NOT NULL;"],
    ["List all innovations with descriptions mentioning 'workflow automation' that saved more than 30 hours.", "SELECT * FROM jidouka WHERE mô_tả LIKE '%workflow automation%' AND số_giờ > 30;"],
    
    ["Show all improvements that used Excel and were launched in 2023.", "SELECT * FROM jidouka WHERE công_cụ = 'Excel' AND thời_điểm_ra_mắt LIKE '2023%';"],
    ["Find all contributors who worked on improvements supporting more than 20 tasks.", "SELECT DISTINCT tác_giả FROM jidouka WHERE số_công_việc_áp_dụng > 20;"],
    ["How many innovations from dc3 saved fewer than 10 hours?", "SELECT COUNT(*) FROM jidouka WHERE bộ_phận = 'dc3' AND số_giờ < 10;"],
    ["List all improvements created using Visual Studio Code and launched in 2024.", "SELECT * FROM jidouka WHERE công_cụ = 'Visual Studio Code' AND thời_điểm_ra_mắt LIKE '2024%';"],
    ["Find all task types created by dc1 in 2024 that saved more than 40 hours.", "SELECT DISTINCT loại_hình_công_việc FROM jidouka WHERE bộ_phận = 'dc1' AND thời_điểm_ra_mắt LIKE '2024%' AND số_giờ > 40;"],
    ["Show innovations from dc2 with 'tool optimization' mentioned in the description.", "SELECT * FROM jidouka WHERE bộ_phận = 'dc2' AND mô_tả LIKE '%tool optimization%';"],
    ["How many improvements from the souko department saved more than 60 hours?", "SELECT COUNT(*) FROM jidouka WHERE bộ_phận = 'souko' AND số_giờ > 60;"],
    ["Find all innovations from 2024 that were related to 'data automation'.", "SELECT * FROM jidouka WHERE thời_điểm_ra_mắt LIKE '2024%' AND loại_hình_công_việc = 'data automation';"],
    ["Show products created using Python with more than 50 saved hours.", "SELECT sản_phẩm FROM jidouka WHERE công_cụ = 'Python' AND số_giờ > 50;"],
    ["List all improvements launched by dc1 with a saved hour count under 10.", "SELECT * FROM jidouka WHERE bộ_phận = 'dc1' AND số_giờ < 10;"],

        ["Show all innovations from dc2 that saved over 50 hours and supported more than 30 tasks.", "SELECT * FROM jidouka WHERE bộ_phận = 'dc2' AND số_giờ > 50 AND số_công_việc_áp_dụng > 30;"],
    ["Find all task types related to workflow optimization launched in 2024.", "SELECT DISTINCT loại_hình_công_việc FROM jidouka WHERE loại_hình_công_việc LIKE '%workflow optimization%' AND thời_điểm_ra_mắt LIKE '2024%';"],
    ["List products created using Excel with saved hours greater than 40.", "SELECT sản_phẩm FROM jidouka WHERE công_cụ = 'Excel' AND số_giờ > 40;"],
    ["How many improvements launched in Q2 2024 used Python as a tool?", "SELECT COUNT(*) FROM jidouka WHERE thời_điểm_ra_mắt BETWEEN '2024-04-01' AND '2024-06-30' AND công_cụ = 'Python';"],
    ["Show improvements from dc1 that saved more than 100 hours and were related to task types for process optimization.", "SELECT * FROM jidouka WHERE bộ_phận = 'dc1' AND số_giờ > 100 AND loại_hình_công_việc LIKE '%process optimization%';"],
    ["Find all contributors who worked on improvements launched in 2023 that saved fewer than 10 hours.", "SELECT DISTINCT tác_giả FROM jidouka WHERE thời_điểm_ra_mắt LIKE '2023%' AND số_giờ < 10;"],
    ["List all tools used for innovations that supported fewer than 10 tasks.", "SELECT DISTINCT công_cụ FROM jidouka WHERE số_công_việc_áp_dụng < 10;"],
    ["How many improvements launched in 2022 saved over 50 hours?", "SELECT COUNT(*) FROM jidouka WHERE thời_điểm_ra_mắt LIKE '2022%' AND số_giờ > 50;"],
    ["Show all products generated by innovations from dc3 in 2024.", "SELECT sản_phẩm FROM jidouka WHERE bộ_phận = 'dc3' AND thời_điểm_ra_mắt LIKE '2024%' AND sản_phẩm IS NOT NULL;"],
    ["Find all improvements from dc1 related to database processing.", "SELECT * FROM jidouka WHERE bộ_phận = 'dc1' AND loại_hình_công_việc = 'database processing';"],
    
    ["List contributors from dc2 who worked on improvements launched before 2023.", "SELECT DISTINCT tác_giả FROM jidouka WHERE bộ_phận = 'dc2' AND thời_điểm_ra_mắt < '2023-01-01';"],
    ["Show all improvements launched in the last quarter of 2023.", "SELECT * FROM jidouka WHERE thời_điểm_ra_mắt BETWEEN '2023-10-01' AND '2023-12-31';"],
    ["Find all innovations with the term 'workflow automation' mentioned in their description.", "SELECT * FROM jidouka WHERE mô_tả LIKE '%workflow automation%';"],
    ["List all innovations that saved more than 10 hours and supported over 20 tasks.", "SELECT * FROM jidouka WHERE số_giờ > 10 AND số_công_việc_áp_dụng > 20;"],
    ["How many improvements launched by dcd in 2024 are related to data entry?", "SELECT COUNT(*) FROM jidouka WHERE bộ_phận = 'dcd' AND thời_điểm_ra_mắt LIKE '2024%' AND loại_hình_công_việc = 'data entry';"],
    ["Find all contributors from dc1 who worked on innovations supporting more than 30 jobs.", "SELECT DISTINCT tác_giả FROM jidouka WHERE bộ_phận = 'dc1' AND số_công_việc_áp_dụng > 30;"],
    ["Show all improvements from dc2 that saved fewer than 20 hours and were related to task types for data entry.", "SELECT * FROM jidouka WHERE bộ_phận = 'dc2' AND số_giờ < 20 AND loại_hình_công_việc = 'data entry';"],
    ["List all innovations launched in 2024 that supported over 50 tasks.", "SELECT * FROM jidouka WHERE thời_điểm_ra_mắt LIKE '2024%' AND số_công_việc_áp_dụng > 50;"],
    ["How many improvements from souko department saved more than 60 hours?", "SELECT COUNT(*) FROM jidouka WHERE bộ_phận = 'souko' AND số_giờ > 60;"],
    
    ["Find all innovations launched before 2023 that were related to task types like process automation.", "SELECT * FROM jidouka WHERE thời_điểm_ra_mắt < '2023-01-01' AND loại_hình_công_việc LIKE '%process automation%';"],
    ["Show all products created by tools used in task types for data processing.", "SELECT sản_phẩm FROM jidouka WHERE loại_hình_công_việc = 'data processing' AND công_cụ IS NOT NULL;"],
    ["List all improvements from dc1 that saved more than 100 hours and were related to job types like workflow optimization.", "SELECT * FROM jidouka WHERE bộ_phận = 'dc1' AND số_giờ > 100 AND loại_hình_công_việc LIKE '%workflow optimization%';"],
    ["How many products were created using Visual Studio Code in 2024?", "SELECT COUNT(*) FROM jidouka WHERE công_cụ = 'Visual Studio Code' AND thời_điểm_ra_mắt LIKE '2024%' AND sản_phẩm IS NOT NULL;"],
    ["Find all improvements that saved fewer than 10 hours and were launched in 2023.", "SELECT * FROM jidouka WHERE số_giờ < 10 AND thời_điểm_ra_mắt LIKE '2023%';"],
    ["List all task types that saved more than 50 hours.", "SELECT DISTINCT loại_hình_công_việc FROM jidouka WHERE số_giờ > 50;"],
    ["Show all improvements created by dc3 that were related to task types for data processing.", "SELECT * FROM jidouka WHERE bộ_phận = 'dc3' AND loại_hình_công_việc = 'data processing';"],
    ["How many improvements from souko department were launched before 2024?", "SELECT COUNT(*) FROM jidouka WHERE bộ_phận = 'souko' AND thời_điểm_ra_mắt < '2024-01-01';"],
    ["Find all innovations launched in the first quarter of 2024.", "SELECT * FROM jidouka WHERE thời_điểm_ra_mắt BETWEEN '2024-01-01' AND '2024-03-31';"],
    
    ["List all tools used in improvements launched by dc2 in 2023.", "SELECT DISTINCT công_cụ FROM jidouka WHERE bộ_phận = 'dc2' AND thời_điểm_ra_mắt LIKE '2023%';"],
    ["How many improvements in 2024 saved more than 20 hours and were related to task types like data automation?", "SELECT COUNT(*) FROM jidouka WHERE thời_điểm_ra_mắt LIKE '2024%' AND số_giờ > 20 AND loại_hình_công_việc = 'data automation';"],
    ["Show all innovations created by contributors in dc2 with descriptions mentioning 'data entry'.", "SELECT * FROM jidouka WHERE bộ_phận = 'dc2' AND mô_tả LIKE '%data entry%';"],
    ["Find all products from improvements that saved more than 30 hours.", "SELECT sản_phẩm FROM jidouka WHERE số_giờ > 30;"],
    ["List all innovations from dc1 that were related to task types like database processing.", "SELECT * FROM jidouka WHERE bộ_phận = 'dc1' AND loại_hình_công_việc = 'database processing';"],
    ["How many improvements were launched in 2024 by contributors in dcd?", "SELECT COUNT(*) FROM jidouka WHERE thời_điểm_ra_mắt LIKE '2024%' AND bộ_phận = 'dcd';"],
    ["Show all innovations from dc3 that supported more than 10 tasks.", "SELECT * FROM jidouka WHERE bộ_phận = 'dc3' AND số_công_việc_áp_dụng > 10;"],
    ["Find all innovations created by contributors from souko that saved fewer than 20 hours.", "SELECT * FROM jidouka WHERE bộ_phận = 'souko' AND số_giờ < 20;"],
    ["List all task types that were related to product creation in 2023.", "SELECT DISTINCT loại_hình_công_việc FROM jidouka WHERE thời_điểm_ra_mắt LIKE '2023%' AND sản_phẩm IS NOT NULL;"],
    
    ["How many improvements from dc2 were related to toolkits like Excel and saved over 30 hours?", "SELECT COUNT(*) FROM jidouka WHERE bộ_phận = 'dc2' AND công_cụ = 'Excel' AND số_giờ > 30;"],
    ["Show all products created using Python from innovations that saved over 40 hours.", "SELECT sản_phẩm FROM jidouka WHERE công_cụ = 'Python' AND số_giờ > 40;"],
    ["List all task types that supported fewer than 10 tasks in the company.", "SELECT DISTINCT loại_hình_công_việc FROM jidouka WHERE số_công_việc_áp_dụng < 10;"],
    ["Find all improvements from dcd that saved more than 50 hours and were related to workflow optimization.", "SELECT * FROM jidouka WHERE bộ_phận = 'dcd' AND số_giờ > 50 AND loại_hình_công_việc LIKE '%workflow optimization%';"],
    ["How many contributors worked on innovations launched by souko in 2024?", "SELECT COUNT(DISTINCT tác_giả) FROM jidouka WHERE bộ_phận = 'souko' AND thời_điểm_ra_mắt LIKE '2024%';"],
    ["Show all improvements launched in 2024 by dc1 related to task types like database processing.", "SELECT * FROM jidouka WHERE bộ_phận = 'dc1' AND thời_điểm_ra_mắt LIKE '2024%' AND loại_hình_công_việc = 'database processing';"],
    ["Find all tools used by contributors from dc2 that saved fewer than 20 hours.", "SELECT DISTINCT công_cụ FROM jidouka WHERE bộ_phận = 'dc2' AND số_giờ < 20;"],
    ["List improvements launched in 2024 that saved more than 10 hours and were related to data automation.", "SELECT * FROM jidouka WHERE thời_điểm_ra_mắt LIKE '2024%' AND số_giờ > 10 AND loại_hình_công_việc = 'data automation';"],
    ["How many improvements launched by dc1 saved fewer than 10 hours and were related to data entry?", "SELECT COUNT(*) FROM jidouka WHERE bộ_phận = 'dc1' AND số_giờ < 10 AND loại_hình_công_việc = 'data entry';"],

        ["Show all innovations launched by dc1 in 2024 that supported more than 40 tasks.", "SELECT * FROM jidouka WHERE bộ_phận = 'dc1' AND thời_điểm_ra_mắt LIKE '2024%' AND số_công_việc_áp_dụng > 40;"],
    ["Find all tools used by innovations that saved more than 30 hours and supported over 20 tasks.", "SELECT DISTINCT công_cụ FROM jidouka WHERE số_giờ > 30 AND số_công_việc_áp_dụng > 20;"],
    ["How many improvements from souko were related to task types like data processing?", "SELECT COUNT(*) FROM jidouka WHERE bộ_phận = 'souko' AND loại_hình_công_việc = 'data processing';"],
    ["List all products created using Excel from innovations that were launched in 2023.", "SELECT DISTINCT sản_phẩm FROM jidouka WHERE công_cụ = 'Excel' AND thời_điểm_ra_mắt LIKE '2023%';"],
    ["Show all task types that were launched in 2024 and saved more than 50 hours.", "SELECT DISTINCT loại_hình_công_việc FROM jidouka WHERE thời_điểm_ra_mắt LIKE '2024%' AND số_giờ > 50;"],
    ["Find all improvements launched in 2023 that were related to task types like workflow optimization.", "SELECT * FROM jidouka WHERE thời_điểm_ra_mắt LIKE '2023%' AND loại_hình_công_việc = 'workflow optimization';"],
    ["List all improvements from dc2 that saved over 100 hours.", "SELECT * FROM jidouka WHERE bộ_phận = 'dc2' AND số_giờ > 100;"],
    ["How many innovations from dc3 were launched in 2022 and saved more than 30 hours?", "SELECT COUNT(*) FROM jidouka WHERE bộ_phận = 'dc3' AND thời_điểm_ra_mắt LIKE '2022%' AND số_giờ > 30;"],
    ["Show all innovations created using Visual Studio Code in 2024 that saved more than 40 hours.", "SELECT * FROM jidouka WHERE công_cụ = 'Visual Studio Code' AND thời_điểm_ra_mắt LIKE '2024%' AND số_giờ > 40;"],
    ["Find all contributors from dc1 who worked on innovations that were launched before 2023 and saved fewer than 10 hours.", "SELECT DISTINCT tác_giả FROM jidouka WHERE bộ_phận = 'dc1' AND thời_điểm_ra_mắt < '2023-01-01' AND số_giờ < 10;"],
    
    ["List all innovations from souko launched in 2024 that were related to data automation.", "SELECT * FROM jidouka WHERE bộ_phận = 'souko' AND thời_điểm_ra_mắt LIKE '2024%' AND loại_hình_công_việc = 'data automation';"],
    ["How many improvements launched in 2023 supported fewer than 5 tasks?", "SELECT COUNT(*) FROM jidouka WHERE thời_điểm_ra_mắt LIKE '2023%' AND số_công_việc_áp_dụng < 5;"],
    ["Find all products generated by tools used for task types related to database processing.", "SELECT sản_phẩm FROM jidouka WHERE loại_hình_công_việc = 'database processing' AND công_cụ IS NOT NULL;"],
    ["Show all task types launched in 2024 that saved fewer than 20 hours.", "SELECT DISTINCT loại_hình_công_việc FROM jidouka WHERE thời_điểm_ra_mắt LIKE '2024%' AND số_giờ < 20;"],
    ["List all innovations from dc3 with descriptions mentioning 'data entry' and saved more than 50 hours.", "SELECT * FROM jidouka WHERE bộ_phận = 'dc3' AND mô_tả LIKE '%data entry%' AND số_giờ > 50;"],
    ["How many innovations from dc2 were launched after 2023 that saved fewer than 30 hours?", "SELECT COUNT(*) FROM jidouka WHERE bộ_phận = 'dc2' AND thời_điểm_ra_mắt > '2023-01-01' AND số_giờ < 30;"],
    ["Find all improvements that were related to task types for product creation.", "SELECT * FROM jidouka WHERE loại_hình_công_việc LIKE '%product creation%';"],
    ["Show all improvements launched by dc1 that were related to workflow optimization and saved more than 30 hours.", "SELECT * FROM jidouka WHERE bộ_phận = 'dc1' AND loại_hình_công_việc LIKE '%workflow optimization%' AND số_giờ > 30;"],
    ["List all innovations launched in 2023 that saved over 50 hours.", "SELECT * FROM jidouka WHERE thời_điểm_ra_mắt LIKE '2023%' AND số_giờ > 50;"],
    
    ["How many innovations were created using Python as a tool in 2024?", "SELECT COUNT(*) FROM jidouka WHERE công_cụ = 'Python' AND thời_điểm_ra_mắt LIKE '2024%';"],
    ["Find all contributors from dc1 who worked on improvements that saved more than 100 hours and were related to data automation.", "SELECT DISTINCT tác_giả FROM jidouka WHERE bộ_phận = 'dc1' AND số_giờ > 100 AND loại_hình_công_việc = 'data automation';"],
    ["List all products generated by innovations launched in 2024 from the souko department.", "SELECT sản_phẩm FROM jidouka WHERE bộ_phận = 'souko' AND thời_điểm_ra_mắt LIKE '2024%';"],
    ["How many improvements were launched by dc2 in 2023 that saved fewer than 20 hours?", "SELECT COUNT(*) FROM jidouka WHERE bộ_phận = 'dc2' AND thời_điểm_ra_mắt LIKE '2023%' AND số_giờ < 20;"],
    ["Find all innovations from dc3 that were related to data entry and saved more than 40 hours.", "SELECT * FROM jidouka WHERE bộ_phận = 'dc3' AND loại_hình_công_việc = 'data entry' AND số_giờ > 40;"],
    ["List all task types that saved more than 50 hours and were related to toolkits like Python.", "SELECT DISTINCT loại_hình_công_việc FROM jidouka WHERE số_giờ > 50 AND công_cụ = 'Python';"],
    ["How many products were created in 2024 using Visual Studio Code that saved over 20 hours?", "SELECT COUNT(*) FROM jidouka WHERE công_cụ = 'Visual Studio Code' AND thời_điểm_ra_mắt LIKE '2024%' AND số_giờ > 20 AND sản_phẩm IS NOT NULL;"],
    ["Show all innovations that were related to job types like data processing and saved more than 30 hours.", "SELECT * FROM jidouka WHERE loại_hình_công_việc = 'data processing' AND số_giờ > 30;"],
    ["Find all improvements created by contributors in dc2 that were related to task types like database processing.", "SELECT * FROM jidouka WHERE bộ_phận = 'dc2' AND loại_hình_công_việc = 'database processing';"],
    
    ["List all improvements that supported more than 10 tasks and saved over 50 hours.", "SELECT * FROM jidouka WHERE số_công_việc_áp_dụng > 10 AND số_giờ > 50;"],
    ["How many task types related to database processing were launched in 2024?", "SELECT COUNT(DISTINCT loại_hình_công_việc) FROM jidouka WHERE loại_hình_công_việc = 'database processing' AND thời_điểm_ra_mắt LIKE '2024%';"],
    ["Show all innovations from dc1 that saved more than 30 hours and were related to job types like process optimization.", "SELECT * FROM jidouka WHERE bộ_phận = 'dc1' AND số_giờ > 30 AND loại_hình_công_việc LIKE '%process optimization%';"],
    ["List all improvements from souko department that saved fewer than 10 hours and were related to task types like data entry.", "SELECT * FROM jidouka WHERE bộ_phận = 'souko' AND số_giờ < 10 AND loại_hình_công_việc = 'data entry';"],
    ["Find all improvements launched by dcd that were related to workflow automation and saved more than 50 hours.", "SELECT * FROM jidouka WHERE bộ_phận = 'dcd' AND loại_hình_công_việc LIKE '%workflow automation%' AND số_giờ > 50;"],
    ["Show all improvements created using Visual Studio Code in 2024 related to task types like product creation.", "SELECT * FROM jidouka WHERE công_cụ = 'Visual Studio Code' AND thời_điểm_ra_mắt LIKE '2024%' AND loại_hình_công_việc LIKE '%product creation%';"],
    ["List all products generated using Excel by innovations from dc2 in 2023.", "SELECT sản_phẩm FROM jidouka WHERE công_cụ = 'Excel' AND bộ_phận = 'dc2' AND thời_điểm_ra_mắt LIKE '2023%';"],
    ["How many contributors from souko worked on innovations that saved fewer than 10 hours?", "SELECT COUNT(DISTINCT tác_giả) FROM jidouka WHERE bộ_phận = 'souko' AND số_giờ < 10;"],
    ["Find all improvements from dc1 launched in 2024 that saved fewer than 10 hours and were related to task types like data automation.", "SELECT * FROM jidouka WHERE bộ_phận = 'dc1' AND thời_điểm_ra_mắt LIKE '2024%' AND số_giờ < 10 AND loại_hình_công_việc = 'data automation';"],

    ["List all task types launched in 2023 that saved over 100 hours.", "SELECT DISTINCT loại_hình_công_việc FROM jidouka WHERE thời_điểm_ra_mắt LIKE '2023%' AND số_giờ > 100;"],
    ["How many innovations launched by dc1 saved fewer than 20 hours and supported fewer than 5 tasks?", "SELECT COUNT(*) FROM jidouka WHERE bộ_phận = 'dc1' AND số_giờ < 20 AND số_công_việc_áp_dụng < 5;"],
    ["Find all improvements from souko that saved more than 50 hours and were related to data automation.", "SELECT * FROM jidouka WHERE bộ_phận = 'souko' AND số_giờ > 50 AND loại_hình_công_việc = 'data automation';"],
    ["Show all innovations launched before 2023 by dc2 that were related to database processing.", "SELECT * FROM jidouka WHERE bộ_phận = 'dc2' AND thời_điểm_ra_mắt < '2023-01-01' AND loại_hình_công_việc = 'database processing';"],
    ["How many task types related to workflow optimization were launched in 2024 and saved over 40 hours?", "SELECT COUNT(DISTINCT loại_hình_công_việc) FROM jidouka WHERE loại_hình_công_việc = 'workflow optimization' AND thời_điểm_ra_mắt LIKE '2024%' AND số_giờ > 40;"],
    ["Find all improvements that saved over 100 hours and were related to data entry.", "SELECT * FROM jidouka WHERE số_giờ > 100 AND loại_hình_công_việc = 'data entry';"],
    ["List all improvements from souko that saved fewer than 10 hours and were related to toolkits like Python.", "SELECT * FROM jidouka WHERE bộ_phận = 'souko' AND số_giờ < 10 AND công_cụ = 'Python';"],
    ["How many products were created using Excel in 2024 that supported more than 30 tasks?", "SELECT COUNT(*) FROM jidouka WHERE công_cụ = 'Excel' AND thời_điểm_ra_mắt LIKE '2024%' AND số_công_việc_áp_dụng > 30;"],
    ["Show all improvements from dc3 that saved more than 50 hours and were related to data automation.", "SELECT * FROM jidouka WHERE bộ_phận = 'dc3' AND số_giờ > 50 AND loại_hình_công_việc = 'data automation';"],
    ["Find all contributors from dc1 who worked on task types related to data processing and saved fewer than 10 hours.", "SELECT DISTINCT tác_giả FROM jidouka WHERE bộ_phận = 'dc1' AND loại_hình_công_việc = 'data processing' AND số_giờ < 10;"],
    
    ["List all products created by innovations from dcd launched in 2024 that saved over 50 hours.", "SELECT sản_phẩm FROM jidouka WHERE bộ_phận = 'dcd' AND thời_điểm_ra_mắt LIKE '2024%' AND số_giờ > 50;"],
    ["How many innovations related to task types like database processing were created using Visual Studio Code in 2024?", "SELECT COUNT(*) FROM jidouka WHERE công_cụ = 'Visual Studio Code' AND loại_hình_công_việc = 'database processing' AND thời_điểm_ra_mắt LIKE '2024%';"],
    ["Find all task types launched by dc2 that saved more than 40 hours and were related to process optimization.", "SELECT DISTINCT loại_hình_công_việc FROM jidouka WHERE bộ_phận = 'dc2' AND số_giờ > 40 AND loại_hình_công_việc LIKE '%process optimization%';"],
    ["Show all improvements that saved more than 30 hours and were related to task types like product creation.", "SELECT * FROM jidouka WHERE số_giờ > 30 AND loại_hình_công_việc = 'product creation';"],
    ["How many contributors from souko worked on task types related to workflow optimization and saved over 50 hours?", "SELECT COUNT(DISTINCT tác_giả) FROM jidouka WHERE bộ_phận = 'souko' AND loại_hình_công_việc = 'workflow optimization' AND số_giờ > 50;"],
    ["List all improvements from dc1 that were related to job types like data entry and saved fewer than 10 hours.", "SELECT * FROM jidouka WHERE bộ_phận = 'dc1' AND loại_hình_công_việc = 'data entry' AND số_giờ < 10;"],
    ["How many task types were launched in 2024 that supported more than 20 tasks and saved over 30 hours?", "SELECT COUNT(DISTINCT loại_hình_công_việc) FROM jidouka WHERE thời_điểm_ra_mắt LIKE '2024%' AND số_công_việc_áp_dụng > 20 AND số_giờ > 30;"],
    ["Find all products created using Python from innovations launched in 2024.", "SELECT DISTINCT sản_phẩm FROM jidouka WHERE công_cụ = 'Python' AND thời_điểm_ra_mắt LIKE '2024%';"],
    ["List all improvements from souko launched in 2024 that saved fewer than 20 hours and were related to data automation.", "SELECT * FROM jidouka WHERE bộ_phận = 'souko' AND thời_điểm_ra_mắt LIKE '2024%' AND số_giờ < 20 AND loại_hình_công_việc = 'data automation';"],
    ["Show all improvements that saved more than 50 hours and were related to task types like product creation.", "SELECT * FROM jidouka WHERE số_giờ > 50 AND loại_hình_công_việc = 'product creation';"],
    
    ["How many contributors from dc1 worked on innovations launched in 2024 that saved fewer than 10 hours?", "SELECT COUNT(DISTINCT tác_giả) FROM jidouka WHERE bộ_phận = 'dc1' AND thời_điểm_ra_mắt LIKE '2024%' AND số_giờ < 10;"],
    ["Find all task types launched by dc3 that saved over 100 hours.", "SELECT DISTINCT loại_hình_công_việc FROM jidouka WHERE bộ_phận = 'dc3' AND số_giờ > 100;"],
    ["List all innovations from dc2 that saved over 50 hours and were related to database processing.", "SELECT * FROM jidouka WHERE bộ_phận = 'dc2' AND số_giờ > 50 AND loại_hình_công_việc = 'database processing';"],
    ["How many products were created using Excel from innovations launched before 2024?", "SELECT COUNT(*) FROM jidouka WHERE công_cụ = 'Excel' AND thời_điểm_ra_mắt < '2024-01-01';"],
    ["Find all innovations from dcd that were related to task types like data entry and saved fewer than 30 hours.", "SELECT * FROM jidouka WHERE bộ_phận = 'dcd' AND loại_hình_công_việc = 'data entry' AND số_giờ < 30;"],
    ["Show all task types that saved fewer than 10 hours and were related to workflow optimization.", "SELECT DISTINCT loại_hình_công_việc FROM jidouka WHERE số_giờ < 10 AND loại_hình_công_việc LIKE '%workflow optimization%';"],
    ["How many innovations were created using Visual Studio Code and saved over 50 hours?", "SELECT COUNT(*) FROM jidouka WHERE công_cụ = 'Visual Studio Code' AND số_giờ > 50;"],
    ["List all improvements launched by dc1 in 2024 that were related to job types like process optimization.", "SELECT * FROM jidouka WHERE bộ_phận = 'dc1' AND thời_điểm_ra_mắt LIKE '2024%' AND loại_hình_công_việc LIKE '%process optimization%';"],
    ["Find all products generated by tools used for task types related to database processing and saved more than 50 hours.", "SELECT DISTINCT sản_phẩm FROM jidouka WHERE loại_hình_công_việc = 'database processing' AND số_giờ > 50;"],
    
    ["Show all improvements launched in 2023 by souko that saved over 30 hours and were related to workflow optimization.", "SELECT * FROM jidouka WHERE bộ_phận = 'souko' AND thời_điểm_ra_mắt LIKE '2023%' AND số_giờ > 30 AND loại_hình_công_việc LIKE '%workflow optimization%';"],
    ["How many task types related to data processing were launched by dc2 in 2024?", "SELECT COUNT(DISTINCT loại_hình_công_việc) FROM jidouka WHERE bộ_phận = 'dc2' AND loại_hình_công_việc = 'data processing' AND thời_điểm_ra_mắt LIKE '2024%';"],
    ["List all improvements that saved more than 50 hours and were related to task types like database processing.", "SELECT * FROM jidouka WHERE số_giờ > 50 AND loại_hình_công_việc = 'database processing';"],
    ["How many innovations launched by souko in 2024 saved over 100 hours and supported more than 30 tasks?", "SELECT COUNT(*) FROM jidouka WHERE bộ_phận = 'souko' AND thời_điểm_ra_mắt LIKE '2024%' AND số_giờ > 100 AND số_công_việc_áp_dụng > 30;"],
    ["Find all task types launched before 2024 that saved fewer than 10 hours.", "SELECT DISTINCT loại_hình_công_việc FROM jidouka WHERE thời_điểm_ra_mắt < '2024-01-01' AND số_giờ < 10;"],
    ["Show all innovations from dc3 launched in 2023 that were related to task types like product creation.", "SELECT * FROM jidouka WHERE bộ_phận = 'dc3' AND thời_điểm_ra_mắt LIKE '2023%' AND loại_hình_công_việc = 'product creation';"],
    ["How many contributors from souko worked on innovations that saved over 100 hours and were related to workflow optimization?", "SELECT COUNT(DISTINCT tác_giả) FROM jidouka WHERE bộ_phận = 'souko' AND số_giờ > 100 AND loại_hình_công_việc = 'workflow optimization';"],
    ["List all improvements launched by dc2 that saved fewer than 20 hours and were related to task types like data entry.", "SELECT * FROM jidouka WHERE bộ_phận = 'dc2' AND số_giờ < 20 AND loại_hình_công_việc = 'data entry';"]
]

# %%
len(data)
# Out:
# 451

# %%
import re
def modify_query(query):
    modified_query = re.sub(r"= '([^']*)'", r"LIKE LOWER('%\1%')", query)
    return modified_query

# %%
data2 = []
for i in range(len(data)):
    lst = []
    lst.append(data[i][0])
    lst.append(modify_query(data[i][1]))
    data2.append(lst)

# %%
dct = {'context':[],'question':[], 'answer':[]}
for i in range(len(data2)):
    dct['context'].append(context)
    dct['question'].append(data[i][0])
    dct['answer'].append(data2[i][1])

# %%
import pandas as pd 
df3 = pd.DataFrame(dct)

# %%
df3.to_csv('output451_records_english.csv', index=False)

# %%
df_a = pd.read_csv('output289_records_vietnam.csv')
df_b = pd.read_csv('output300_records _vietnam.csv')

# %%
def format_context(sample):
    sample['context'] = context
    return sample

# %%
df_a['context'] = context 
df_b['context'] = context

# %%
df_combined = pd.concat([df_a, df_b], axis=0)

# %%
df_combined
# Out:
#                                                context  \
# 0     \nYou are an SQL query assistant. Based on th...
# 1     \nYou are an SQL query assistant. Based on th...
# 2     \nYou are an SQL query assistant. Based on th...
# 3     \nYou are an SQL query assistant. Based on th...
# 4     \nYou are an SQL query assistant. Based on th...
# ..                                                 ...
# 295   \nYou are an SQL query assistant. Based on th...
# 296   \nYou are an SQL query assistant. Based on th...
# 297   \nYou are an SQL query assistant. Based on th...
# 298   \nYou are an SQL query assistant. Based on th...
# 299   \nYou are an SQL query assistant. Based on th...
#
#                                               question  \
# 0    Cải tiến nào có số giờ tiết kiệm từ 5 đến 15 v...
# 1    Danh sách các cải tiến có tác giả là 'Tran Thi...
# 2    Có cải tiến nào giúp tối ưu hóa quy trình quản...
# 3    Tìm các cải tiến có tác giả là 'Nguyen Thi T' ...
# ...

# %%
df_combined.to_csv('output589_records_vietnam.csv', index=False)
